# %%
import numpy as np
import pandas as pd
import sys
import pickle
from env_action.environment import FJSP_under_uncertainties_Env

directory           = 'SMALL'
planning_horizon    = 480*60
critical_machines   = {5, 6, 7, 8, 9, 10, 11, 12, 13, 21, 22, 26, 27}
ReworkProbability   = 0.03
maxtime             = 10
PopSize             = 80
WeibullDistribution = pd.read_excel('DATA/DataMaster.xlsx', sheet_name='Distribution')
K                   = 30
maxJob              = 1320
maxOpe              = 5760

# Default setting
reward_ratio            = 0.99
learning_rate           = 1e-4
explore_fraction_phase1 = 0.8
explore_fraction_phase2 = 0.5
explore_fraction_phase3 = 0.3
num_timestep_phase1     = 2000
num_timestep_phase2     = 6000
num_timestep_phase3     = 12000


purpose = 'testing training freq'

#------- EXPLORATION FRACTION------------
if purpose == "SA low exploration fraction":
    explore_fraction_phase1 = 0.7
    explore_fraction_phase2 = 0.4
    explore_fraction_phase3 = 0.2
if purpose == "SA high exploration fraction":
    explore_fraction_phase1 = 0.9
    explore_fraction_phase2 = 0.6
    explore_fraction_phase3 = 0.4

#---------- REWARD RATIO-------------
if purpose == "SA reward 0.90":
    reward_ratio = 0.90
if purpose == "SA reward 0.80":
    reward_ratio = 0.80

#---------- CURRICULUM -------------
if purpose == "SA learning distribution smaller":
    num_timestep_phase1     = 1000
    num_timestep_phase2     = 2000
    num_timestep_phase3     = 5000
if purpose == "SA learning distribution more in ealier":
    num_timestep_phase1     = 10000
    num_timestep_phase2     = 7000
    num_timestep_phase3     = 6000

#-----------LEARNING RATE ---------
if purpose == "SA learning rate 1e-3 ":
    learning_rate = 1e-3
if purpose == "SA learning rate 1e-5 ":
    learning_rate = 1e-5

# %%
import gymnasium as gym
import matplotlib.pyplot as plt
from stable_baselines3.common.vec_env     import DummyVecEnv
from stable_baselines3.common.callbacks   import BaseCallback, EvalCallback
from stable_baselines3.common.monitor     import Monitor
from stable_baselines3.common.env_checker import check_env 

with open('DATA/SMALL/pickle_instances_480.pkl', 'rb') as f:
    instances = pickle.load(f)
with open('DATA/SMALL/pickle_scenarios_480.pkl', 'rb') as f:
    scenarios = pickle.load(f)

env1 = FJSP_under_uncertainties_Env(True , True , instances, scenarios, K, WeibullDistribution, critical_machines, 
                                    ReworkProbability, planning_horizon, PopSize, maxtime, maxJob, maxOpe, reward_ratio)
env2 = FJSP_under_uncertainties_Env(True , False, instances, scenarios, K, WeibullDistribution, critical_machines, 
                                    ReworkProbability, planning_horizon, PopSize, maxtime, maxJob, maxOpe, reward_ratio)
env3 = FJSP_under_uncertainties_Env(False, False, instances, scenarios, K, WeibullDistribution, critical_machines, 
                                    ReworkProbability, planning_horizon, PopSize, maxtime, maxJob, maxOpe, reward_ratio)

# check_env(env1)
# obs = env1.reset(seed=42)
# print("Observation:", obs)

# episodes = 2
# for episode in range(episodes):
# 	done = False
# 	obs = env1.reset()
# 	while done == False:#not done:
# 		random_action = env1.action_space.sample()
# 		obs, reward, done, truncated, info = env1.step(random_action)
# 		print('reward', reward)

# %%
from stable_baselines3 import DQN
import os
import datetime
import pandas as pd
from stable_baselines3.common.callbacks import BaseCallback

action_list            = ["GA", "TS", 
                          "LFOH", "LAPH", "LAP_LFO", 
                          "LFOH_TS", "LAPH_TS", "LFOH_GA", "LAPH_GA",
                          "CDR1", "CDR2", "CDR3", "CDR5", "CDR6",
                          "RCRS"]
                          
# Create directories for models and logs
current_time = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")


models_dir = f"models/{purpose}_{current_time}"
logdir = f"logs/{purpose}_{current_time}"
log_training_txt_dir = "log_training_txt"
log_training_excel_dir = "log_training_excel"

if not os.path.exists(models_dir):
    os.makedirs(models_dir)
if not os.path.exists(logdir):
    os.makedirs(logdir)
if not os.path.exists(log_training_txt_dir):
    os.makedirs(log_training_txt_dir)
if not os.path.exists(log_training_excel_dir):
    os.makedirs(log_training_excel_dir)

# Generate unique file names based on current time
log_file          = os.path.join(log_training_txt_dir,   f"training_{purpose}_{current_time}.txt")
excel_file        = os.path.join(log_training_excel_dir, f"training_{purpose}_{current_time}.xlsx")
action_count_file = os.path.join(log_training_txt_dir,   f"action_count_{purpose}_{current_time}.txt")
action_excel_file = os.path.join(log_training_excel_dir, f"action_count_{purpose}_{current_time}.xlsx")

# Define the custom callback -------------------------------------------------------------
class CustomCallback(BaseCallback):
    def __init__(self, log_dir, excel_file, txt_file, action_count_file, action_excel_file, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.log_dir = log_dir
        self.excel_file = excel_file
        self.txt_file = txt_file
        self.action_count_file = action_count_file
        self.action_excel_file = action_excel_file
        self.logs = []
        self.episode_rewards = []
        self.action_counts = {}
        self.episode_start = True

    def _on_training_start(self) -> None:
        # Initialize action counts
        self.action_counts = {action: 0 for action in action_list}

    def _on_step(self) -> bool:
        if self.episode_start:
            self.episode_rewards.append(0)
            self.episode_start = False

        # Record reward for the current step
        reward = self.locals['rewards'][0]
        self.episode_rewards[-1] += reward

        # Increment action count
        action = self.locals.get('actions', None)
        if action is not None:
            action_name = action_list[action[0]]
            self.action_counts[action_name] += 1
        
        return True

    def _on_rollout_end(self) -> None:
        # Called at the end of each episode
        sum_reward   = self.episode_rewards[-1] if self.episode_rewards else 0
        tardiness    = self.training_env.get_attr('unwrapped')[0].all_Tard
        
        self.logger.record('train/episode_reward',   sum_reward)
        self.logger.record('train/actual_tardiness', tardiness)
        

        self.logs.append({
            'episode': len(self.episode_rewards),
            'sum_reward': sum_reward,
            'tardiness': tardiness
        })

        self.episode_start = True

    
    def _on_training_end(self) -> None:
        # Save logs to Excel
        df = pd.DataFrame(self.logs)
        df.to_excel(self.excel_file, index=False)

        action_df = pd.DataFrame(list(self.action_counts.items()), columns=['Action', 'Count'])
        action_df.to_excel(self.action_excel_file, index=False)

        # Save logs to text file
        with open(self.txt_file, 'w') as f:
            f.write(df.to_string(index=False))
        with open(self.action_count_file, 'w') as f:
            f.write(action_df.to_string(index=False))

# Create the callback
callback = CustomCallback(log_dir=logdir, 
                          excel_file=excel_file,
                          txt_file=log_file,
                          action_count_file=action_count_file,
                          action_excel_file=action_excel_file,
                          verbose=1)

# Initialize the DQN model
model_path = os.path.join(models_dir, f"DQN_.zip")
model_phase1 = DQN("MlpPolicy", 
                    env1, 
                    verbose=1, 
                    tensorboard_log=logdir, 
                    train_freq=(3,"episode"),
                    target_update_interval  = 2000,
                    exploration_initial_eps = 0.80, 
                    exploration_final_eps   = 0.30, 
                    exploration_fraction    = explore_fraction_phase1, 
                    )

# Phase 1 training
model_phase1.learn(total_timesteps=num_timestep_phase1, 
                    reset_num_timesteps=True, 
                    tb_log_name="DQN",
                    log_interval=3,
                    callback=callback
                    )
model_phase1.save(model_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# urgent
# Logging to logs/testing training freq_2024-07-14_07-22-29/DQN_1
# Method selection:                    CDR3
# Method selection:                    CDR1
# urgent
# Method selection:                    LAPH-GA
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LFOH-TS
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LAPH
# Method selection:                    RCRS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    LFOH
# long
# urgent
# Method selection:                    LFOH
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LFOH
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | -91.5    |
# |    exploration_rate | 0.787    |
# | time/               |          |
# |    episodes         | 3        |
# |    fps              | 0        |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 42       |
# ----------------------------------
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAP_LFO
# long
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    CDR1
# long
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR1
# urgent
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAPH
# long
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# long
# urgent
# Method selection:                    LFOH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    LFOH-GA
# long
# urgent
# Method selection:                    LAPH
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | -60      |
# |    exploration_rate | 0.775    |
# | time/               |          |
# |    episodes         | 6        |
# |    fps              | 0        |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 80       |
# | train/              |          |
# |    actual_tardiness | 2.45e+06 |
# |    episode_reward   | -275     |
# ----------------------------------
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH-GA
# long
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-GA
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    CDR3
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | -50.6    |
# |    exploration_rate | 0.763    |
# | time/               |          |
# |    episodes         | 9        |
# |    fps              | 0        |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 119      |
# | train/              |          |
# |    actual_tardiness | 6.51e+05 |
# |    episode_reward   | -85.5    |
# ----------------------------------
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    LFOH-TS
# long
# urgent
# Method selection:                    CDR5
# long
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    LAPH
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | -44      |
# |    exploration_rate | 0.751    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 0        |
# |    time_elapsed     | 234      |
# |    total_timesteps  | 158      |
# | train/              |          |
# |    actual_tardiness | 8.07e+05 |
# |    episode_reward   | -95.7    |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.36     |
# |    n_updates        | 1        |
# ----------------------------------
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    GA
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR1
# long
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    GA
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | -48.2    |
# |    exploration_rate | 0.738    |
# | time/               |          |
# |    episodes         | 15       |
# |    fps              | 0        |
# |    time_elapsed     | 303      |
# |    total_timesteps  | 198      |
# | train/              |          |
# |    actual_tardiness | 3.47e+05 |
# |    episode_reward   | -71.7    |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.76     |
# |    n_updates        | 2        |
# ----------------------------------
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR5
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LAPH
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH-GA
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | -43.6    |
# |    exploration_rate | 0.726    |
# | time/               |          |
# |    episodes         | 18       |
# |    fps              | 0        |
# |    time_elapsed     | 378      |
# |    total_timesteps  | 237      |
# | train/              |          |
# |    actual_tardiness | 1.48e+06 |
# |    episode_reward   | -195     |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.1      |
# |    n_updates        | 3        |
# ----------------------------------
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LAPH
# long
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LFOH
# long
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    LFOH
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | -40.9    |
# |    exploration_rate | 0.714    |
# | time/               |          |
# |    episodes         | 21       |
# |    fps              | 0        |
# |    time_elapsed     | 435      |
# |    total_timesteps  | 276      |
# | train/              |          |
# |    actual_tardiness | 3.11e+05 |
# |    episode_reward   | -62.2    |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.27     |
# |    n_updates        | 4        |
# ----------------------------------
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR1
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    LAPH-TS
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | -42.3    |
# |    exploration_rate | 0.702    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 0        |
# |    time_elapsed     | 501      |
# |    total_timesteps  | 315      |
# | train/              |          |
# |    actual_tardiness | 1.14e+06 |
# |    episode_reward   | -72.8    |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.52     |
# |    n_updates        | 5        |
# ----------------------------------
# Method selection:                    RCRS
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LAP_LFO
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | -42.7    |
# |    exploration_rate | 0.689    |
# | time/               |          |
# |    episodes         | 27       |
# |    fps              | 0        |
# |    time_elapsed     | 544      |
# |    total_timesteps  | 354      |
# | train/              |          |
# |    actual_tardiness | 9.01e+05 |
# |    episode_reward   | -157     |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.21     |
# |    n_updates        | 6        |
# ----------------------------------
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR3
# urgent
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    LFOH-TS
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR3
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | -40.9    |
# |    exploration_rate | 0.678    |
# | time/               |          |
# |    episodes         | 30       |
# |    fps              | 0        |
# |    time_elapsed     | 591      |
# |    total_timesteps  | 392      |
# | train/              |          |
# |    actual_tardiness | 1.51e+06 |
# |    episode_reward   | -139     |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.08     |
# |    n_updates        | 7        |
# ----------------------------------
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    CDR1
# urgent
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    CDR1
# long
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH
# long
# urgent
# Method selection:                    LAPH
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | -40.5    |
# |    exploration_rate | 0.666    |
# | time/               |          |
# |    episodes         | 33       |
# |    fps              | 0        |
# |    time_elapsed     | 635      |
# |    total_timesteps  | 430      |
# | train/              |          |
# |    actual_tardiness | 7.58e+05 |
# |    episode_reward   | -71.9    |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.52     |
# |    n_updates        | 8        |
# ----------------------------------
# Method selection:                    TS
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LFOH
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH-TS
# long
# urgent
# Method selection:                    LFOH-TS
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | -40      |
# |    exploration_rate | 0.653    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 0        |
# |    time_elapsed     | 685      |
# |    total_timesteps  | 469      |
# | train/              |          |
# |    actual_tardiness | 3.41e+05 |
# |    episode_reward   | -110     |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.27     |
# |    n_updates        | 9        |
# ----------------------------------
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    LFOH-TS
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR1
# urgent
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR5
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR6
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | -40.3    |
# |    exploration_rate | 0.642    |
# | time/               |          |
# |    episodes         | 39       |
# |    fps              | 0        |
# |    time_elapsed     | 732      |
# |    total_timesteps  | 507      |
# | train/              |          |
# |    actual_tardiness | 4.38e+05 |
# |    episode_reward   | -105     |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.07     |
# |    n_updates        | 10       |
# ----------------------------------
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR1
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LFOH-TS
# long
# urgent
# Method selection:                    CDR3
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | -42.1    |
# |    exploration_rate | 0.629    |
# | time/               |          |
# |    episodes         | 42       |
# |    fps              | 0        |
# |    time_elapsed     | 774      |
# |    total_timesteps  | 546      |
# | train/              |          |
# |    actual_tardiness | 7.87e+05 |
# |    episode_reward   | -129     |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.81     |
# |    n_updates        | 11       |
# ----------------------------------
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | -42.3    |
# |    exploration_rate | 0.617    |
# | time/               |          |
# |    episodes         | 45       |
# |    fps              | 0        |
# |    time_elapsed     | 826      |
# |    total_timesteps  | 585      |
# | train/              |          |
# |    actual_tardiness | 1.22e+06 |
# |    episode_reward   | -196     |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.36     |
# |    n_updates        | 12       |
# ----------------------------------
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    CDR1
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | -41.3    |
# |    exploration_rate | 0.605    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 0        |
# |    time_elapsed     | 874      |
# |    total_timesteps  | 624      |
# | train/              |          |
# |    actual_tardiness | 1.44e+06 |
# |    episode_reward   | -139     |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.23     |
# |    n_updates        | 13       |
# ----------------------------------
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH-TS
# long
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR3
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | -40.3    |
# |    exploration_rate | 0.593    |
# | time/               |          |
# |    episodes         | 51       |
# |    fps              | 0        |
# |    time_elapsed     | 916      |
# |    total_timesteps  | 663      |
# | train/              |          |
# |    actual_tardiness | 6.54e+05 |
# |    episode_reward   | -75.3    |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.11     |
# |    n_updates        | 14       |
# ----------------------------------
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LFOH
# long
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    LFOH-TS
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LAP_LFO
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | -39.6    |
# |    exploration_rate | 0.581    |
# | time/               |          |
# |    episodes         | 54       |
# |    fps              | 0        |
# |    time_elapsed     | 947      |
# |    total_timesteps  | 702      |
# | train/              |          |
# |    actual_tardiness | 8.32e+05 |
# |    episode_reward   | -73      |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.69     |
# |    n_updates        | 15       |
# ----------------------------------
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR3
# long
# urgent
# ...
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    LFOH-TS
# long
# urgent
# Method selection:                    GA
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | -41.3    |
# |    exploration_rate | 0.3      |
# | time/               |          |
# |    episodes         | 138      |
# |    fps              | 0        |
# |    time_elapsed     | 3595     |
# |    total_timesteps  | 1793     |
# | train/              |          |
# |    actual_tardiness | 3.06e+05 |
# |    episode_reward   | -49.7    |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.61     |
# |    n_updates        | 43       |
# ----------------------------------
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAP_LFO
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    CDR1
# long
# urgent
# Method selection:                    CDR5
# long
# urgent
# Method selection:                    GA
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | -40.2    |
# |    exploration_rate | 0.3      |
# | time/               |          |
# |    episodes         | 141      |
# |    fps              | 0        |
# |    time_elapsed     | 3773     |
# |    total_timesteps  | 1832     |
# | train/              |          |
# |    actual_tardiness | 3.15e+05 |
# |    episode_reward   | -39.5    |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.32     |
# |    n_updates        | 44       |
# ----------------------------------
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | -39.4    |
# |    exploration_rate | 0.3      |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 0        |
# |    time_elapsed     | 3942     |
# |    total_timesteps  | 1871     |
# | train/              |          |
# |    actual_tardiness | 3.63e+05 |
# |    episode_reward   | -67      |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.69     |
# |    n_updates        | 45       |
# ----------------------------------
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    LFOH-GA
# long
# urgent
# Method selection:                    CDR1
# long
# urgent
# Method selection:                    LFOH-GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAP_LFO
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | -39.8    |
# |    exploration_rate | 0.3      |
# | time/               |          |
# |    episodes         | 147      |
# |    fps              | 0        |
# |    time_elapsed     | 4093     |
# |    total_timesteps  | 1910     |
# | train/              |          |
# |    actual_tardiness | 5.21e+05 |
# |    episode_reward   | -44.5    |
# |    learning_rate    | 0.0001   |
# |    loss             | 4        |
# |    n_updates        | 46       |
# ----------------------------------
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    LFOH
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    LAP_LFO
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    RCRS
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | -39.7    |
# |    exploration_rate | 0.3      |
# | time/               |          |
# |    episodes         | 150      |
# |    fps              | 0        |
# |    time_elapsed     | 4223     |
# |    total_timesteps  | 1949     |
# | train/              |          |
# |    actual_tardiness | 2.68e+06 |
# |    episode_reward   | -150     |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.98     |
# |    n_updates        | 47       |
# ----------------------------------
# Method selection:                    LFOH
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    CDR5
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | -39.9    |
# |    exploration_rate | 0.3      |
# | time/               |          |
# |    episodes         | 153      |
# |    fps              | 0        |
# |    time_elapsed     | 4357     |
# |    total_timesteps  | 1988     |
# | train/              |          |
# |    actual_tardiness | 3.11e+05 |
# |    episode_reward   | -60.1    |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.73     |
# |    n_updates        | 48       |
# ----------------------------------
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    LAPH
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LFOH-TS
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    LAP_LFO
# long
# urgent
# Method selection:                    LAP_LFO
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | -38.6    |
# |    exploration_rate | 0.3      |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 0        |
# |    time_elapsed     | 4537     |
# |    total_timesteps  | 2027     |
# | train/              |          |
# |    actual_tardiness | 7.18e+05 |
# |    episode_reward   | -93.5    |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.14     |
# |    n_updates        | 49       |
# ----------------------------------

# %%
# Phase 2 training
model_phase2 = DQN.load(model_path, 
                        env=env2, 
                        verbose=1, 
                        tensorboard_log=logdir, 
                        train_freq=(1, "episode"),
                        target_update_interval=2000
                        # , exploration_initial_eps=0.50, 
                        # exploration_final_eps=0.10, 
                        # exploration_fraction=explore_fraction_phase2
                        )

model_phase2.exploration_schedule.initial_p = 0.5
model_phase2.exploration_schedule.final_p = 0.1
model_phase2.exploration_schedule.schedule_timesteps = explore_fraction_phase2 * num_timestep_phase2


model_phase2.learn(total_timesteps=num_timestep_phase2, 
                   tb_log_name="DQN_phase2",
                   log_interval=3,
                   reset_num_timesteps=False,
                   callback=callback)
model_phase2.save(model_path)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs/testing training freq_2024-07-14_07-22-29/DQN_phase2_0
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAP_LFO
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    RCRS
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    GA
# Method selection:                    CDR2
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR6
# long
# Method selection:                    CDR5
# Method selection:                    CDR3
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    GA
# Method selection:                    RCRS
# Method selection:                    TS
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    LAP_LFO
# Method selection:                    LAPH-TS
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | -37.6    |
# |    exploration_rate | 0.295    |
# | time/               |          |
# |    episodes         | 159      |
# |    fps              | 0        |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 2061     |
# ----------------------------------
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    GA
# long
# Method selection:                    CDR3
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAP_LFO
# long
# Method selection:                    CDR3
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-TS
# long
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    LFOH-TS
# Method selection:                    GA
# long
# Method selection:                    CDR1
# long
# Method selection:                    LAPH-GA
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.7     |
# |    ep_rew_mean      | -36.3    |
# |    exploration_rate | 0.293    |
# | time/               |          |
# |    episodes         | 162      |
# |    fps              | 0        |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 2080     |
# | train/              |          |
# |    actual_tardiness | 1.06e+05 |
# |    episode_reward   | -8.17    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.363    |
# |    n_updates        | 51       |
# ----------------------------------
# Method selection:                    LAPH-GA
# Method selection:                    CDR1
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR1
# long
# urgent
# Method selection:                    GA
# Method selection:                    LAPH-GA
# Method selection:                    RCRS
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    GA
# Method selection:                    LAP_LFO
# long
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR2
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# Method selection:                    GA
# urgent
# Method selection:                    CDR5
# Method selection:                    GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LFOH
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    LFOH
# long
# urgent
# Method selection:                    GA
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.7     |
# |    ep_rew_mean      | -34.9    |
# |    exploration_rate | 0.289    |
# | time/               |          |
# |    episodes         | 165      |
# |    fps              | 0        |
# |    time_elapsed     | 214      |
# |    total_timesteps  | 2114     |
# | train/              |          |
# |    actual_tardiness | 3.48e+03 |
# |    episode_reward   | -0.154   |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0948   |
# |    n_updates        | 52       |
# ----------------------------------
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LFOH
# long
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    CDR6
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    LAPH-GA
# Method selection:                    CDR5
# Method selection:                    LFOH-TS
# Method selection:                    CDR2
# long
# Method selection:                    GA
# long
# Method selection:                    CDR5
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.6     |
# |    ep_rew_mean      | -34      |
# |    exploration_rate | 0.287    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 0        |
# |    time_elapsed     | 304      |
# |    total_timesteps  | 2142     |
# | train/              |          |
# |    actual_tardiness | 2.81e+05 |
# |    episode_reward   | -58.7    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.28     |
# |    n_updates        | 53       |
# ----------------------------------
# Method selection:                    LFOH
# Method selection:                    LAPH-GA
# Method selection:                    RCRS
# Method selection:                    LAPH-GA
# long
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    LAP_LFO
# long
# Method selection:                    CDR5
# long
# Method selection:                    GA
# long
# Method selection:                    CDR3
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    LAPH
# long
# urgent
# Method selection:                    TS
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.6     |
# |    ep_rew_mean      | -32.9    |
# |    exploration_rate | 0.283    |
# | time/               |          |
# |    episodes         | 171      |
# |    fps              | 0        |
# |    time_elapsed     | 399      |
# |    total_timesteps  | 2178     |
# | train/              |          |
# |    actual_tardiness | 2.17e+04 |
# |    episode_reward   | -16.2    |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.98     |
# |    n_updates        | 54       |
# ----------------------------------
# Method selection:                    CDR2
# Method selection:                    CDR2
# long
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# long
# Method selection:                    GA
# Method selection:                    RCRS
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    GA
# Method selection:                    LAPH-TS
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    LFOH-GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.4     |
# |    ep_rew_mean      | -31.9    |
# |    exploration_rate | 0.28     |
# | time/               |          |
# |    episodes         | 174      |
# |    fps              | 0        |
# |    time_elapsed     | 463      |
# |    total_timesteps  | 2206     |
# | train/              |          |
# |    actual_tardiness | 1.25e+04 |
# |    episode_reward   | -14.2    |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.38     |
# |    n_updates        | 55       |
# ----------------------------------
# Method selection:                    LFOH
# Method selection:                    LAPH
# Method selection:                    LAPH-GA
# long
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    LFOH
# long
# Method selection:                    LFOH-GA
# long
# Method selection:                    GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    GA
# long
# Method selection:                    GA
# Method selection:                    CDR1
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    CDR2
# long
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    CDR3
# long
# Method selection:                    GA
# long
# Method selection:                    LFOH-GA
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | -30.7    |
# |    exploration_rate | 0.278    |
# | time/               |          |
# |    episodes         | 177      |
# |    fps              | 0        |
# |    time_elapsed     | 508      |
# |    total_timesteps  | 2229     |
# | train/              |          |
# |    actual_tardiness | 1.66e+05 |
# |    episode_reward   | -7.33    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.215    |
# |    n_updates        | 56       |
# ----------------------------------
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAP_LFO
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    LAPH-TS
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# Method selection:                    TS
# Method selection:                    GA
# Method selection:                    LAPH-GA
# Method selection:                    LFOH-GA
# long
# Method selection:                    LAP_LFO
# long
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    CDR3
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | -28.5    |
# |    exploration_rate | 0.275    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 0        |
# |    time_elapsed     | 602      |
# |    total_timesteps  | 2262     |
# | train/              |          |
# |    actual_tardiness | 3.64e+04 |
# |    episode_reward   | -1.76    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.609    |
# |    n_updates        | 57       |
# ----------------------------------
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    GA
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | -28.8    |
# |    exploration_rate | 0.271    |
# | time/               |          |
# |    episodes         | 183      |
# |    fps              | 0        |
# |    time_elapsed     | 686      |
# |    total_timesteps  | 2296     |
# | train/              |          |
# |    actual_tardiness | 1.39e+04 |
# |    episode_reward   | -7.11    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0373   |
# |    n_updates        | 58       |
# ----------------------------------
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    GA
# long
# Method selection:                    LAP_LFO
# long
# Method selection:                    CDR5
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# Method selection:                    CDR1
# Method selection:                    CDR6
# Method selection:                    GA
# Method selection:                    LAP_LFO
# long
# Method selection:                    TS
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | -27.7    |
# |    exploration_rate | 0.269    |
# | time/               |          |
# |    episodes         | 186      |
# |    fps              | 0        |
# |    time_elapsed     | 746      |
# |    total_timesteps  | 2321     |
# | train/              |          |
# |    actual_tardiness | 2.46e+06 |
# |    episode_reward   | -121     |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.19     |
# |    n_updates        | 59       |
# ----------------------------------
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    CDR1
# Method selection:                    CDR6
# long
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    CDR1
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    CDR2
# long
# Method selection:                    GA
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | -26.3    |
# |    exploration_rate | 0.265    |
# | time/               |          |
# |    episodes         | 189      |
# |    fps              | 0        |
# |    time_elapsed     | 848      |
# |    total_timesteps  | 2357     |
# | train/              |          |
# |    actual_tardiness | 1.28e+04 |
# |    episode_reward   | -6.63    |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.22     |
# |    n_updates        | 60       |
# ----------------------------------
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-TS
# Method selection:                    CDR6
# long
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LFOH
# Method selection:                    LAPH-GA
# long
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# Method selection:                    LAPH-GA
# Method selection:                    LFOH
# Method selection:                    CDR5
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    TS
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR5
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | -24.9    |
# |    exploration_rate | 0.262    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 0        |
# |    time_elapsed     | 909      |
# |    total_timesteps  | 2388     |
# | train/              |          |
# |    actual_tardiness | 8.39e+03 |
# |    episode_reward   | -11      |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.635    |
# |    n_updates        | 61       |
# ----------------------------------
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LFOH-GA
# long
# Method selection:                    LAPH
# Method selection:                    GA
# long
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    CDR3
# long
# Method selection:                    LFOH
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | -23.5    |
# |    exploration_rate | 0.259    |
# | time/               |          |
# |    episodes         | 195      |
# |    fps              | 0        |
# |    time_elapsed     | 984      |
# |    total_timesteps  | 2420     |
# | train/              |          |
# |    actual_tardiness | 1.28e+04 |
# |    episode_reward   | -3.21    |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.37     |
# |    n_updates        | 62       |
# ----------------------------------
# Method selection:                    CDR3
# long
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LFOH-GA
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    CDR3
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LFOH-GA
# long
# Method selection:                    CDR2
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# Method selection:                    CDR3
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-TS
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | -21.8    |
# |    exploration_rate | 0.255    |
# | time/               |          |
# |    episodes         | 198      |
# |    fps              | 0        |
# |    time_elapsed     | 1022     |
# |    total_timesteps  | 2455     |
# | train/              |          |
# |    actual_tardiness | 880      |
# |    episode_reward   | -39.8    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.136    |
# |    n_updates        | 63       |
# ----------------------------------
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    GA
# long
# Method selection:                    CDR6
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    GA
# long
# Method selection:                    CDR3
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.6     |
# |    ep_rew_mean      | -20      |
# |    exploration_rate | 0.253    |
# | time/               |          |
# |    episodes         | 201      |
# |    fps              | 0        |
# |    time_elapsed     | 1067     |
# |    total_timesteps  | 2475     |
# | train/              |          |
# |    actual_tardiness | 0        |
# |    episode_reward   | -0.655   |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.698    |
# |    n_updates        | 64       |
# ----------------------------------
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LFOH
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    LAPH-TS
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    RCRS
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    TS
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    LFOH-TS
# long
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LFOH-TS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | -18.6    |
# |    exploration_rate | 0.251    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 0        |
# |    time_elapsed     | 1099     |
# |    total_timesteps  | 2499     |
# | train/              |          |
# |    actual_tardiness | 400      |
# |    episode_reward   | -4.21    |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.49     |
# |    n_updates        | 65       |
# ----------------------------------
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LFOH
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    LFOH
# Method selection:                    LAPH-GA
# long
# Method selection:                    CDR3
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LFOH
# Method selection:                    TS
# Method selection:                    CDR2
# long
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# Method selection:                    LAPH
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    GA
# long
# Method selection:                    CDR3
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | -16.5    |
# |    exploration_rate | 0.248    |
# | time/               |          |
# |    episodes         | 207      |
# |    fps              | 0        |
# |    time_elapsed     | 1120     |
# |    total_timesteps  | 2524     |
# | train/              |          |
# |    actual_tardiness | 1.11e+06 |
# |    episode_reward   | -39.9    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.09     |
# |    n_updates        | 66       |
# ----------------------------------
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR1
# long
# urgent
# Method selection:                    GA
# Method selection:                    CDR1
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    CDR5
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | -14.3    |
# |    exploration_rate | 0.246    |
# | time/               |          |
# |    episodes         | 210      |
# |    fps              | 0        |
# |    time_elapsed     | 1161     |
# |    total_timesteps  | 2548     |
# | train/              |          |
# |    actual_tardiness | 3.18e+03 |
# |    episode_reward   | -0.48    |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.87     |
# |    n_updates        | 67       |
# ----------------------------------
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    CDR5
# Method selection:                    LAPH-GA
# long
# Method selection:                    CDR3
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAP_LFO
# Method selection:                    LAPH-GA
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | -13.1    |
# |    exploration_rate | 0.244    |
# | time/               |          |
# |    episodes         | 213      |
# |    fps              | 0        |
# |    time_elapsed     | 1189     |
# |    total_timesteps  | 2567     |
# | train/              |          |
# |    actual_tardiness | 7.69e+04 |
# |    episode_reward   | -12.1    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0791   |
# |    n_updates        | 68       |
# ----------------------------------
# Method selection:                    LAPH-GA
# Method selection:                    GA
# Method selection:                    TS
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LFOH
# long
# urgent
# Method selection:                    LFOH-TS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | -12.6    |
# |    exploration_rate | 0.241    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 0        |
# |    time_elapsed     | 1255     |
# |    total_timesteps  | 2599     |
# | train/              |          |
# |    actual_tardiness | 1.34e+03 |
# |    episode_reward   | -3.75    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.541    |
# |    n_updates        | 69       |
# ----------------------------------
# Method selection:                    GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# Method selection:                    CDR3
# Method selection:                    GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# Method selection:                    CDR3
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    GA
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | -11.8    |
# |    exploration_rate | 0.238    |
# | time/               |          |
# |    episodes         | 219      |
# |    fps              | 0        |
# |    time_elapsed     | 1309     |
# |    total_timesteps  | 2632     |
# | train/              |          |
# |    actual_tardiness | 1.46e+05 |
# |    episode_reward   | -48.3    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.279    |
# |    n_updates        | 70       |
# ----------------------------------
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    TS
# long
# Method selection:                    LAPH-GA
# Method selection:                    LFOH-GA
# long
# Method selection:                    CDR1
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LFOH
# Method selection:                    LAPH-GA
# Method selection:                    CDR3
# long
# Method selection:                    TS
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | -11.2    |
# |    exploration_rate | 0.235    |
# | time/               |          |
# |    episodes         | 222      |
# |    fps              | 0        |
# |    time_elapsed     | 1341     |
# |    total_timesteps  | 2661     |
# | train/              |          |
# |    actual_tardiness | 1.18e+05 |
# |    episode_reward   | -16.3    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.265    |
# |    n_updates        | 71       |
# ----------------------------------
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    CDR3
# Method selection:                    LAPH-GA
# Method selection:                    GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    TS
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    LFOH
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    CDR2
# long
# Method selection:                    LAPH-GA
# Method selection:                    CDR3
# long
# Method selection:                    CDR2
# long
# Method selection:                    LAPH-TS
# Method selection:                    CDR3
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | -10.8    |
# |    exploration_rate | 0.232    |
# | time/               |          |
# |    episodes         | 225      |
# |    fps              | 0        |
# |    time_elapsed     | 1404     |
# |    total_timesteps  | 2693     |
# | train/              |          |
# |    actual_tardiness | 3.1e+03  |
# |    episode_reward   | -6.89    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0515   |
# |    n_updates        | 72       |
# ----------------------------------
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# long
# Method selection:                    CDR3
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | -10.6    |
# |    exploration_rate | 0.229    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 0        |
# |    time_elapsed     | 1456     |
# |    total_timesteps  | 2724     |
# | train/              |          |
# |    actual_tardiness | 3.8e+04  |
# |    episode_reward   | -14.5    |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.22     |
# |    n_updates        | 73       |
# ----------------------------------
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    CDR1
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    CDR6
# long
# urgent
# ...
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    LFOH
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR5
# long
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# Method selection:                    CDR6
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.64     |
# |    ep_rew_mean      | -13.4    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 768      |
# |    fps              | 0        |
# |    time_elapsed     | 7586     |
# |    total_timesteps  | 7816     |
# | train/              |          |
# |    actual_tardiness | 5.41e+04 |
# |    episode_reward   | -17.6    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.341    |
# |    n_updates        | 253      |
# ----------------------------------
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    TS
# Method selection:                    CDR6
# long
# Method selection:                    GA
# long
# Method selection:                    CDR6
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    RCRS
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR6
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.63     |
# |    ep_rew_mean      | -13.7    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 771      |
# |    fps              | 0        |
# |    time_elapsed     | 7607     |
# |    total_timesteps  | 7844     |
# | train/              |          |
# |    actual_tardiness | 2.64e+03 |
# |    episode_reward   | -48.7    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.424    |
# |    n_updates        | 254      |
# ----------------------------------
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    CDR2
# long
# Method selection:                    GA
# Method selection:                    CDR6
# long
# Method selection:                    GA
# Method selection:                    CDR6
# long
# Method selection:                    CDR2
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR5
# long
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.64     |
# |    ep_rew_mean      | -13.7    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 774      |
# |    fps              | 0        |
# |    time_elapsed     | 7637     |
# |    total_timesteps  | 7874     |
# | train/              |          |
# |    actual_tardiness | 2.33e+06 |
# |    episode_reward   | -83.4    |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.24     |
# |    n_updates        | 255      |
# ----------------------------------
# Method selection:                    TS
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR6
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.67     |
# |    ep_rew_mean      | -14      |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 777      |
# |    fps              | 0        |
# |    time_elapsed     | 7675     |
# |    total_timesteps  | 7905     |
# | train/              |          |
# |    actual_tardiness | 1.01e+06 |
# |    episode_reward   | -57.9    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.347    |
# |    n_updates        | 256      |
# ----------------------------------
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    CDR6
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.7      |
# |    ep_rew_mean      | -14.3    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 0        |
# |    time_elapsed     | 7708     |
# |    total_timesteps  | 7936     |
# | train/              |          |
# |    actual_tardiness | 4.12e+05 |
# |    episode_reward   | -82.5    |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.23     |
# |    n_updates        | 257      |
# ----------------------------------
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    CDR6
# long
# Method selection:                    GA
# Method selection:                    CDR6
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    CDR6
# long
# Method selection:                    LAPH-GA
# Method selection:                    CDR6
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    CDR6
# long
# Method selection:                    GA
# Method selection:                    CDR6
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.7      |
# |    ep_rew_mean      | -14.3    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 783      |
# |    fps              | 0        |
# |    time_elapsed     | 7743     |
# |    total_timesteps  | 7965     |
# | train/              |          |
# |    actual_tardiness | 3.67e+05 |
# |    episode_reward   | -58.3    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.161    |
# |    n_updates        | 258      |
# ----------------------------------
# Method selection:                    TS
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    CDR6
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    CDR6
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# Method selection:                    LAPH
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    CDR5
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    LAP_LFO
# long
# Method selection:                    CDR6
# long
# Method selection:                    CDR6
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.78     |
# |    ep_rew_mean      | -13.2    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 786      |
# |    fps              | 0        |
# |    time_elapsed     | 7769     |
# |    total_timesteps  | 7998     |
# | train/              |          |
# |    actual_tardiness | 2.95e+03 |
# |    episode_reward   | -0.697   |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.298    |
# |    n_updates        | 259      |
# ----------------------------------
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    CDR6
# long
# Method selection:                    CDR5
# Method selection:                    CDR6
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    CDR6
# long
# Method selection:                    CDR6
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-TS
# Method selection:                    GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    CDR6
# long
# Method selection:                    CDR6
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.75     |
# |    ep_rew_mean      | -12.7    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 789      |
# |    fps              | 0        |
# |    time_elapsed     | 7814     |
# |    total_timesteps  | 8028     |
# | train/              |          |
# |    actual_tardiness | 1.29e+05 |
# |    episode_reward   | -35      |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.98     |
# |    n_updates        | 260      |
# ----------------------------------

# %%
# Phase 3 training
from stable_baselines3 import DQN
model_phase3 = DQN.load(model_path, 
                        env=env3, 
                        verbose=1, 
                        tensorboard_log=logdir, 
                        train_freq=(1, "episode"),
                        target_update_interval=2000
                        # ,exploration_initial_eps=0.20, 
                        # exploration_final_eps=0.1, 
                        # exploration_fraction=explore_fraction_phase3
                        )

model_phase3.exploration_schedule.initial_p = 0.20
model_phase3.exploration_schedule.final_p = 0.05
model_phase3.exploration_schedule.schedule_timesteps = explore_fraction_phase3 * 10000

model_phase3.learn(total_timesteps=10000, 
                   tb_log_name="DQN_phase3",
                   log_interval=3,
                   reset_num_timesteps=False,
                   callback=callback)
model_phase3.save(model_path)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs/testing training freq_2024-07-14_07-22-29/DQN_phase3_0
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    RCRS
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LFOH
# Method selection:                    LAPH-GA
# Method selection:                    CDR6
# long
# Method selection:                    CDR6
# long
# Method selection:                    CDR6
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    GA
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    GA
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.77     |
# |    ep_rew_mean      | -12.2    |
# |    exploration_rate | 0.143    |
# | time/               |          |
# |    episodes         | 792      |
# |    fps              | 2        |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 8055     |
# | train/              |          |
# |    actual_tardiness | 250      |
# |    episode_reward   | -0.00868 |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.49e-05 |
# |    n_updates        | 263      |
# ----------------------------------
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    GA
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR5
# Method selection:                    LAPH-GA
# Method selection:                    CDR6
# long
# Method selection:                    LFOH
# Method selection:                    LAPH-GA
# Method selection:                    CDR6
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    CDR6
# Method selection:                    CDR6
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.69     |
# |    ep_rew_mean      | -11.9    |
# |    exploration_rate | 0.142    |
# | time/               |          |
# |    episodes         | 795      |
# |    fps              | 2        |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 8075     |
# | train/              |          |
# |    actual_tardiness | 3.04e+05 |
# |    episode_reward   | -10.8    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.253    |
# |    n_updates        | 266      |
# ----------------------------------
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    CDR6
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    CDR5
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    CDR6
# long
# Method selection:                    GA
# Method selection:                    GA
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.59     |
# |    ep_rew_mean      | -11.3    |
# |    exploration_rate | 0.141    |
# | time/               |          |
# |    episodes         | 798      |
# |    fps              | 2        |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 8096     |
# | train/              |          |
# |    actual_tardiness | 0        |
# |    episode_reward   | 0        |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.387    |
# |    n_updates        | 269      |
# ----------------------------------
# Method selection:                    CDR6
# Method selection:                    LAPH-GA
# Method selection:                    TS
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    GA
# Method selection:                    CDR6
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# Method selection:                    CDR6
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR6
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.67     |
# |    ep_rew_mean      | -10.5    |
# |    exploration_rate | 0.139    |
# | time/               |          |
# |    episodes         | 801      |
# |    fps              | 1        |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 8124     |
# | train/              |          |
# |    actual_tardiness | 0        |
# |    episode_reward   | 0        |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.132    |
# |    n_updates        | 272      |
# ----------------------------------
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# Method selection:                    GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR6
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    RCRS
# Method selection:                    LFOH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# urgent
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR6
# urgent
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 9.87      |
# |    ep_rew_mean      | -10.3     |
# |    exploration_rate | 0.137     |
# | time/               |           |
# |    episodes         | 804       |
# |    fps              | 0         |
# |    time_elapsed     | 150       |
# |    total_timesteps  | 8172      |
# | train/              |           |
# |    actual_tardiness | 0         |
# |    episode_reward   | -0.000802 |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.0537    |
# |    n_updates        | 275       |
# -----------------------------------
# Method selection:                    LFOH-GA
# urgent
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LFOH-TS
# urgent
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR6
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | -10.5    |
# |    exploration_rate | 0.135    |
# | time/               |          |
# |    episodes         | 807      |
# |    fps              | 0        |
# |    time_elapsed     | 285      |
# |    total_timesteps  | 8226     |
# | train/              |          |
# |    actual_tardiness | 50       |
# |    episode_reward   | -0.00307 |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.306    |
# |    n_updates        | 278      |
# ----------------------------------
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    CDR6
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    CDR6
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# Method selection:                    GA
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | -10.8    |
# |    exploration_rate | 0.132    |
# | time/               |          |
# |    episodes         | 810      |
# |    fps              | 0        |
# |    time_elapsed     | 434      |
# |    total_timesteps  | 8293     |
# | train/              |          |
# |    actual_tardiness | 1.35e+03 |
# |    episode_reward   | -0.0482  |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.186    |
# |    n_updates        | 281      |
# ----------------------------------
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    TS
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAP_LFO
# Method selection:                    RCRS
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    RCRS
# Method selection:                    CDR2
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    CDR3
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    CDR2
# Method selection:                    LFOH-GA
# Method selection:                    LAPH-TS
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LAPH
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | -10.6    |
# |    exploration_rate | 0.129    |
# | time/               |          |
# |    episodes         | 813      |
# |    fps              | 0        |
# |    time_elapsed     | 744      |
# |    total_timesteps  | 8368     |
# | train/              |          |
# |    actual_tardiness | 0        |
# |    episode_reward   | 0        |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.121    |
# |    n_updates        | 284      |
# ----------------------------------
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    CDR3
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    CDR5
# Method selection:                    LFOH-GA
# Method selection:                    LFOH
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | -10.4    |
# |    exploration_rate | 0.126    |
# | time/               |          |
# |    episodes         | 816      |
# |    fps              | 0        |
# |    time_elapsed     | 994      |
# |    total_timesteps  | 8438     |
# | train/              |          |
# |    actual_tardiness | 3.21e+05 |
# |    episode_reward   | -12      |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.212    |
# |    n_updates        | 287      |
# ----------------------------------
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-TS
# Method selection:                    CDR2
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    CDR1
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LAPH-GA
# Method selection:                    CDR1
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    CDR5
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    CDR6
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    CDR5
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | -10.3    |
# |    exploration_rate | 0.122    |
# | time/               |          |
# |    episodes         | 819      |
# |    fps              | 0        |
# |    time_elapsed     | 1194     |
# |    total_timesteps  | 8511     |
# | train/              |          |
# |    actual_tardiness | 0        |
# |    episode_reward   | -0.00941 |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.109    |
# |    n_updates        | 290      |
# ----------------------------------
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LAPH
# Method selection:                    LFOH
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    CDR5
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    TS
# Method selection:                    GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 12.1      |
# |    ep_rew_mean      | -9.68     |
# |    exploration_rate | 0.119     |
# | time/               |           |
# |    episodes         | 822       |
# |    fps              | 0         |
# |    time_elapsed     | 1398      |
# |    total_timesteps  | 8579      |
# | train/              |           |
# |    actual_tardiness | 0         |
# |    episode_reward   | -8.68e-05 |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.0568    |
# |    n_updates        | 293       |
# -----------------------------------
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# Method selection:                    GA
# Method selection:                    LAPH-GA
# Method selection:                    RCRS
# Method selection:                    LAPH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LAP_LFO
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    RCRS
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LAPH
# Method selection:                    CDR2
# Method selection:                    LAPH-GA
# Method selection:                    LFOH-GA
# Method selection:                    TS
# Method selection:                    LAPH-TS
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.5     |
# |    ep_rew_mean      | -9.58    |
# |    exploration_rate | 0.116    |
# | time/               |          |
# |    episodes         | 825      |
# |    fps              | 0        |
# |    time_elapsed     | 1607     |
# |    total_timesteps  | 8652     |
# | train/              |          |
# |    actual_tardiness | 2.49e+03 |
# |    episode_reward   | -0.0889  |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0944   |
# |    n_updates        | 296      |
# ----------------------------------
# Method selection:                    GA
# Method selection:                    LFOH
# Method selection:                    LFOH
# Method selection:                    LFOH
# Method selection:                    CDR2
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    CDR5
# Method selection:                    CDR1
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    CDR1
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# Method selection:                    LFOH
# Method selection:                    LAPH-TS
# Method selection:                    LFOH
# Method selection:                    GA
# Method selection:                    LAP_LFO
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | -8.87    |
# |    exploration_rate | 0.113    |
# | time/               |          |
# |    episodes         | 828      |
# |    fps              | 0        |
# |    time_elapsed     | 1768     |
# |    total_timesteps  | 8727     |
# | train/              |          |
# |    actual_tardiness | 6.16e+05 |
# |    episode_reward   | -23.5    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.111    |
# |    n_updates        | 299      |
# ----------------------------------
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-GA
# Method selection:                    GA
# Method selection:                    LFOH
# Method selection:                    LFOH
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH
# Method selection:                    LFOH
# Method selection:                    LFOH
# Method selection:                    LFOH
# Method selection:                    LFOH-GA
# long
# Method selection:                    LFOH
# long
# Method selection:                    LFOH
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | -9.08    |
# |    exploration_rate | 0.11     |
# | time/               |          |
# |    episodes         | 831      |
# |    fps              | 0        |
# |    time_elapsed     | 1889     |
# |    total_timesteps  | 8785     |
# | train/              |          |
# |    actual_tardiness | 0        |
# |    episode_reward   | 0        |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0934   |
# |    n_updates        | 302      |
# ----------------------------------
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR5
# long
# urgent
# Method selection:                    LFOH
# Method selection:                    GA
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    LFOH
# long
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    RCRS
# Method selection:                    LFOH
# Method selection:                    LFOH
# Method selection:                    LFOH
# Method selection:                    LFOH
# Method selection:                    LFOH
# Method selection:                    GA
# long
# Method selection:                    LFOH
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# long
# Method selection:                    GA
# long
# Method selection:                    LFOH
# long
# Method selection:                    LFOH
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | -9.03    |
# |    exploration_rate | 0.109    |
# | time/               |          |
# |    episodes         | 834      |
# |    fps              | 0        |
# |    time_elapsed     | 1907     |
# |    total_timesteps  | 8812     |
# | train/              |          |
# |    actual_tardiness | 8.51e+04 |
# |    episode_reward   | -3.05    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.147    |
# |    n_updates        | 305      |
# ----------------------------------
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH
# long
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    LFOH
# long
# urgent
# Method selection:                    LFOH
# long
# urgent
# Method selection:                    LFOH
# long
# urgent
# Method selection:                    LFOH
# long
# urgent
# Method selection:                    LFOH
# long
# urgent
# Method selection:                    LFOH
# Method selection:                    LFOH
# Method selection:                    LFOH
# Method selection:                    GA
# long
# Method selection:                    LFOH
# Method selection:                    GA
# long
# Method selection:                    LFOH
# Method selection:                    LFOH
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-GA
# long
# Method selection:                    LFOH
# long
# Method selection:                    LFOH
# long
# Method selection:                    LFOH
# long
# Method selection:                    LFOH
# long
# Method selection:                    LFOH
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | -9.16    |
# |    exploration_rate | 0.107    |
# | time/               |          |
# |    episodes         | 837      |
# |    fps              | 0        |
# ...
# |    actual_tardiness | 8.67e+05 |
# |    episode_reward   | -32.3    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.143    |
# |    n_updates        | 545      |
# ----------------------------------
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAP_LFO
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    LAPH
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    CDR6
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.2     |
# |    ep_rew_mean      | -9.04    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 1077     |
# |    fps              | 0        |
# |    time_elapsed     | 9953     |
# |    total_timesteps  | 12879    |
# | train/              |          |
# |    actual_tardiness | 1.59e+05 |
# |    episode_reward   | -5.97    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.251    |
# |    n_updates        | 548      |
# ----------------------------------
# Method selection:                    LAPH
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR1
# urgent
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR3
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.5     |
# |    ep_rew_mean      | -9.88    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 1080     |
# |    fps              | 0        |
# |    time_elapsed     | 10002    |
# |    total_timesteps  | 12919    |
# | train/              |          |
# |    actual_tardiness | 2.43e+06 |
# |    episode_reward   | -92.8    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0589   |
# |    n_updates        | 551      |
# ----------------------------------
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    TS
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    LFOH-GA
# long
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.4     |
# |    ep_rew_mean      | -9.87    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 1083     |
# |    fps              | 0        |
# |    time_elapsed     | 10035    |
# |    total_timesteps  | 12945    |
# | train/              |          |
# |    actual_tardiness | 0        |
# |    episode_reward   | 0        |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.12     |
# |    n_updates        | 554      |
# ----------------------------------
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LFOH
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    CDR1
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.1     |
# |    ep_rew_mean      | -9.84    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 1086     |
# |    fps              | 0        |
# |    time_elapsed     | 10073    |
# |    total_timesteps  | 12977    |
# | train/              |          |
# |    actual_tardiness | 1.1e+05  |
# |    episode_reward   | -3.94    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.429    |
# |    n_updates        | 557      |
# ----------------------------------
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    TS
# long
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAP_LFO
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | -9.8     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 1089     |
# |    fps              | 0        |
# |    time_elapsed     | 10105    |
# |    total_timesteps  | 13002    |
# | train/              |          |
# |    actual_tardiness | 0        |
# |    episode_reward   | 0        |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.333    |
# |    n_updates        | 560      |
# ----------------------------------
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LFOH
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAP_LFO
# long
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-GA
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | -9.85    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 1092     |
# |    fps              | 0        |
# |    time_elapsed     | 10125    |
# |    total_timesteps  | 13025    |
# | train/              |          |
# |    actual_tardiness | 5.57e+04 |
# |    episode_reward   | -1.95    |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.57     |
# |    n_updates        | 563      |
# ----------------------------------
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | -9.7     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 1095     |
# |    fps              | 0        |
# |    time_elapsed     | 10141    |
# |    total_timesteps  | 13046    |
# | train/              |          |
# |    actual_tardiness | 0        |
# |    episode_reward   | 0        |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.132    |
# |    n_updates        | 566      |
# ----------------------------------
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-GA
# Method selection:                    LFOH
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    LFOH-TS
# long
# Method selection:                    LAPH-GA
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | -9.61    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 1098     |
# |    fps              | 0        |
# |    time_elapsed     | 10152    |
# |    total_timesteps  | 13064    |
# | train/              |          |
# |    actual_tardiness | 2.72e+04 |
# |    episode_reward   | -0.949   |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0458   |
# |    n_updates        | 569      |
# ----------------------------------
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    CDR5
# long
# urgent
# Method selection:                    LAPH-GA

# %%
with open('VALIDATION/SMALL/pickle_valid_instances_480.pkl', 'rb') as f:
    valid_instances = pickle.load(f)
with open('VALIDATION/SMALL/pickle_valid_scenarios_480.pkl', 'rb') as f:
    valid_scenarios = pickle.load(f)

results = []
method = 'predictive-reactive DQN'
InstanceList = [f'valid{i+1}' for i in range(12)]
ScenarioList = ['A', 'B', 'C']

valenv = FJSP_under_uncertainties_Env(False, False, valid_instances, valid_scenarios, K, WeibullDistribution, critical_machines, 
                                      ReworkProbability, planning_horizon, PopSize, maxtime, maxJob, maxOpe, reward_ratio)


model = DQN.load(model_path, env=valenv)

for instance_id in InstanceList:
    print("-----------", instance_id)
    for scenario_id in ScenarioList:
        print("-----", scenario_id)
        # Reset the environment with the new dataset
        valenv.reset(test=True, 
                  datatest=instance_id, 
                  scenariotest=scenario_id)
        
        obs, info = valenv.reset()
        done = False
        
        while not done:
            action, _states = model.predict(obs)
            obs, reward, done, truncated, info = valenv.step(action)
        
        tardiness = valenv.calc_tardiness()
    
        results.append({
                        'Method'    : method,
                        'InstanceID': instance_id,
                        'ScenarioID': scenario_id,
                        'Tardiness' : tardiness
                        })

df = pd.DataFrame(results)
file_name = f"VALIDATION/{purpose}.xlsx"
df.to_excel(file_name, index=False)
