# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'

import tensorflow as tf

import gymnasium as gym
import pickle

from VALIDATION.KeyRef_2.KeyRef_2_env2 import Luo_DDQN_env
from stable_baselines3.common.callbacks   import BaseCallback
from stable_baselines3.common.env_checker import check_env

import datetime
import pandas as pd
from stable_baselines3.common.callbacks import BaseCallback

K = 30
planning_horizon        = 480*60
ReworkProbability       = 0.03
critical_machines       = {5, 6, 7, 8, 9, 10, 11, 12, 13, 21, 22, 26, 27}


purpose                 = "_tight_duedate_JA_MB"
directory               = 'DATA/TIGHT_DUEDATE'

tight_duedate_setting   = True if "tight_duedate" in purpose else False
JA_only_setting         = True if "JA_only" in purpose else False

WeibullDistribution     = pd.read_excel('DATA/DataMaster.xlsx', sheet_name='Distribution')

with open('DATA/ComponentMaster.pkl', 'rb') as f:
    master = pickle.load(f)
with open(f'{directory}_VALIDATION/pickle_valid_scenarios_480.pkl', 'rb') as f:
    valid_scenarios = pickle.load(f)

env = Luo_DDQN_env(K, planning_horizon, ReworkProbability, valid_scenarios, WeibullDistribution, critical_machines,
			  	 master, tight_duedate_setting, JA_only_setting, directory)

# check_env(env)
# obs = env.reset(seed=42,
#                 test=True, 
#                 datatest="valid2", 
#                 scenariotest="A")
            
# print("Observation:", obs)

# episodes = 1
# for episode in range(episodes):
# 	done = False
# 	obs = env.reset(test=True, 
#                     datatest="valid2", 
#                     scenariotest="A")
# 	while done == False: #not done:
# 		random_action = env.action_space.sample()
# 		obs, reward, done, truncated, info = env.step(random_action)

# %%
import numpy as np
import torch
from stable_baselines3 import DQN

model_path = "models/LuoDDQN_loose_duedate_JA_MB-2025-01-12_01-21-19/CustomDQN_"

model = DQN.load(model_path, env=env)
def softmax_action_selection(model, obs, mu):
    obs_tensor      = torch.tensor(obs, dtype=torch.float32).unsqueeze(0).to(model.device)
    q_values        = model.q_net(obs_tensor).detach().cpu().numpy().flatten()
    exp_q_values    = np.exp(mu * q_values)
    probabilities   = exp_q_values / np.sum(exp_q_values)
    action          = np.random.choice(len(q_values), p=probabilities)
    return action

results = []
InstanceList = [f'valid{i+1}' for i in range(15)]
ScenarioList = ['A', 'B', 'C']

mu = 1.6 
for action_id in range(4,6):
    print('CDR', action_id+1)
    for instance_id in InstanceList:
        print("-----------", instance_id)
        for scenario_id in ScenarioList:
            print("-----", scenario_id)
            # Reset the environment with the new dataset
            obs, info = env.reset(test=True, 
                    datatest=instance_id, 
                    scenariotest=scenario_id,
                    fixedaction=action_id)
            
            done = False
            
            while not done:
                action = softmax_action_selection(model, obs, mu)
                obs, reward, done, truncated, info = env.step(action)
            
            tardiness = env.calc_tardiness()
            print(tardiness)
            results.append({
                            'Method'    : f'CDR{action_id+1}',
                            'InstanceID': instance_id,
                            'ScenarioID': scenario_id,
                            'Tardiness' : tardiness
                            })
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# CDR 5
# ----------- valid1
# ----- A
# 0 There are 444 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 1
# [[0, 114]]
# [[0, 114]]
# ----------- Random MB at time 7200 on machine [1] at Ope [0, 114]
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 8
# [[2, 405]]
# [[2, 405]]
# ----------- Random MB at time 28800 on machine [8] at Ope [2, 405]
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 101240.0
# ----- B
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 8
# [[2, 185]]
# [[2, 185], [2, 187]]
# ----------- Random MB at time 12000 on machine [8] at Ope [2, 185]
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 8
# [[2, 207]]
# [[2, 207]]
# ----------- Random MB at time 13560 on machine [8] at Ope [2, 207]
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 10
# [[2, 477]]
# [[2, 477]]
# ----------- Random MB at time 34080 on machine [10] at Ope [2, 477]
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 122010.0
# ----- C
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 107810.0
# ----------- valid2
# ----- A
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 87720.0
# ----- B
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 6
# [[2, 235]]
# [[2, 235]]
# ----------- Random MB at time 17580 on machine [6] at Ope [2, 235]
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 102300.0
# ----- C
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 9
# [[2, 409]]
# [[2, 409]]
# ----------- Random MB at time 29320 on machine [9] at Ope [2, 409]
# 0 95 29320 [('MB', 9, 120.0, 'critical')]
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 86425.0
# ----------- valid3
# ----- A
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 9
# [[2, 171]]
# [[2, 171]]
# ----------- Random MB at time 12600 on machine [9] at Ope [2, 171]
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 88860.0
# ----- B
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 96215.0
# ----- C
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 9
# [[2, 342]]
# [[2, 342]]
# ----------- Random MB at time 24800 on machine [9] at Ope [2, 342]
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 93500.0
# ----------- valid4
# ----- A
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 1
# [[0, 313]]
# [[0, 313]]
# ----------- Random MB at time 23000 on machine [1] at Ope [0, 313]
# 0 191 23000 [('MB', 1, 900.0, 'normal')]
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 93480.0
# ----- B
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 94795.0
# ----- C
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 1
# [[0, 16]]
# [[0, 16]]
# ----------- Random MB at time 540 on machine [1] at Ope [0, 16]
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 12
# having MB in random_events 16
# having MB in random_events 17
# [[2, 229]]
# [[2, 229]]
# ----------- Random MB at time 16920 on machine [12, 16, 17] at Ope [2, 229]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 37
#      35 while not done:
#      36     action = softmax_action_selection(model, obs, mu)
# ---> 37     obs, reward, done, truncated, info = env.step(action)
#      39 tardiness = env.calc_tardiness()
#      40 print(tardiness)
#
# File c:\Users\dvtruc\Downloads\HuynhHoangMyDung\Thesis\VALIDATION\KeyRef_2\KeyRef_2_env2.py:454, in Luo_DDQN_env.step(self, action)
#     451 self.S_k = np.maximum(self.S_k, self.t)
#     452 # Handle mannually if uncertain event is a machine breakdown
#     453 # print("3. handle machine breakdown")
# --> 454 self.handle_machine_breakdown()
#     456 # Job Arrival
#     457 # print("4. handle job arrival")
#     458 self.handle_job_arrival()
#
# File c:\Users\dvtruc\Downloads\HuynhHoangMyDung\Thesis\VALIDATION\KeyRef_2\KeyRef_2_env2.py:280, in Luo_DDQN_env.handle_machine_breakdown(self)
#     275 for breakdown_MC in self.MBList:
#     276 	overlap_mask = np.logical_or(
#     277 			np.logical_and(self.S_ij >= self.t        		 		  , self.C_ij <= self.t + self.re[breakdown_MC]),       # in
#     278 			np.logical_and(self.S_ij <= self.t             		      , self.C_ij >  self.t     				   ),       # left
#     279 			np.logical_and(self.S_ij <  self.t + self.re[breakdown_MC], self.C_ij >= self.t + self.re[breakdown_MC]))       # right
# --> 280 	indices = np.argwhere(X_mask[:, :, breakdown_MC] & overlap_mask[:, :])
#     281 	operation = indices.tolist()
#     282 	print(operation)
#
# ValueError: operands could not be broadcast together with shapes (7,232) (8,232)

# %%
df = pd.DataFrame(results)

# %%
display(df)
# Out:
#    Method InstanceID ScenarioID  Tardiness
# 0    CDR3     valid1          A   102905.0
# 1    CDR3     valid1          B   128555.0
# 2    CDR3     valid1          C   107110.0
# 3    CDR3     valid2          A   102015.0
# 4    CDR3     valid2          B   112680.0
# ..    ...        ...        ...        ...
# 71   CDR4     valid9          C    70790.0
# 72   CDR4    valid10          A    92810.0
# 73   CDR4    valid10          B    96515.0
# 74   CDR4    valid10          C    93560.0
# 75   CDR4    valid11          A   101955.0
#
# [76 rows x 4 columns]

# %%
file_name = f"VALIDATION/LuoDDQN_{purpose}_56CDRs_FULL.xlsx"
df.to_excel(file_name, index=False)
