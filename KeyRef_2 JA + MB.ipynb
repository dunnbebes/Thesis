# %%
import gymnasium as gym
import pickle
from VALIDATION.KeyRef_2.KeyRef_2_env2 import KeyRef2_JA_and_MB_env
from stable_baselines3.common.callbacks   import BaseCallback
from stable_baselines3.common.env_checker import check_env
import os
import datetime
import pandas as pd
from stable_baselines3.common.callbacks import BaseCallback

K = 30
planning_horizon = 480*60
ReworkProbability = 0.03

with open('DATA/SMALL/pickle_valid_scenarios_480.pkl', 'rb') as f:
    valid_scenarios = pickle.load(f)

env = KeyRef2_JA_and_MB_env(K, planning_horizon, ReworkProbability, valid_scenarios)

# check_env(env)
# obs = env.reset(seed=42,
#                 test=True, 
#                 datatest="valid2", 
#                 scenariotest="A")
            
# print("Observation:", obs)

# episodes = 1
# for episode in range(episodes):
# 	done = False
# 	obs = env.reset(test=True, 
#                     datatest="valid2", 
#                     scenariotest="A")
# 	while done == False: #not done:
# 		random_action = env.action_space.sample()
# 		obs, reward, done, truncated, info = env.step(random_action)

# %%
# action_list = ["CDR1", "CDR2", "CDR3", "CDR4", "CDR5", "CDR6"]
                          
# # Create directories for models and logs
# current_time = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
# models_dir = f"models/keyref2-{current_time}"
# logdir = f"logs/keyref2-{current_time}"
# log_training_txt_dir = "keyref2_log_training_txt"
# log_training_excel_dir = "keyref2_log_training_excel"

# if not os.path.exists(models_dir):
#     os.makedirs(models_dir)
# if not os.path.exists(logdir):
#     os.makedirs(logdir)
# if not os.path.exists(log_training_txt_dir):
#     os.makedirs(log_training_txt_dir)
# if not os.path.exists(log_training_excel_dir):
#     os.makedirs(log_training_excel_dir)

# # Generate unique file names based on current time
# log_file          = os.path.join(log_training_txt_dir,   f"training_keyref2.txt")
# excel_file        = os.path.join(log_training_excel_dir, f"training_keyref2.xlsx")
# action_count_file = os.path.join(log_training_txt_dir,   f"action_count_keyref2.txt")
# action_excel_file = os.path.join(log_training_excel_dir, f"action_count_keyref2.xlsx")

# # Define the custom callback -------------------------------------------------------------
# class CustomCallback(BaseCallback):
#     def __init__(self, log_dir, excel_file, txt_file, action_count_file, action_excel_file, verbose=0):
#         super(CustomCallback, self).__init__(verbose)
#         self.log_dir = log_dir
#         self.excel_file = excel_file
#         self.txt_file = txt_file
#         self.action_count_file = action_count_file
#         self.action_excel_file = action_excel_file
#         self.logs = []
#         self.episode_rewards = []
#         self.action_counts = {}
#         self.episode_start = True

#     def _on_training_start(self) -> None:
#         # Initialize action counts
#         self.action_counts = {action: 0 for action in action_list}

#     def _on_step(self) -> bool:
#         if self.episode_start:
#             self.episode_rewards.append(0)
#             self.episode_start = False

#         # Record reward for the current step
#         reward = self.locals['rewards'][0]
#         self.episode_rewards[-1] += reward

#         # Increment action count
#         action = self.locals.get('actions', None)
#         if action is not None:
#             action_name = action_list[action[0]]
#             self.action_counts[action_name] += 1
            
#         return True

#     def _on_rollout_end(self) -> None:
#         # Called at the end of each episode
#         sum_reward   = self.episode_rewards[-1] if self.episode_rewards else 0
        
#         self.logger.record('train/episode_reward',   sum_reward)
#         self.logs.append({
#             'sum_reward': sum_reward,
#         })

#         self.episode_start = True

    
#     def _on_training_end(self) -> None:
#         # Save logs to Excel
#         df = pd.DataFrame(self.logs)
#         df.to_excel(self.excel_file, index=False)

#         action_df = pd.DataFrame(list(self.action_counts.items()), columns=['Action', 'Count'])
#         action_df.to_excel(self.action_excel_file, index=False)

#         # Save logs to text file
#         with open(self.txt_file, 'w') as f:
#             f.write(df.to_string(index=False))
#         with open(self.action_count_file, 'w') as f:
#             f.write(action_df.to_string(index=False))

# # Create the callback
# callback = CustomCallback(log_dir=logdir, 
#                           excel_file=excel_file,
#                           txt_file=log_file,
#                           action_count_file=action_count_file,
#                           action_excel_file=action_excel_file,
#                           verbose=1)

# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# from gymnasium import spaces
# from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
# from stable_baselines3 import DQN

# class CustomFeaturesExtractor(BaseFeaturesExtractor):
#     """
#     Custom feature extractor for DQN.
    
#     :param observation_space: (spaces.Box)
#     """
#     def __init__(self, observation_space: spaces.Box):
#         super(CustomFeaturesExtractor, self).__init__(observation_space, features_dim=6)  # Output features_dim matches last layer's output
#         n_input_nodes = observation_space.shape[0]
#         self.fc1 = nn.Linear(n_input_nodes, 30)
#         self.fc2 = nn.Linear(30, 30)
#         self.fc3 = nn.Linear(30, 30)
#         self.fc4 = nn.Linear(30, 30)
#         self.fc5 = nn.Linear(30, 30)
#         self.fc6 = nn.Linear(30, 6)  # Output layer with 6 nodes

#     def forward(self, observations: torch.Tensor) -> torch.Tensor:
#         x = F.tanh(self.fc1(observations))
#         x = F.tanh(self.fc2(x))
#         x = F.tanh(self.fc3(x))
#         x = F.tanh(self.fc4(x))
#         x = F.tanh(self.fc5(x))
#         x = self.fc6(x)  # Output layer
#         return x

# # Custom DQN class to implement soft target update
# class CustomDQN(DQN):
#     def __init__(self, *args, tau=0.01, **kwargs):
#         super(CustomDQN, self).__init__(*args, **kwargs)
#         self.tau = tau

#     def train(self, gradient_steps, batch_size=100):
#         # Train for gradient_steps
#         for gradient_step in range(gradient_steps):
#             # Sample replay buffer
#             replay_data = self.replay_buffer.sample(batch_size, env=self._vec_normalize_env)
            
#             # Mix online and target networks
#             target_q_values = self.q_net_target(replay_data.next_observations)
#             next_q_values, _ = target_q_values.max(dim=1)
#             next_q_values = next_q_values.reshape(-1, 1)

#             # Compute the target for the Q function
#             target_q = replay_data.rewards + (1 - replay_data.dones) * self.gamma * next_q_values

#             # Get current Q estimates
#             current_q = self.q_net(replay_data.observations).gather(1, replay_data.actions.long())

#             # Compute Huber loss (less sensitive to outliers)
#             loss = F.smooth_l1_loss(current_q, target_q)

#             # Optimize the model
#             self.policy.optimizer.zero_grad()
#             loss.backward()
#             self.policy.optimizer.step()

#             # Soft update of target network
#             with torch.no_grad():
#                 for target_param, param in zip(self.q_net_target.parameters(), self.q_net.parameters()):
#                     target_param.data.copy_(self.tau * param.data + (1.0 - self.tau) * target_param.data)

#             self.logger.record('train/loss', loss.item())

# # Define policy_kwargs for DQN model
# policy_kwargs = dict(
#     features_extractor_class=CustomFeaturesExtractor,
# )

# model_path = os.path.join(models_dir, "CustomDQN_.zip")
# # Initialize CustomDQN using the custom model
# model = CustomDQN(
#     'MlpPolicy',                    # Use a Multi-layer Perceptron (MLP) policy
#     env,                            # Your RL environment
#     policy_kwargs=policy_kwargs,
#     buffer_size=2000,               # Replay buffer size N
#     batch_size=32,                  # Batch size
#     gamma=0.9,                      # Discount factor
#     tau=0.01,                       # Soft target update strategy
#     exploration_initial_eps=0.5,    # Initial epsilon
#     exploration_final_eps=0.1,      # Final epsilon
#     exploration_fraction=0.5,
#     verbose=1,
#     tensorboard_log=logdir,
#     train_freq=(30,"step"),
#     learning_starts= 2000,
#     learning_rate= 1e-4
# )
# model.learn(total_timesteps=20000, 
#             tb_log_name="KeyRef2",
#             log_interval=1,
#             reset_num_timesteps=True,
#             callback=callback)
# model.save(model_path)

# %%
import numpy as np
import torch
from stable_baselines3 import DQN

model_path = "models/keyref2-2024-11-30_13-16-25/CustomDQN_"

model = DQN.load(model_path, env=env)
def softmax_action_selection(model, obs, mu):
    obs_tensor      = torch.tensor(obs, dtype=torch.float32).unsqueeze(0).to(model.device)
    q_values        = model.q_net(obs_tensor).detach().cpu().numpy().flatten()
    exp_q_values    = np.exp(mu * q_values)
    probabilities   = exp_q_values / np.sum(exp_q_values)
    action          = np.random.choice(len(q_values), p=probabilities)
    return action

results = []
method = 'keyref2'
InstanceList = [f'valid{i+1}' for i in range(5)]
ScenarioList = ['A', 'B', 'C']

mu = 1.6 
for time_run in range(1):
    print('time:', time_run)
    for instance_id in InstanceList:
        print("-----------", instance_id)
        for scenario_id in ScenarioList:
            print("-----", scenario_id)
            # Reset the environment with the new dataset
            obs, info = env.reset(test=True, 
                    datatest=instance_id, 
                    scenariotest=scenario_id)
            
            done = False
            
            while not done:
                action = softmax_action_selection(model, obs, mu)
                obs, reward, done, truncated, info = env.step(action)
            
            tardiness = env.calc_tardiness()
            print(tardiness)
            results.append({
                            'TimeRun'   : time_run,
                            'Method'    : method,
                            'InstanceID': instance_id,
                            'ScenarioID': scenario_id,
                            'Tardiness' : tardiness
                            })
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# time: 0
# ----------- valid1
# ----- A
# Testing
# MB
#  [[], [], [], [], [], [], [(3600.0, 2100.0, 'critical')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  214
# ----------- Rework job  410
# There are 694 jobs left
# There are 624 jobs left
# There are 554 jobs left
# ----------- Rework job  354
# ----------- Rework job  71
# There are 486 jobs left
# ----------- Rework job  435
# ----------- Rework job  403
# There are 418 jobs left
# ----------- Rework job  23
# ----------- Rework job  473
# There are 350 jobs left
# ----------- Rework job  27
# ----------- Rework job  98
# There are 282 jobs left
# ----------- Rework job  2
# There are 213 jobs left
# There are 143 jobs left
# ----------- Rework job  649
# There are 74 jobs left
# There are 4 jobs left
# ----------- Random MB at time 42990.0 on machine [6] at Ope [2, 733]
# ====== Done ======
# 4237300.0
# ----- B
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [], [(7620.0, 1140.0, 'critical')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  224
# ----------- Rework job  717
# ----------- Rework job  249
# ----------- Rework job  291
# There are 696 jobs left
# ----------- Rework job  314
# There are 627 jobs left
# ----------- Rework job  373
# There are 558 jobs left
# ----------- Rework job  62
# There are 489 jobs left
# ----------- Rework job  495
# ----------- Rework job  4
# ----------- Rework job  477
# There are 422 jobs left
# ----------- Rework job  675
# ----------- Rework job  302
# There are 354 jobs left
# There are 284 jobs left
# ----------- Rework job  578
# ----------- Rework job  471
# ----------- Rework job  489
# There are 217 jobs left
# There are 147 jobs left
# ----------- Rework job  671
# ----------- Rework job  611
# ----------- Rework job  655
# There are 80 jobs left
# There are 10 jobs left
# ----------- Random MB at time 39770.0 on machine [9] at Ope [2, 757]
# ====== Done ======
# 3070570.0
# ----- C
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [(20400.0, 2220.0, 'critical')], [], [], [], [], [], [], [], [], [], [], [(34140.0, 7500.0, 'normal')], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  167
# ----------- Rework job  6
# There are 694 jobs left
# ----------- Rework job  616
# ----------- Rework job  250
# ----------- Rework job  489
# There are 627 jobs left
# ----------- Rework job  274
# ----------- Rework job  436
# There are 559 jobs left
# ----------- Rework job  302
# There are 490 jobs left
# ----------- Rework job  571
# ----------- Rework job  349
# ----------- Rework job  667
# There are 423 jobs left
# ----------- Rework job  189
# ----------- Rework job  38
# There are 355 jobs left
# There are 285 jobs left
# ----------- Random MB at time 20400 on machine [8] at Ope [2, 124]
# There are 215 jobs left
# ----------- Rework job  497
# There are 146 jobs left
# There are 76 jobs left
# ----------- Rework job  706
# ----------- Rework job  417
# There are 8 jobs left
# ====== Done ======
# 2763220.0
# ----------- valid2
# ----- A
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [], [(33660.0, 60.0, 'critical')], [(18720.0, 1680.0, 'critical')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  222
# ----------- Rework job  31
# There are 318 jobs left
# ----------- Rework job  52
# ----------- Rework job  103
# There are 250 jobs left
# ----------- Rework job  90
# There are 181 jobs left
# ----------- Rework job  289
# ----------- Rework job  379
# There are 113 jobs left
# ----------- Rework job  311
# ----------- Rework job  235
# ----------- Rework job  340
# ----------- Rework job  384
# There are 47 jobs left
# ----------- Rework job  268
# ----------- Rework job  347
# ====== Done ======
# 413310.0
# ----- B
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  118
# ----------- Rework job  135
# There are 318 jobs left
# ----------- Rework job  21
# There are 249 jobs left
# ----------- Rework job  208
# There are 180 jobs left
# ----------- Rework job  170
# There are 111 jobs left
# ----------- Rework job  26
# ----------- Rework job  365
# ----------- Rework job  340
# There are 44 jobs left
# ----------- Rework job  205
# ----------- Rework job  222
# ====== Done ======
# 245480.0
# ----- C
# Testing
# MB
#  [[], [(21540.0, 1980.0, 'normal')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  50
# ----------- Rework job  32
# ----------- Rework job  66
# There are 319 jobs left
# ----------- Rework job  183
# ----------- Rework job  359
# There are 251 jobs left
# ----------- Rework job  152
# ----------- Rework job  160
# There are 183 jobs left
# ----------- Rework job  246
# ----------- Rework job  109
# ----------- Rework job  124
# There are 116 jobs left
# There are 46 jobs left
# ----------- Rework job  262
# ----------- Rework job  125
# ----------- Rework job  151
# ----------- Rework job  64
# ====== Done ======
# 966780.0
# ----------- valid3
# ----- A
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [(11340.0, 3180.0, 'critical')], [], [], [(30300.0, 840.0, 'critical')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  39
# ----------- Rework job  61
# ----------- Rework job  84
# There are 428 jobs left
# ----------- Rework job  20
# ----------- Rework job  480
# ----------- Rework job  107
# There are 361 jobs left
# ----------- Rework job  48
# ----------- Rework job  151
# ----------- Rework job  145
# ----------- Rework job  264
# There are 295 jobs left
# ----------- Rework job  475
# There are 226 jobs left
# ----------- Rework job  356
# There are 157 jobs left
# There are 87 jobs left
# ----------- Rework job  365
# There are 18 jobs left
# ----------- Random MB at time 15430.0 on machine [8] at Ope [2, 189]
# ====== Done ======
# 1188190.0
# ----- B
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  52
# ----------- Rework job  54
# There are 427 jobs left
# ----------- Rework job  11
# ----------- Rework job  180
# ----------- Rework job  248
# ----------- Rework job  22
# There are 361 jobs left
# ----------- Rework job  314
# ----------- Rework job  330
# ----------- Rework job  342
# There are 294 jobs left
# ----------- Rework job  487
# ----------- Rework job  345
# ----------- Rework job  154
# There are 227 jobs left
# There are 157 jobs left
# ----------- Rework job  190
# There are 88 jobs left
# ----------- Rework job  431
# ----------- Rework job  95
# ----------- Rework job  25
# ----------- Rework job  114
# ----------- Rework job  148
# There are 23 jobs left
# ----------- Rework job  461
# ====== Done ======
# 1825130.0
# ----- C
# Testing
# MB
#  [[], [(14160.0, 2760.0, 'normal')], [], [], [], [], [(6900.0, 5040.0, 'critical'), (19800.0, 3360.0, 'critical')], [], [], [], [], [], [], [], [], [], [], [], [], [(34380.0, 5580.0, 'normal')], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  258
# There are 426 jobs left
# ----------- Rework job  81
# ----------- Rework job  107
# There are 358 jobs left
# ----------- Rework job  0
# There are 289 jobs left
# ----------- Rework job  341
# ----------- Rework job  342
# There are 221 jobs left
# ----------- Rework job  231
# ----------- Rework job  440
# ----------- Rework job  205
# There are 154 jobs left
# ----------- Rework job  203
# ----------- Rework job  227
# ----------- Rework job  369
# There are 87 jobs left
# ----------- Rework job  387
# ----------- Rework job  389
# ----------- Rework job  422
# There are 20 jobs left
# ----------- Random MB at time 6900 on machine [6] at Ope [2, 503]
# ====== Done ======
# 1162940.0
# ----------- valid4
# ----- A
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [], [], [(7440.0, 900.0, 'critical')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# There are 325 jobs left
# ----------- Rework job  84
# ----------- Rework job  219
# There are 257 jobs left
# ----------- Rework job  217
# ----------- Rework job  256
# ----------- Rework job  324
# ----------- Rework job  354
# There are 191 jobs left
# ----------- Rework job  201
# There are 122 jobs left
# ----------- Rework job  158
# ----------- Rework job  156
# ----------- Rework job  327
# There are 55 jobs left
# ----------- Rework job  380
# ----------- Random MB at time 18520.0 on machine [10] at Ope [2, 29]
# ====== Done ======
# 770780.0
# ----- B
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  95
# ----------- Rework job  100
# ----------- Rework job  144
# ----------- Rework job  13
# There are 329 jobs left
# ----------- Rework job  202
# There are 260 jobs left
# ----------- Rework job  83
# ----------- Rework job  369
# There are 192 jobs left
# ----------- Rework job  330
# ----------- Rework job  226
# ----------- Rework job  210
# There are 125 jobs left
# ----------- Rework job  372
# ----------- Rework job  121
# ----------- Rework job  174
# ----------- Rework job  71
# ----------- Rework job  203
# There are 60 jobs left
# ----------- Rework job  81
# ====== Done ======
# 559940.0
# ----- C
# Testing
# MB
#  [[], [], [], [], [], [], [(18960.0, 6240.0, 'critical'), (34680.0, 420.0, 'critical')], [], [], [(3180.0, 4560.0, 'critical'), (25320.0, 1320.0, 'critical')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  10
# ----------- Rework job  40
# ----------- Rework job  117
# ----------- Random MB at time 3180 on machine [9] at Ope [2, 265]
# There are 328 jobs left
# ----------- Rework job  289
# ----------- Rework job  57
# ----------- Rework job  251
# There are 261 jobs left
# ----------- Rework job  386
# ----------- Rework job  388
# ----------- Rework job  216
# There are 194 jobs left
# There are 124 jobs left
# ----------- Rework job  73
# There are 55 jobs left
# ----------- Rework job  11
# ====== Done ======
# 198660.0
# ----------- valid5
# ----- A
# Testing
# MB
#  [[], [(12300.0, 2220.0, 'normal')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  41
# There are 568 jobs left
# There are 498 jobs left
# ----------- Rework job  30
# ----------- Rework job  188
# ----------- Random MB at time 12300 on machine [1] at Ope [1, 485]
# There are 430 jobs left
# ----------- Rework job  171
# There are 361 jobs left
# ----------- Rework job  529
# ----------- Rework job  10
# There are 293 jobs left
# ----------- Rework job  15
# ----------- Rework job  327
# There are 225 jobs left
# ----------- Rework job  32
# ----------- Rework job  636
# There are 157 jobs left
# ----------- Rework job  296
# ----------- Rework job  345
# There are 89 jobs left
# ----------- Rework job  632
# ----------- Rework job  255
# There are 21 jobs left
# ====== Done ======
# 1018750.0
# ----- B
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  405
# ----------- Rework job  7
# ----------- Rework job  108
# ----------- Rework job  53
# ----------- Rework job  568
# There are 572 jobs left
# ----------- Rework job  19
# ----------- Rework job  96
# ----------- Rework job  309
# ----------- Rework job  121
# There are 506 jobs left
# ----------- Rework job  198
# ----------- Rework job  165
# ----------- Rework job  268
# There are 439 jobs left
# ----------- Rework job  439
# ----------- Rework job  11
# There are 371 jobs left
# There are 301 jobs left
# ----------- Rework job  566
# ----------- Rework job  168
# ----------- Rework job  205
# There are 234 jobs left
# ----------- Rework job  243
# ----------- Rework job  296
# There are 166 jobs left
# ----------- Rework job  531
# There are 97 jobs left
# There are 27 jobs left
# ----------- Rework job  315
# ----------- Rework job  260
# ====== Done ======
# 1128760.0
# ----- C
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  251
# ----------- Rework job  272
# There are 569 jobs left
# ----------- Rework job  192
# ----------- Rework job  133
# There are 501 jobs left
# ----------- Rework job  488
# ----------- Rework job  185
# There are 433 jobs left
# ----------- Rework job  198
# ----------- Rework job  453
# There are 365 jobs left
# ----------- Rework job  301
# ----------- Rework job  234
# There are 297 jobs left
# ----------- Rework job  169
# ----------- Rework job  610
# ----------- Rework job  39
# ----------- Rework job  285
# There are 231 jobs left
# ----------- Rework job  573
# There are 162 jobs left
# ----------- Rework job  583
# There are 93 jobs left
# ----------- Rework job  475
# ----------- Rework job  146
# There are 25 jobs left
# ----------- Rework job  341
# ====== Done ======
# 1066500.0

# %%
InstanceList = [f'valid{i+1}' for i in range(5,15)]

for time_run in range(1):
    print('time:', time_run)
    for instance_id in InstanceList:
        print("-----------", instance_id)
        for scenario_id in ScenarioList:
            print("-----", scenario_id)
            # Reset the environment with the new dataset
            obs, info = env.reset(test=True, 
                    datatest=instance_id, 
                    scenariotest=scenario_id)
            
            done = False
            
            while not done:
                action = softmax_action_selection(model, obs, mu)
                obs, reward, done, truncated, info = env.step(action)
            
            tardiness = env.calc_tardiness()
            print(tardiness)
            results.append({
                            'TimeRun'   : time_run,
                            'Method'    : method,
                            'InstanceID': instance_id,
                            'ScenarioID': scenario_id,
                            'Tardiness' : tardiness
                            })
# Out:
# time: 0
# ----------- valid6
# ----- A
# Testing
# MB
#  [[], [(27120.0, 720.0, 'normal')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  410
# ----------- Rework job  199
# There are 451 jobs left
# There are 381 jobs left
# ----------- Rework job  357
# ----------- Rework job  192
# There are 313 jobs left
# There are 243 jobs left
# ----------- Rework job  405
# ----------- Rework job  99
# ----------- Rework job  164
# There are 176 jobs left
# ----------- Rework job  19
# There are 107 jobs left
# ----------- Rework job  119
# ----------- Rework job  491
# There are 39 jobs left
# ====== Done ======
# 4970480.0
# ----- B
# Testing
# MB
#  [[], [], [], [], [], [], [], [(3300.0, 240.0, 'critical'), (6300.0, 1080.0, 'critical')], [(7980.0, 480.0, 'critical')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  297
# ----------- Rework job  242
# There are 451 jobs left
# ----------- Rework job  293
# ----------- Rework job  361
# ----------- Rework job  451
# There are 384 jobs left
# ----------- Rework job  386
# There are 315 jobs left
# ----------- Rework job  438
# ----------- Rework job  39
# ----------- Rework job  316
# ----------- Rework job  435
# There are 249 jobs left
# ----------- Rework job  428
# ----------- Rework job  304
# ----------- Rework job  492
# There are 182 jobs left
# ----------- Rework job  5
# There are 113 jobs left
# ----------- Rework job  265
# ----------- Rework job  366
# ----------- Rework job  491
# ----------- Rework job  508
# There are 47 jobs left
# ----------- Rework job  14
# ----------- Rework job  261
# ----------- Rework job  38
# ----------- Random MB at time 36240.0 on machine [7] at Ope [2, 38]
# ====== Done ======
# 4493880.0
# ----- C
# Testing
# MB
#  [[], [], [], [], [], [], [(2520.0, 4020.0, 'critical')], [(12360.0, 5640.0, 'critical')], [(35280.0, 2700.0, 'critical')], [(25620.0, 6360.0, 'critical')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Random MB at time 2520 on machine [6] at Ope [2, 285]
# ----------- Random MB at time 12360 on machine [7] at Ope [2, 104]
# There are 449 jobs left
# ----------- Rework job  181
# There are 380 jobs left
# ----------- Rework job  484
# There are 311 jobs left
# There are 241 jobs left
# ----------- Rework job  445
# There are 172 jobs left
# ----------- Rework job  389
# ----------- Rework job  502
# There are 104 jobs left
# ----------- Rework job  265
# ----------- Rework job  47
# ----------- Rework job  54
# There are 37 jobs left
# ----------- Rework job  268
# ----------- Rework job  31
# ----------- Random MB at time 35050.0 on machine [9] at Ope [2, 522]
# ====== Done ======
# 3843770.0
# ----------- valid7
# ----- A
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  27
# ----------- Rework job  71
# ----------- Rework job  14
# ----------- Rework job  2
# There are 94 jobs left
# ----------- Rework job  6
# ----------- Rework job  36
# ----------- Rework job  113
# ----------- Rework job  40
# ----------- Rework job  91
# There are 29 jobs left
# ----------- Rework job  74
# ====== Done ======
# 871380.0
# ----- B
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [(15240.0, 1140.0, 'critical')], [(4860.0, 9660.0, 'critical')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  103
# There are 91 jobs left
# ----------- Rework job  71
# There are 22 jobs left
# ----------- Random MB at time 6960.0 on machine [9] at Ope [2, 14]
# ====== Done ======
# 930510.0
# ----- C
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [], [(29460.0, 1200.0, 'critical')], [], [], [(17880.0, 1800.0, 'critical')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  127
# ----------- Rework job  146
# There are 92 jobs left
# ----------- Rework job  59
# ----------- Rework job  73
# ----------- Rework job  4
# There are 25 jobs left
# ====== Done ======
# 966770.0
# ----------- valid8
# ----- A
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  53
# ----------- Rework job  250
# ----------- Rework job  147
# ----------- Rework job  131
# There are 519 jobs left
# ----------- Rework job  527
# There are 450 jobs left
# ----------- Rework job  457
# ----------- Rework job  510
# There are 382 jobs left
# ----------- Rework job  551
# ----------- Rework job  584
# There are 314 jobs left
# ----------- Rework job  571
# ----------- Rework job  233
# There are 246 jobs left
# ----------- Rework job  266
# ----------- Rework job  40
# There are 178 jobs left
# ----------- Rework job  275
# There are 109 jobs left
# There are 39 jobs left
# ====== Done ======
# 1141770.0
# ----- B
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [(660.0, 5160.0, 'normal')], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  44
# ----------- Rework job  65
# ----------- Rework job  351
# ----------- Rework job  108
# There are 519 jobs left
# ----------- Rework job  305
# There are 450 jobs left
# ----------- Random MB at time 660 on machine [16] at Ope [1, 372]
# ----------- Rework job  518
# There are 381 jobs left
# ----------- Rework job  150
# There are 312 jobs left
# ----------- Rework job  175
# ----------- Rework job  192
# There are 244 jobs left
# ----------- Rework job  498
# ----------- Rework job  356
# There are 176 jobs left
# ----------- Rework job  259
# There are 107 jobs left
# ----------- Rework job  324
# ----------- Rework job  367
# There are 39 jobs left
# ----------- Rework job  434
# ----------- Rework job  416
# ----------- Rework job  424
# ----------- Rework job  435
# ----------- Rework job  447
# ====== Done ======
# 1576730.0
# ----- C
# Testing
# MB
#  [[], [], [], [(2340.0, 6120.0, 'normal')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  141
# ----------- Rework job  8
# There are 517 jobs left
# There are 447 jobs left
# ----------- Rework job  13
# ----------- Random MB at time 2340 on machine [3] at Ope [0, 408]
# ----------- Rework job  477
# There are 379 jobs left
# ----------- Rework job  348
# ----------- Rework job  151
# ----------- Rework job  334
# There are 312 jobs left
# ----------- Rework job  482
# ----------- Rework job  386
# ----------- Rework job  421
# ----------- Rework job  501
# ----------- Rework job  360
# There are 247 jobs left
# ----------- Rework job  213
# ----------- Rework job  37
# ----------- Rework job  579
# ----------- Rework job  273
# ----------- Rework job  516
# There are 182 jobs left
# ----------- Rework job  295
# ----------- Rework job  253
# There are 114 jobs left
# ----------- Rework job  500
# There are 45 jobs left
# ----------- Rework job  388
# ----------- Rework job  449
# ====== Done ======
# 1918670.0
# ----------- valid9
# ----- A
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [], [], [], [(10980.0, 3840.0, 'critical')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# There are 393 jobs left
# ----------- Rework job  337
# ----------- Rework job  21
# ----------- Rework job  328
# There are 326 jobs left
# ----------- Rework job  364
# ----------- Rework job  10
# There are 258 jobs left
# ----------- Rework job  204
# ----------- Rework job  123
# ----------- Rework job  126
# ----------- Rework job  447
# There are 192 jobs left
# There are 122 jobs left
# ----------- Rework job  440
# There are 53 jobs left
# ----------- Rework job  117
# ----------- Rework job  172
# ----------- Rework job  149
# ----------- Random MB at time 38020.0 on machine [11] at Ope [2, 166]
# ====== Done ======
# 2089150.0
# ----- B
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [(26160.0, 1920.0, 'critical'), (32940.0, 2700.0, 'critical')], [], [], [], [(28200.0, 3180.0, 'critical')], [], [], [], [(18180.0, 3300.0, 'normal')], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Random MB at time 18180 on machine [16] at Ope [1, 9]
# There are 393 jobs left
# ----------- Rework job  404
# ----------- Rework job  313
# ----------- Rework job  298
# ----------- Rework job  11
# There are 327 jobs left
# ----------- Rework job  14
# ----------- Rework job  320
# There are 259 jobs left
# ----------- Rework job  206
# There are 190 jobs left
# ----------- Rework job  402
# There are 121 jobs left
# ----------- Rework job  420
# ----------- Rework job  438
# There are 53 jobs left
# ----------- Rework job  53
# ----------- Rework job  60
# ----------- Random MB at time 26160 on machine [8] at Ope [2, 90]
# ====== Done ======
# 1984050.0
# ----- C
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [(7980.0, 5220.0, 'critical')], [(17520.0, 2460.0, 'critical')], [(11280.0, 4560.0, 'critical'), (26460.0, 1680.0, 'critical')], [(15540.0, 4440.0, 'critical')], [], [], [], [], [], [], [(15720.0, 2760.0, 'normal')], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Random MB at time 7980 on machine [8] at Ope [2, 243]
# ----------- Random MB at time 11280 on machine [10] at Ope [2, 20]
# ----------- Rework job  2
# ----------- Rework job  80
# ----------- Random MB at time 15540 on machine [11] at Ope [2, 295]
# There are 395 jobs left
# ----------- Rework job  307
# There are 326 jobs left
# ----------- Rework job  331
# ----------- Rework job  380
# There are 258 jobs left
# ----------- Rework job  459
# ----------- Rework job  247
# ----------- Rework job  371
# There are 191 jobs left
# ----------- Rework job  33
# ----------- Rework job  285
# There are 123 jobs left
# ----------- Rework job  71
# ----------- Rework job  134
# There are 55 jobs left
# ----------- Rework job  146
# ----------- Random MB at time 22620.0 on machine [18] at Ope [1, 407]
# ====== Done ======
# 1376330.0
# ----------- valid10
# ----- A
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [], [], [(22080.0, 300.0, 'critical')], [], [(26220.0, 2040.0, 'critical')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  213
# ----------- Rework job  55
# ----------- Rework job  60
# ----------- Rework job  67
# ----------- Rework job  138
# ----------- Rework job  189
# There are 373 jobs left
# ----------- Rework job  153
# There are 304 jobs left
# ----------- Rework job  141
# There are 235 jobs left
# There are 165 jobs left
# ----------- Rework job  251
# ----------- Rework job  367
# There are 97 jobs left
# ----------- Rework job  293
# There are 28 jobs left
# ----------- Rework job  386
# ====== Done ======
# 516650.0
# ----- B
# Testing
# MB
#  [[], [(19440.0, 3120.0, 'normal')], [], [], [], [], [], [], [], [], [], [(22440.0, 4320.0, 'critical')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  119
# There are 368 jobs left
# There are 298 jobs left
# ----------- Rework job  316
# ----------- Rework job  149
# ----------- Rework job  90
# ----------- Rework job  306
# ----------- Rework job  340
# ----------- Rework job  190
# There are 234 jobs left
# There are 164 jobs left
# ----------- Rework job  375
# ----------- Rework job  241
# ----------- Rework job  319
# There are 97 jobs left
# ----------- Rework job  324
# ----------- Rework job  308
# There are 29 jobs left
# ----------- Rework job  411
# ====== Done ======
# 371200.0
# ----- C
# Testing
# MB
#  [[], [], [], [], [], [], [], [(24840.0, 1140.0, 'critical')], [], [], [(26220.0, 1320.0, 'critical')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  139
# ----------- Rework job  217
# ----------- Rework job  40
# There are 370 jobs left
# ----------- Rework job  150
# ----------- Rework job  80
# ----------- Rework job  130
# ----------- Rework job  203
# There are 304 jobs left
# ----------- Rework job  131
# ----------- Rework job  304
# There are 236 jobs left
# ----------- Rework job  413
# ----------- Rework job  153
# ----------- Rework job  120
# ----------- Rework job  352
# There are 170 jobs left
# ----------- Rework job  254
# ----------- Rework job  401
# There are 102 jobs left
# There are 32 jobs left
# ----------- Rework job  381
# ----------- Rework job  299
# ====== Done ======
# 654260.0
# ----------- valid11
# ----- A
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [], [], [(23760.0, 1920.0, 'critical')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  266
# ----------- Rework job  313
# There are 977 jobs left
# There are 907 jobs left
# ----------- Rework job  357
# There are 838 jobs left
# There are 768 jobs left
# ----------- Rework job  423
# ----------- Rework job  272
# There are 700 jobs left
# There are 630 jobs left
# There are 560 jobs left
# There are 490 jobs left
# ----------- Rework job  957
# There are 421 jobs left
# ----------- Rework job  987
# ----------- Rework job  998
# ----------- Rework job  1003
# ----------- Rework job  1010
# There are 355 jobs left
# There are 285 jobs left
# There are 215 jobs left
# ----------- Rework job  232
# ----------- Rework job  350
# There are 147 jobs left
# ----------- Rework job  339
# There are 78 jobs left
# ----------- Rework job  305
# There are 9 jobs left
# ----------- Random MB at time 23760 on machine [10] at Ope [2, 249]
# ====== Done ======
# 1366230.0
# ----- B
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  94
# ----------- Rework job  386
# There are 977 jobs left
# There are 907 jobs left
# ----------- Rework job  653
# ----------- Rework job  256
# There are 839 jobs left
# ----------- Rework job  62
# ----------- Rework job  895
# ----------- Rework job  13
# ----------- Rework job  727
# There are 773 jobs left
# ----------- Rework job  549
# ----------- Rework job  755
# There are 705 jobs left
# ----------- Rework job  239
# There are 636 jobs left
# ----------- Rework job  821
# There are 567 jobs left
# ----------- Rework job  875
# ----------- Rework job  1024
# ----------- Rework job  465
# There are 500 jobs left
# There are 430 jobs left
# There are 360 jobs left
# ----------- Rework job  277
# There are 291 jobs left
# ----------- Rework job  961
# ----------- Rework job  326
# ----------- Rework job  3
# ----------- Rework job  422
# ----------- Rework job  438
# There are 226 jobs left
# ----------- Rework job  382
# ----------- Rework job  201
# There are 158 jobs left
# ----------- Rework job  967
# ----------- Rework job  6
# ----------- Rework job  119
# There are 91 jobs left
# ----------- Rework job  92
# There are 22 jobs left
# ----------- Rework job  104
# ====== Done ======
# 1262500.0
# ----- C
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [], [], [(31320.0, 10560.0, 'critical')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  326
# ----------- Rework job  104
# ----------- Rework job  174
# ----------- Rework job  159
# There are 979 jobs left
# ----------- Rework job  364
# There are 910 jobs left
# ----------- Rework job  659
# ----------- Rework job  674
# There are 842 jobs left
# ----------- Rework job  518
# There are 773 jobs left
# ----------- Rework job  788
# There are 704 jobs left
# ----------- Rework job  54
# There are 635 jobs left
# ----------- Rework job  901
# There are 566 jobs left
# ----------- Rework job  621
# There are 497 jobs left
# ----------- Rework job  466
# ----------- Rework job  128
# There are 429 jobs left
# There are 359 jobs left
# ----------- Rework job  455
# ----------- Rework job  449
# There are 291 jobs left
# ----------- Rework job  620
# There are 222 jobs left
# There are 152 jobs left
# ----------- Rework job  289
# There are 83 jobs left
# ----------- Rework job  902
# ----------- Rework job  191
# ----------- Rework job  100
# ----------- Rework job  97
# ----------- Rework job  113
# There are 18 jobs left
# ----------- Rework job  933
# ----------- Random MB at time 31320 on machine [10] at Ope [2, 83]
# ====== Done ======
# 745930.0
# ----------- valid12
# ----- A
# Testing
# MB
#  [[], [(7500.0, 5460.0, 'normal'), (23760.0, 1080.0, 'normal')], [], [], [], [], [], [], [], [(780.0, 120.0, 'critical')], [], [], [(19860.0, 1800.0, 'critical')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  80
# ----------- Rework job  46
# There are 377 jobs left
# There are 307 jobs left
# ----------- Rework job  299
# There are 238 jobs left
# ----------- Rework job  433
# There are 169 jobs left
# ----------- Rework job  12
# There are 100 jobs left
# ----------- Rework job  369
# There are 31 jobs left
# ----------- Rework job  250
# ----------- Random MB at time 13450.0 on machine [9] at Ope [2, 173]
# ====== Done ======
# 833070.0
# ----- B
# Testing
# MB
#  [[], [(31680.0, 3360.0, 'normal')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  40
# ----------- Rework job  79
# ----------- Rework job  57
# ----------- Rework job  100
# There are 379 jobs left
# ----------- Rework job  259
# ----------- Rework job  261
# There are 311 jobs left
# ----------- Rework job  405
# ----------- Rework job  377
# There are 243 jobs left
# ----------- Rework job  327
# ----------- Rework job  312
# ----------- Rework job  406
# There are 176 jobs left
# ----------- Rework job  284
# ----------- Rework job  58
# ----------- Rework job  243
# ----------- Rework job  35
# ----------- Rework job  103
# ----------- Rework job  390
# ----------- Rework job  193
# There are 113 jobs left
# ----------- Rework job  422
# ----------- Rework job  396
# ----------- Rework job  328
# There are 46 jobs left
# ====== Done ======
# 989310.0
# ----- C
# Testing
# MB
#  [[], [], [], [], [], [], [(30780.0, 5640.0, 'critical')], [(18960.0, 960.0, 'critical')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# There are 375 jobs left
# ----------- Rework job  227
# ----------- Rework job  279
# ----------- Rework job  293
# There are 308 jobs left
# ----------- Rework job  103
# ----------- Rework job  182
# There are 240 jobs left
# ----------- Rework job  426
# ----------- Rework job  249
# ----------- Rework job  340
# ----------- Rework job  191
# ----------- Rework job  394
# There are 175 jobs left
# There are 105 jobs left
# ----------- Rework job  7
# ----------- Rework job  371
# ----------- Rework job  318
# ----------- Rework job  77
# ----------- Rework job  268
# There are 40 jobs left
# ====== Done ======
# 605120.0
# ----------- valid13
# ----- A
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [], [], [(33240.0, 1140.0, 'critical')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  118
# ----------- Rework job  74
# ----------- Rework job  77
# There are 213 jobs left
# ----------- Rework job  194
# There are 144 jobs left
# There are 74 jobs left
# ----------- Rework job  22
# There are 5 jobs left
# ====== Done ======
# 138620.0
# ----- B
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# There are 210 jobs left
# ----------- Rework job  159
# ----------- Rework job  47
# ----------- Rework job  263
# ----------- Rework job  266
# There are 144 jobs left
# ----------- Rework job  102
# ----------- Rework job  240
# There are 76 jobs left
# ----------- Rework job  162
# There are 7 jobs left
# ====== Done ======
# 226230.0
# ----- C
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [(27240.0, 3000.0, 'critical')], [(20460.0, 300.0, 'critical')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  196
# There are 211 jobs left
# ----------- Rework job  60
# ----------- Rework job  81
# There are 143 jobs left
# ----------- Rework job  110
# ----------- Rework job  95
# ----------- Rework job  269
# There are 76 jobs left
# ----------- Rework job  97
# There are 7 jobs left
# ====== Done ======
# 383020.0
# ----------- valid14
# ----- A
# Testing
# MB
#  [[], [], [], [], [], [], [], [(27900.0, 360.0, 'critical')], [], [(24240.0, 540.0, 'critical')], [(12120.0, 3420.0, 'critical')], [], [], [], [], [], [(5700.0, 6060.0, 'normal')], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  353
# ----------- Rework job  360
# There are 384 jobs left
# ----------- Rework job  236
# ----------- Rework job  308
# There are 316 jobs left
# ----------- Rework job  232
# There are 247 jobs left
# ----------- Rework job  13
# ----------- Rework job  51
# There are 179 jobs left
# ----------- Rework job  259
# ----------- Rework job  329
# There are 111 jobs left
# ----------- Rework job  117
# ----------- Rework job  218
# ----------- Rework job  176
# ----------- Rework job  149
# ----------- Rework job  310
# There are 46 jobs left
# ----------- Rework job  177
# ----------- Rework job  44
# ----------- Rework job  3
# ----------- Rework job  10
# ====== Done ======
# 582600.0
# ----- B
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [], [], [(24900.0, 180.0, 'critical')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  256
# ----------- Rework job  251
# There are 384 jobs left
# ----------- Rework job  260
# There are 315 jobs left
# ----------- Rework job  193
# ----------- Rework job  116
# ----------- Rework job  426
# There are 248 jobs left
# There are 178 jobs left
# ----------- Rework job  70
# There are 109 jobs left
# ----------- Rework job  184
# ----------- Rework job  117
# There are 41 jobs left
# ----------- Rework job  98
# ----------- Rework job  75
# ====== Done ======
# 670070.0
# ----- C
# Testing
# MB
#  [[], [(4680.0, 6900.0, 'normal')], [], [], [], [], [], [], [], [], [(29220.0, 480.0, 'critical')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  353
# ----------- Rework job  392
# There are 384 jobs left
# ----------- Rework job  417
# ----------- Rework job  34
# There are 316 jobs left
# ----------- Rework job  159
# ----------- Rework job  26
# ----------- Rework job  281
# ----------- Rework job  433
# There are 250 jobs left
# ----------- Rework job  94
# There are 181 jobs left
# ----------- Rework job  0
# There are 112 jobs left
# ----------- Rework job  185
# There are 43 jobs left
# ====== Done ======
# 359940.0
# ----------- valid15
# ----- A
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [], [], [(6540.0, 300.0, 'critical'), (10080.0, 7380.0, 'critical')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  146
# ----------- Rework job  288
# ----------- Rework job  253
# ----------- Rework job  468
# There are 444 jobs left
# ----------- Rework job  317
# There are 375 jobs left
# ----------- Rework job  372
# ----------- Rework job  503
# ----------- Rework job  41
# ----------- Rework job  479
# ----------- Rework job  73
# There are 310 jobs left
# ----------- Rework job  377
# There are 241 jobs left
# ----------- Rework job  407
# There are 172 jobs left
# ----------- Rework job  111
# ----------- Rework job  13
# ----------- Rework job  458
# ----------- Rework job  287
# There are 106 jobs left
# ----------- Rework job  85
# ----------- Rework job  167
# ----------- Rework job  280
# ----------- Rework job  190
# There are 40 jobs left
# ----------- Rework job  465
# ----------- Rework job  386
# ----------- Random MB at time 30910.0 on machine [10] at Ope [2, 45]
# ====== Done ======
# 5250010.0
# ----- B
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [(13140.0, 540.0, 'critical')], [], [], [(24060.0, 4980.0, 'critical')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Rework job  139
# ----------- Rework job  145
# There are 442 jobs left
# ----------- Rework job  418
# ----------- Rework job  58
# ----------- Rework job  424
# ----------- Rework job  226
# ----------- Rework job  362
# There are 377 jobs left
# ----------- Rework job  322
# There are 308 jobs left
# ----------- Rework job  291
# ----------- Rework job  183
# ----------- Rework job  492
# There are 241 jobs left
# ----------- Rework job  116
# ----------- Rework job  76
# ----------- Rework job  11
# ----------- Rework job  7
# There are 175 jobs left
# ----------- Rework job  470
# ----------- Rework job  318
# ----------- Rework job  33
# ----------- Rework job  171
# There are 109 jobs left
# ----------- Rework job  83
# There are 40 jobs left
# ----------- Rework job  507
# ----------- Random MB at time 28330.0 on machine [8] at Ope [2, 60]
# ====== Done ======
# 3282990.0
# ----- C
# Testing
# MB
#  [[], [], [], [], [], [], [], [], [], [], [], [], [(8220.0, 5760.0, 'critical')], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ----------- Random MB at time 8220 on machine [12] at Ope [2, 332]
# ----------- Rework job  358
# ----------- Rework job  375
# There are 442 jobs left
# ----------- Rework job  165
# ----------- Rework job  342
# ----------- Rework job  84
# There are 375 jobs left
# ----------- Rework job  239
# There are 306 jobs left
# ----------- Rework job  444
# There are 237 jobs left
# There are 167 jobs left
# ----------- Rework job  297
# ----------- Rework job  106
# There are 99 jobs left
# There are 29 jobs left
# ====== Done ======
# 4145560.0

# %%
df = pd.DataFrame(results)
file_name = f"VALIDATION/LuoDDQN_RS.xlsx"
df.to_excel(file_name, index=False)
