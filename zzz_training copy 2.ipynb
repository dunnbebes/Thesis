# %%
import numpy as np
import pandas as pd
import sys
import pickle
from env_action.environment import FJSP_under_uncertainties_Env

directory           = 'SMALL'
planning_horizon    = 480*60
critical_machines   = {5, 6, 7, 8, 9, 10, 11, 12, 13, 21, 22, 26, 27}
ReworkProbability   = 0.03
maxtime             = 10
PopSize             = 80
WeibullDistribution = pd.read_excel('DATA/DataMaster.xlsx', sheet_name='Distribution')
K                   = 30
maxJob              = 1320
maxOpe              = 5760

# Default setting
reward_ratio            = 0.99
learning_rate           = 1e-4
explore_fraction_phase1 = 0.8
explore_fraction_phase2 = 0.5
explore_fraction_phase3 = 0.3
num_timestep_phase1     = 2000
num_timestep_phase2     = 6000
num_timestep_phase3     = 12000


purpose = 'testing-self-attention'

#------- EXPLORATION FRACTION------------
if purpose == "SA low exploration fraction":
    explore_fraction_phase1 = 0.7
    explore_fraction_phase2 = 0.4
    explore_fraction_phase3 = 0.2
if purpose == "SA high exploration fraction":
    explore_fraction_phase1 = 0.9
    explore_fraction_phase2 = 0.6
    explore_fraction_phase3 = 0.4

#---------- REWARD RATIO-------------
if purpose == "SA reward 0.90":
    reward_ratio = 0.90
if purpose == "SA reward 0.80":
    reward_ratio = 0.80

#---------- CURRICULUM -------------
if purpose == "SA learning distribution smaller":
    num_timestep_phase1     = 1000
    num_timestep_phase2     = 2000
    num_timestep_phase3     = 5000
if purpose == "SA learning distribution more in ealier":
    num_timestep_phase1     = 10000
    num_timestep_phase2     = 7000
    num_timestep_phase3     = 6000

#-----------LEARNING RATE ---------
if purpose == "SA learning rate 1e-3 ":
    learning_rate = 1e-3
if purpose == "SA learning rate 1e-5 ":
    learning_rate = 1e-5

# %%
import gymnasium as gym
import matplotlib.pyplot as plt
from stable_baselines3.common.vec_env     import DummyVecEnv
from stable_baselines3.common.callbacks   import BaseCallback, EvalCallback
from stable_baselines3.common.monitor     import Monitor
from stable_baselines3.common.env_checker import check_env 

with open('DATA/SMALL/pickle_instances_480.pkl', 'rb') as f:
    instances = pickle.load(f)
with open('DATA/SMALL/pickle_scenarios_480.pkl', 'rb') as f:
    scenarios = pickle.load(f)

env1 = FJSP_under_uncertainties_Env(True , True , instances, scenarios, K, WeibullDistribution, critical_machines, 
                                    ReworkProbability, planning_horizon, PopSize, maxtime, maxJob, maxOpe, reward_ratio)
env2 = FJSP_under_uncertainties_Env(True , False, instances, scenarios, K, WeibullDistribution, critical_machines, 
                                    ReworkProbability, planning_horizon, PopSize, maxtime, maxJob, maxOpe, reward_ratio)
env3 = FJSP_under_uncertainties_Env(False, False, instances, scenarios, K, WeibullDistribution, critical_machines, 
                                    ReworkProbability, planning_horizon, PopSize, maxtime, maxJob, maxOpe, reward_ratio)

# check_env(env1)
# obs = env1.reset(seed=42)
# print("Observation:", obs)

# episodes = 2
# for episode in range(episodes):
# 	done = False
# 	obs = env1.reset()
# 	while done == False:#not done:
# 		random_action = env1.action_space.sample()
# 		obs, reward, done, truncated, info = env1.step(random_action)
# 		print('reward', reward)
# Out:
# 2024-07-14 07:20:29.020582: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from stable_baselines3 import DQN
import os
import datetime
import pandas as pd
from stable_baselines3.common.callbacks import BaseCallback

action_list            = ["GA", "TS", 
                          "LFOH", "LAPH", "LAP_LFO", 
                          "LFOH_TS", "LAPH_TS", "LFOH_GA", "LAPH_GA",
                          "CDR1", "CDR2", "CDR3", "CDR5", "CDR6",
                          "RCRS"]
                          
# Create directories for models and logs
current_time = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")


models_dir = f"models/{purpose}_{current_time}"
logdir = f"logs/{purpose}_{current_time}"
log_training_txt_dir = "log_training_txt"
log_training_excel_dir = "log_training_excel"

if not os.path.exists(models_dir):
    os.makedirs(models_dir)
if not os.path.exists(logdir):
    os.makedirs(logdir)
if not os.path.exists(log_training_txt_dir):
    os.makedirs(log_training_txt_dir)
if not os.path.exists(log_training_excel_dir):
    os.makedirs(log_training_excel_dir)

# Generate unique file names based on current time
log_file          = os.path.join(log_training_txt_dir,   f"training_{purpose}_{current_time}.txt")
excel_file        = os.path.join(log_training_excel_dir, f"training_{purpose}_{current_time}.xlsx")
action_count_file = os.path.join(log_training_txt_dir,   f"action_count_{purpose}_{current_time}.txt")
action_excel_file = os.path.join(log_training_excel_dir, f"action_count_{purpose}_{current_time}.xlsx")

# Define the custom callback -------------------------------------------------------------
class CustomCallback(BaseCallback):
    def __init__(self, log_dir, excel_file, txt_file, action_count_file, action_excel_file, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.log_dir = log_dir
        self.excel_file = excel_file
        self.txt_file = txt_file
        self.action_count_file = action_count_file
        self.action_excel_file = action_excel_file
        self.logs = []
        self.episode_rewards = []
        self.action_counts = {}
        self.episode_start = True

    def _on_training_start(self) -> None:
        # Initialize action counts
        self.action_counts = {action: 0 for action in action_list}

    def _on_step(self) -> bool:
        if self.episode_start:
            self.episode_rewards.append(0)
            self.episode_start = False

        # Record reward for the current step
        reward = self.locals['rewards'][0]
        self.episode_rewards[-1] += reward

        # Increment action count
        action = self.locals.get('actions', None)
        if action is not None:
            action_name = action_list[action[0]]
            self.action_counts[action_name] += 1
        
        return True

    def _on_rollout_end(self) -> None:
        # Called at the end of each episode
        sum_reward   = self.episode_rewards[-1] if self.episode_rewards else 0
        tardiness    = self.training_env.get_attr('unwrapped')[0].all_Tard
        
        self.logger.record('train/episode_reward',   sum_reward)
        self.logger.record('train/actual_tardiness', tardiness)
        

        self.logs.append({
            'episode': len(self.episode_rewards),
            'sum_reward': sum_reward,
            'tardiness': tardiness
        })

        self.episode_start = True

    
    def _on_training_end(self) -> None:
        # Save logs to Excel
        df = pd.DataFrame(self.logs)
        df.to_excel(self.excel_file, index=False)

        action_df = pd.DataFrame(list(self.action_counts.items()), columns=['Action', 'Count'])
        action_df.to_excel(self.action_excel_file, index=False)

        # Save logs to text file
        with open(self.txt_file, 'w') as f:
            f.write(df.to_string(index=False))
        with open(self.action_count_file, 'w') as f:
            f.write(action_df.to_string(index=False))

# Create the callback
callback = CustomCallback(log_dir=logdir, 
                          excel_file=excel_file,
                          txt_file=log_file,
                          action_count_file=action_count_file,
                          action_excel_file=action_excel_file,
                          verbose=1)

import torch
import torch.nn as nn
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
from stable_baselines3.dqn.policies import DQNPolicy

class SelfAttention(nn.Module):
    def __init__(self, input_dim, hidden_dim):
        super(SelfAttention, self).__init__()
        self.query = nn.Linear(input_dim, hidden_dim)
        self.key = nn.Linear(input_dim, hidden_dim)
        self.value = nn.Linear(input_dim, hidden_dim)
        self.scale = 1.0 / (hidden_dim ** 0.5)

    def forward(self, x):
        query = self.query(x)
        key = self.key(x)
        value = self.value(x)
        scores = torch.matmul(query, key.transpose(-2, -1)) * self.scale
        attn = torch.softmax(scores, dim=-1)
        context = torch.matmul(attn, value)
        return context

class CustomFeatureExtractor(BaseFeaturesExtractor):
    def __init__(self, observation_space, features_dim=256):
        super(CustomFeatureExtractor, self).__init__(observation_space, features_dim)
        input_dim = observation_space.shape[0]
        hidden_dim = 64  # Matching SB3's default hidden dimension for DQN
        self.attention = SelfAttention(input_dim, hidden_dim)
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, features_dim)

    def forward(self, observations):
        x = self.attention(observations)
        x = torch.relu(self.fc1(x)) 
        x = torch.relu(self.fc2(x))
        return x

class CustomDQNPolicy(DQNPolicy):
    def __init__(self, *args, **kwargs):
        super(CustomDQNPolicy, self).__init__(
            *args,
            features_extractor_class=CustomFeatureExtractor,
            features_extractor_kwargs=dict(features_dim=256),  # Matching SB3's default features_dim for DQN
            **kwargs
        )

# Initialize the DQN model
model_path = os.path.join(models_dir, f"DQN_.zip")
model_phase1 = DQN(CustomDQNPolicy, 
                    env1, 
                    verbose=1, 
                    tensorboard_log=logdir, 
                    train_freq=(1,"episode"),
                    target_update_interval  = 2000,
                    exploration_initial_eps = 0.80, 
                    exploration_final_eps   = 0.30, 
                    exploration_fraction    = explore_fraction_phase1, 
                    )

# Phase 1 training
model_phase1.learn(total_timesteps=num_timestep_phase1, 
                    reset_num_timesteps=True, 
                    tb_log_name="DQN",
                    log_interval=3,
                    callback=callback
                    )
model_phase1.save(model_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# urgent
# Logging to logs/testing-self-attention_2024-07-14_07-20-31/DQN_1
# Method selection:                    TS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR5
# Method selection:                    LFOH
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LFOH
# long
# urgent
# Method selection:                    CDR5
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    LAPH
# long
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH
# long
# urgent
# Method selection:                    LAP_LFO
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LAPH
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LAP_LFO
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | -21.3    |
# |    exploration_rate | 0.787    |
# | time/               |          |
# |    episodes         | 3        |
# |    fps              | 0        |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 41       |
# | train/              |          |
# |    actual_tardiness | 2.34e+05 |
# |    episode_reward   | -8.48    |
# ----------------------------------
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH-TS
# Method selection:                    CDR1
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    LAP_LFO
# long
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LFOH-TS
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR5
# urgent
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# long
# urgent
# Method selection:                    LAP_LFO
# long
# urgent
# Method selection:                    CDR6
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | -51.9    |
# |    exploration_rate | 0.775    |
# | time/               |          |
# |    episodes         | 6        |
# |    fps              | 0        |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 80       |
# | train/              |          |
# |    actual_tardiness | 2.59e+06 |
# |    episode_reward   | -96.9    |
# ----------------------------------
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LFOH-TS
# long
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    CDR5
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH
# long
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR1
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR1
# long
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    LAP_LFO
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | -49      |
# |    exploration_rate | 0.763    |
# | time/               |          |
# |    episodes         | 9        |
# |    fps              | 0        |
# |    time_elapsed     | 128      |
# |    total_timesteps  | 119      |
# | train/              |          |
# |    actual_tardiness | 2.05e+06 |
# |    episode_reward   | -74.8    |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.1      |
# |    n_updates        | 1        |
# ----------------------------------
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    LAPH
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LFOH-GA
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | -50.7    |
# |    exploration_rate | 0.751    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 0        |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 158      |
# | train/              |          |
# |    actual_tardiness | 1.5e+06  |
# |    episode_reward   | -55.1    |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.69     |
# |    n_updates        | 4        |
# ----------------------------------
# Method selection:                    TS
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LFOH-TS
# long
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    LAPH
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    LFOH
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | -50.4    |
# |    exploration_rate | 0.738    |
# | time/               |          |
# |    episodes         | 15       |
# |    fps              | 0        |
# |    time_elapsed     | 210      |
# |    total_timesteps  | 197      |
# | train/              |          |
# |    actual_tardiness | 1.01e+06 |
# |    episode_reward   | -37.7    |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.34     |
# |    n_updates        | 7        |
# ----------------------------------
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    LFOH-TS
# urgent
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LFOH
# long
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    CDR2
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-TS
# long
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR1
# urgent
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    CDR2
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | -51.1    |
# |    exploration_rate | 0.727    |
# | time/               |          |
# |    episodes         | 18       |
# |    fps              | 0        |
# |    time_elapsed     | 252      |
# |    total_timesteps  | 235      |
# | train/              |          |
# |    actual_tardiness | 2.06e+06 |
# |    episode_reward   | -76.5    |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.63     |
# |    n_updates        | 10       |
# ----------------------------------
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LFOH-GA
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    CDR1
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    CDR5
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | -53.5    |
# |    exploration_rate | 0.714    |
# | time/               |          |
# |    episodes         | 21       |
# |    fps              | 0        |
# |    time_elapsed     | 349      |
# |    total_timesteps  | 274      |
# | train/              |          |
# |    actual_tardiness | 3.37e+06 |
# |    episode_reward   | -125     |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.2      |
# |    n_updates        | 13       |
# ----------------------------------
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    LAPH
# long
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LFOH-TS
# long
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    GA
# urgent
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    LAP_LFO
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR1
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | -50.5    |
# |    exploration_rate | 0.703    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 0        |
# |    time_elapsed     | 438      |
# |    total_timesteps  | 312      |
# | train/              |          |
# |    actual_tardiness | 8.16e+05 |
# |    episode_reward   | -29.9    |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.17     |
# |    n_updates        | 16       |
# ----------------------------------
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    GA
# urgent
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR5
# long
# urgent
# Method selection:                    CDR5
# long
# urgent
# Method selection:                    CDR2
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | -50      |
# |    exploration_rate | 0.691    |
# | time/               |          |
# |    episodes         | 27       |
# |    fps              | 0        |
# |    time_elapsed     | 519      |
# |    total_timesteps  | 350      |
# | train/              |          |
# |    actual_tardiness | 2.69e+06 |
# |    episode_reward   | -99.2    |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.19     |
# |    n_updates        | 19       |
# ----------------------------------
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    TS
# urgent
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LFOH-GA
# long
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    LFOH
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR1
# long
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    GA
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | -47.2    |
# |    exploration_rate | 0.679    |
# | time/               |          |
# |    episodes         | 30       |
# |    fps              | 0        |
# |    time_elapsed     | 604      |
# |    total_timesteps  | 388      |
# | train/              |          |
# |    actual_tardiness | 2.64e+05 |
# |    episode_reward   | -9.59    |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.85     |
# |    n_updates        | 22       |
# ----------------------------------
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    LAPH
# long
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR5
# urgent
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | -45.9    |
# |    exploration_rate | 0.667    |
# | time/               |          |
# |    episodes         | 33       |
# |    fps              | 0        |
# |    time_elapsed     | 654      |
# |    total_timesteps  | 426      |
# | train/              |          |
# |    actual_tardiness | 6.48e+05 |
# |    episode_reward   | -24.3    |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.04     |
# |    n_updates        | 25       |
# ----------------------------------
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR1
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    CDR6
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | -46.4    |
# |    exploration_rate | 0.655    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 0        |
# |    time_elapsed     | 709      |
# |    total_timesteps  | 465      |
# | train/              |          |
# |    actual_tardiness | 1.37e+06 |
# |    episode_reward   | -50.7    |
# |    learning_rate    | 0.0001   |
# |    loss             | 3        |
# |    n_updates        | 28       |
# ----------------------------------
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAPH
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR5
# long
# urgent
# Method selection:                    LAPH
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    LFOH
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAP_LFO
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    TS
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | -44.3    |
# |    exploration_rate | 0.643    |
# | time/               |          |
# |    episodes         | 39       |
# |    fps              | 0        |
# |    time_elapsed     | 776      |
# |    total_timesteps  | 504      |
# | train/              |          |
# |    actual_tardiness | 2.88e+05 |
# |    episode_reward   | -10.6    |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.43     |
# |    n_updates        | 31       |
# ----------------------------------
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR1
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    CDR1
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    CDR1
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    LFOH-TS
# long
# urgent
# Method selection:                    TS
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | -47.5    |
# |    exploration_rate | 0.63     |
# | time/               |          |
# |    episodes         | 42       |
# |    fps              | 0        |
# |    time_elapsed     | 819      |
# |    total_timesteps  | 543      |
# | train/              |          |
# |    actual_tardiness | 1.2e+06  |
# |    episode_reward   | -43.4    |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.19     |
# |    n_updates        | 34       |
# ----------------------------------
# Method selection:                    CDR1
# urgent
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR5
# urgent
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    CDR5
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR5
# long
# urgent
# Method selection:                    CDR1
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | -46.7    |
# |    exploration_rate | 0.619    |
# | time/               |          |
# |    episodes         | 45       |
# |    fps              | 0        |
# |    time_elapsed     | 882      |
# |    total_timesteps  | 580      |
# | train/              |          |
# |    actual_tardiness | 9.45e+05 |
# |    episode_reward   | -35.5    |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.78     |
# |    n_updates        | 37       |
# ----------------------------------
# Method selection:                    TS
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    TS
# urgent
# urgent
# Method selection:                    LFOH-GA
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    LAPH
# long
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAP_LFO
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | -44.4    |
# |    exploration_rate | 0.607    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 0        |
# |    time_elapsed     | 933      |
# |    total_timesteps  | 618      |
# | train/              |          |
# |    actual_tardiness | 2.73e+05 |
# |    episode_reward   | -10.3    |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.79     |
# |    n_updates        | 40       |
# ----------------------------------
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR1
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR5
# long
# urgent
# Method selection:                    CDR1
# long
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    CDR5
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | -43.8    |
# |    exploration_rate | 0.595    |
# | time/               |          |
# |    episodes         | 51       |
# |    fps              | 0        |
# |    time_elapsed     | 989      |
# |    total_timesteps  | 657      |
# | train/              |          |
# |    actual_tardiness | 1.95e+06 |
# |    episode_reward   | -71.7    |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.41     |
# |    n_updates        | 43       |
# ----------------------------------
# Method selection:                    TS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    LFOH-GA
# long
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    LAP_LFO
# long
# urgent
# Method selection:                    TS
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | -41.8    |
# |    exploration_rate | 0.583    |
# | time/               |          |
# |    episodes         | 54       |
# |    fps              | 0        |
# |    time_elapsed     | 1046     |
# |    total_timesteps  | 696      |
# | train/              |          |
# |    actual_tardiness | 1.43e+05 |
# |    episode_reward   | -5.12    |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.26     |
# |    n_updates        | 46       |
# ----------------------------------
# Method selection:                    TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    LAP_LFO
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    CDR5
# long
# urgent
# Method selection:                    TS
# urgent
# ----------------------------------
# | rollout/            |          |
# ...
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LFOH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LFOH-TS
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | -25.4    |
# |    exploration_rate | 0.3      |
# | time/               |          |
# |    episodes         | 138      |
# |    fps              | 0        |
# |    time_elapsed     | 2344     |
# |    total_timesteps  | 1784     |
# | train/              |          |
# |    actual_tardiness | 2.02e+05 |
# |    episode_reward   | -7.43    |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.7      |
# |    n_updates        | 130      |
# ----------------------------------
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR1
# long
# urgent
# Method selection:                    LAPH
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | -24.2    |
# |    exploration_rate | 0.3      |
# | time/               |          |
# |    episodes         | 141      |
# |    fps              | 0        |
# |    time_elapsed     | 2424     |
# |    total_timesteps  | 1823     |
# | train/              |          |
# |    actual_tardiness | 6.46e+05 |
# |    episode_reward   | -23      |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.61     |
# |    n_updates        | 133      |
# ----------------------------------
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH
# long
# urgent
# Method selection:                    LAPH-GA
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    CDR5
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | -22.6    |
# |    exploration_rate | 0.3      |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 0        |
# |    time_elapsed     | 2475     |
# |    total_timesteps  | 1862     |
# | train/              |          |
# |    actual_tardiness | 2.43e+05 |
# |    episode_reward   | -9       |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.09     |
# |    n_updates        | 136      |
# ----------------------------------
# Method selection:                    LFOH
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | -22.9    |
# |    exploration_rate | 0.3      |
# | time/               |          |
# |    episodes         | 147      |
# |    fps              | 0        |
# |    time_elapsed     | 2551     |
# |    total_timesteps  | 1901     |
# | train/              |          |
# |    actual_tardiness | 1.59e+05 |
# |    episode_reward   | -5.82    |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.96     |
# |    n_updates        | 139      |
# ----------------------------------
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LFOH
# long
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LFOH-GA
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | -22.8    |
# |    exploration_rate | 0.3      |
# | time/               |          |
# |    episodes         | 150      |
# |    fps              | 0        |
# |    time_elapsed     | 2618     |
# |    total_timesteps  | 1940     |
# | train/              |          |
# |    actual_tardiness | 7.54e+05 |
# |    episode_reward   | -29.1    |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.36     |
# |    n_updates        | 142      |
# ----------------------------------
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR5
# urgent
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LFOH-GA
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | -23.2    |
# |    exploration_rate | 0.3      |
# | time/               |          |
# |    episodes         | 153      |
# |    fps              | 0        |
# |    time_elapsed     | 2680     |
# |    total_timesteps  | 1978     |
# | train/              |          |
# |    actual_tardiness | 1.53e+05 |
# |    episode_reward   | -5.52    |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.63     |
# |    n_updates        | 145      |
# ----------------------------------
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    CDR5
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    CDR5
# urgent

# %%
# Phase 2 training
model_phase2 = DQN.load(model_path, 
                        env=env2, 
                        verbose=1, 
                        tensorboard_log=logdir, 
                        train_freq=(1, "episode"),
                        target_update_interval=2000
                        # , exploration_initial_eps=0.50, 
                        # exploration_final_eps=0.10, 
                        # exploration_fraction=explore_fraction_phase2
                        )

model_phase2.exploration_schedule.initial_p = 0.5
model_phase2.exploration_schedule.final_p = 0.1
model_phase2.exploration_schedule.schedule_timesteps = explore_fraction_phase2 * num_timestep_phase2


model_phase2.learn(total_timesteps=num_timestep_phase2, 
                   tb_log_name="DQN_phase2",
                   log_interval=3,
                   reset_num_timesteps=False,
                   callback=callback)
model_phase2.save(model_path)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs/testing-self-attention_2024-07-14_07-20-31/DQN_phase2_0
# Method selection:                    TS
# Method selection:                    LAPH-TS
# Method selection:                    LAPH-TS
# long
# Method selection:                    CDR1
# Method selection:                    LAPH-TS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | -23.3    |
# |    exploration_rate | 0.299    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 3        |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2009     |
# ----------------------------------
# Method selection:                    CDR6
# Method selection:                    CDR5
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-TS
# Method selection:                    LAPH-TS
# Method selection:                    LAPH-TS
# Method selection:                    LFOH
# long
# Method selection:                    LAPH-TS
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    LFOH-TS
# long
# Method selection:                    CDR6
# Method selection:                    LAPH-TS
# Method selection:                    LAPH-TS
# Method selection:                    LAPH-TS
# Method selection:                    LAPH-TS
# long
# Method selection:                    RCRS
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-TS
# Method selection:                    CDR3
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    CDR3
# long
# Method selection:                    LAPH-TS
# Method selection:                    CDR6
# Method selection:                    LAP_LFO
# Method selection:                    LAPH-TS
# long
# Method selection:                    CDR3
# Method selection:                    LAPH-TS
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | -22.6    |
# |    exploration_rate | 0.296    |
# | time/               |          |
# |    episodes         | 159      |
# |    fps              | 2        |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 2040     |
# | train/              |          |
# |    actual_tardiness | 20       |
# |    episode_reward   | -0.00791 |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00721  |
# |    n_updates        | 151      |
# ----------------------------------
# Method selection:                    LAPH-TS
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    LAPH-TS
# Method selection:                    LAPH-TS
# Method selection:                    LAPH
# Method selection:                    LAPH
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    CDR2
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    LFOH-GA
# Method selection:                    LAPH-TS
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-TS
# Method selection:                    LAPH-TS
# long
# Method selection:                    TS
# Method selection:                    LAPH-TS
# Method selection:                    LAPH-TS
# Method selection:                    CDR5
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    CDR6
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.7     |
# |    ep_rew_mean      | -22.1    |
# |    exploration_rate | 0.293    |
# | time/               |          |
# |    episodes         | 162      |
# |    fps              | 1        |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 2068     |
# | train/              |          |
# |    actual_tardiness | 2.42e+03 |
# |    episode_reward   | -0.085   |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0566   |
# |    n_updates        | 154      |
# ----------------------------------
# Method selection:                    LAPH-TS
# Method selection:                    LAPH-TS
# Method selection:                    LAPH-TS
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-TS
# Method selection:                    LAPH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LAPH-TS
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-TS
# Method selection:                    LAPH-TS
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-TS
# Method selection:                    LAPH-TS
# Method selection:                    LAPH-TS
# Method selection:                    LAPH-TS
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    TS
# Method selection:                    LAPH-TS
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-TS
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.6     |
# |    ep_rew_mean      | -21.3    |
# |    exploration_rate | 0.29     |
# | time/               |          |
# |    episodes         | 165      |
# |    fps              | 2        |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 2099     |
# | train/              |          |
# |    actual_tardiness | 0        |
# |    episode_reward   | 0        |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0361   |
# |    n_updates        | 157      |
# ----------------------------------
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    CDR1
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.5     |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.287    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1        |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 2129     |
# | train/              |          |
# |    actual_tardiness | 6.09e+05 |
# |    episode_reward   | -21.8    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0321   |
# |    n_updates        | 160      |
# ----------------------------------
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LAPH-TS
# Method selection:                    TS
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    CDR2
# long
# Method selection:                    LAPH-TS
# Method selection:                    LFOH
# Method selection:                    TS
# Method selection:                    LAPH-GA
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-TS
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.4     |
# |    ep_rew_mean      | -19.9    |
# |    exploration_rate | 0.285    |
# | time/               |          |
# |    episodes         | 171      |
# |    fps              | 1        |
# |    time_elapsed     | 124      |
# |    total_timesteps  | 2154     |
# | train/              |          |
# |    actual_tardiness | 3.86e+05 |
# |    episode_reward   | -13.6    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.585    |
# |    n_updates        | 163      |
# ----------------------------------
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR1
# long
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    LAPH-TS
# Method selection:                    CDR5
# Method selection:                    LAPH-TS
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-GA
# Method selection:                    LAPH-TS
# long
# Method selection:                    GA
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    CDR5
# long
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAPH-TS
# long
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    LAPH-TS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | -19.7    |
# |    exploration_rate | 0.282    |
# | time/               |          |
# |    episodes         | 174      |
# |    fps              | 1        |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 2184     |
# | train/              |          |
# |    actual_tardiness | 5.26e+04 |
# |    episode_reward   | -1.92    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.136    |
# |    n_updates        | 166      |
# ----------------------------------
# Method selection:                    LFOH-GA
# Method selection:                    CDR2
# long
# Method selection:                    GA
# Method selection:                    TS
# Method selection:                    GA
# Method selection:                    RCRS
# long
# Method selection:                    GA
# long
# Method selection:                    TS
# long
# Method selection:                    LAPH-TS
# Method selection:                    GA
# Method selection:                    CDR5
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    CDR2
# long
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    LAPH-TS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | -19.6    |
# |    exploration_rate | 0.279    |
# | time/               |          |
# |    episodes         | 177      |
# |    fps              | 0        |
# |    time_elapsed     | 233      |
# |    total_timesteps  | 2211     |
# | train/              |          |
# |    actual_tardiness | 9.84e+04 |
# |    episode_reward   | -3.94    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0599   |
# |    n_updates        | 169      |
# ----------------------------------
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    LFOH-GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    GA
# Method selection:                    LFOH-GA
# long
# Method selection:                    CDR2
# long
# Method selection:                    LFOH
# long
# Method selection:                    GA
# long
# Method selection:                    CDR2
# long
# Method selection:                    GA
# Method selection:                    CDR2
# long
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    LFOH-TS
# long
# Method selection:                    RCRS
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    GA
# long
# Method selection:                    CDR6
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | -19.2    |
# |    exploration_rate | 0.276    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 0        |
# |    time_elapsed     | 349      |
# |    total_timesteps  | 2244     |
# | train/              |          |
# |    actual_tardiness | 1.31e+05 |
# |    episode_reward   | -4.9     |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.843    |
# |    n_updates        | 172      |
# ----------------------------------
# Method selection:                    LFOH-GA
# Method selection:                    GA
# Method selection:                    LAPH
# Method selection:                    GA
# Method selection:                    CDR2
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    CDR6
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    CDR2
# long
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    LAP_LFO
# long
# Method selection:                    LAP_LFO
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    CDR2
# long
# Method selection:                    CDR5
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    LAP_LFO
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | -19      |
# |    exploration_rate | 0.273    |
# | time/               |          |
# |    episodes         | 183      |
# |    fps              | 0        |
# |    time_elapsed     | 450      |
# |    total_timesteps  | 2276     |
# | train/              |          |
# |    actual_tardiness | 8.48e+04 |
# |    episode_reward   | -3.48    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.611    |
# |    n_updates        | 175      |
# ----------------------------------
# Method selection:                    LFOH-GA
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    CDR1
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    CDR1
# long
# Method selection:                    LAP_LFO
# long
# Method selection:                    GA
# long
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | -18.9    |
# |    exploration_rate | 0.27     |
# | time/               |          |
# |    episodes         | 186      |
# |    fps              | 0        |
# |    time_elapsed     | 564      |
# |    total_timesteps  | 2304     |
# | train/              |          |
# |    actual_tardiness | 2.06e+05 |
# |    episode_reward   | -7.43    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.197    |
# |    n_updates        | 178      |
# ----------------------------------
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    GA
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    LFOH
# Method selection:                    CDR2
# long
# Method selection:                    GA
# long
# Method selection:                    LFOH-TS
# long
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    CDR1
# Method selection:                    GA
# long
# Method selection:                    GA
# long
# Method selection:                    LFOH
# long
# Method selection:                    GA
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | -18.6    |
# |    exploration_rate | 0.267    |
# | time/               |          |
# |    episodes         | 189      |
# |    fps              | 0        |
# |    time_elapsed     | 676      |
# |    total_timesteps  | 2329     |
# | train/              |          |
# |    actual_tardiness | 4.06e+05 |
# |    episode_reward   | -15      |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.265    |
# |    n_updates        | 181      |
# ----------------------------------
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    LFOH
# long
# Method selection:                    RCRS
# Method selection:                    GA
# long
# Method selection:                    CDR6
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.6     |
# |    ep_rew_mean      | -17.3    |
# |    exploration_rate | 0.265    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 0        |
# |    time_elapsed     | 779      |
# |    total_timesteps  | 2353     |
# | train/              |          |
# |    actual_tardiness | 2.67e+05 |
# |    episode_reward   | -9.58    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.401    |
# |    n_updates        | 184      |
# ----------------------------------
# Method selection:                    GA
# Method selection:                    GA
# Method selection:                    CDR6
# long
# Method selection:                    GA
# long
# Method selection:                    LFOH-TS
# Method selection:                    CDR5
# Method selection:                    RCRS
# long
# Method selection:                    GA
# long
# Method selection:                    RCRS
# Method selection:                    GA
# Method selection:                    TS
# Method selection:                    CDR6
# long
# Method selection:                    GA
# Method selection:                    GA
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    GA
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    LAP_LFO
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.6     |
# |    ep_rew_mean      | -16.8    |
# |    exploration_rate | 0.262    |
# | time/               |          |
# |    episodes         | 195      |
# |    fps              | 0        |
# |    time_elapsed     | 858      |
# |    total_timesteps  | 2385     |
# | train/              |          |
# |    actual_tardiness | 7.3e+04  |
# |    episode_reward   | -2.87    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.386    |
# |    n_updates        | 187      |
# ----------------------------------
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    LFOH-GA
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    TS
# long
# long
# Method selection:                    LFOH-GA
# long
# Method selection:                    RCRS
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | -16.2    |
# |    exploration_rate | 0.258    |
# | time/               |          |
# |    episodes         | 198      |
# |    fps              | 0        |
# |    time_elapsed     | 860      |
# |    total_timesteps  | 2417     |
# | train/              |          |
# |    actual_tardiness | 0        |
# |    episode_reward   | 0        |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.204    |
# |    n_updates        | 190      |
# ----------------------------------
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    CDR5
# long
# urgent
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    CDR6
# long
# Method selection:                    CDR2
# long
# Method selection:                    CDR5
# Method selection:                    LFOH-GA
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    LFOH-GA
# long
# Method selection:                    LAPH-GA
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# Method selection:                    CDR1
# long
# Method selection:                    CDR2
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | -15.9    |
# |    exploration_rate | 0.255    |
# | time/               |          |
# |    episodes         | 201      |
# |    fps              | 0        |
# |    time_elapsed     | 868      |
# |    total_timesteps  | 2448     |
# | train/              |          |
# |    actual_tardiness | 2.75e+04 |
# |    episode_reward   | -1.31    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.123    |
# |    n_updates        | 193      |
# ----------------------------------
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    LFOH-GA
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    LAPH-TS
# long
# Method selection:                    RCRS
# long
# Method selection:                    CDR1
# long
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    LAPH-TS
# long
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | -15.8    |
# |    exploration_rate | 0.253    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 0        |
# |    time_elapsed     | 870      |
# |    total_timesteps  | 2468     |
# | train/              |          |
# |    actual_tardiness | 0        |
# |    episode_reward   | 0        |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0814   |
# |    n_updates        | 196      |
# ----------------------------------
# Method selection:                    RCRS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    CDR6
# long
# Method selection:                    RCRS
# long
# Method selection:                    TS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    LFOH-GA
# long
# Method selection:                    RCRS
# long
# Method selection:                    LFOH-GA
# Method selection:                    LFOH-TS
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | -14.4    |
# |    exploration_rate | 0.25     |
# | time/               |          |
# |    episodes         | 207      |
# |    fps              | 0        |
# |    time_elapsed     | 885      |
# |    total_timesteps  | 2500     |
# | train/              |          |
# |    actual_tardiness | 7.81e+03 |
# |    episode_reward   | -0.62    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.208    |
# |    n_updates        | 199      |
# ----------------------------------
# Method selection:                    RCRS
# Method selection:                    LAPH-GA
# Method selection:                    RCRS
# Method selection:                    GA
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    LFOH-TS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    LFOH
# Method selection:                    LAPH
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    LAPH-GA
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    LAPH
# long
# Method selection:                    RCRS
# Method selection:                    LFOH-GA
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    LFOH
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    CDR6
# long
# Method selection:                    LFOH-TS
# long
# Method selection:                    RCRS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | -13.8    |
# |    exploration_rate | 0.247    |
# | time/               |          |
# |    episodes         | 210      |
# |    fps              | 0        |
# |    time_elapsed     | 899      |
# |    total_timesteps  | 2533     |
# | train/              |          |
# |    actual_tardiness | 0        |
# |    episode_reward   | 0        |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.615    |
# |    n_updates        | 202      |
# ----------------------------------
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    LFOH-GA
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    LAP_LFO
# Method selection:                    CDR3
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# Method selection:                    RCRS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | -12.5    |
# |    exploration_rate | 0.244    |
# | time/               |          |
# |    episodes         | 213      |
# |    fps              | 0        |
# |    time_elapsed     | 901      |
# |    total_timesteps  | 2557     |
# | train/              |          |
# |    actual_tardiness | 0        |
# |    episode_reward   | 0        |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0603   |
# |    n_updates        | 205      |
# ----------------------------------
# Method selection:                    RCRS
# Method selection:                    CDR3
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    LAP_LFO
# long
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    CDR3
# long
# Method selection:                    LAP_LFO
# long
# Method selection:                    LFOH-GA
# long
# Method selection:                    LAPH
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | -12      |
# |    exploration_rate | 0.241    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 0        |
# |    time_elapsed     | 906      |
# |    total_timesteps  | 2587     |
# | train/              |          |
# |    actual_tardiness | 0        |
# |    episode_reward   | 0        |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.258    |
# |    n_updates        | 208      |
# ----------------------------------
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# Method selection:                    CDR6
# long
# Method selection:                    CDR3
# long
# Method selection:                    RCRS
# long
# Method selection:                    CDR1
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    CDR1
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    LAPH
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# Method selection:                    CDR1
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | -10.5    |
# |    exploration_rate | 0.238    |
# | time/               |          |
# |    episodes         | 219      |
# |    fps              | 0        |
# |    time_elapsed     | 909      |
# |    total_timesteps  | 2623     |
# | train/              |          |
# |    actual_tardiness | 1.01e+05 |
# |    episode_reward   | -3.68    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.418    |
# |    n_updates        | 211      |
# ----------------------------------
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    CDR1
# long
# Method selection:                    LAP_LFO
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    CDR1
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    LAPH-GA
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    LFOH-TS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | -9.06    |
# |    exploration_rate | 0.235    |
# | time/               |          |
# |    episodes         | 222      |
# |    fps              | 0        |
# |    time_elapsed     | 911      |
# |    total_timesteps  | 2648     |
# | train/              |          |
# |    actual_tardiness | 0        |
# |    episode_reward   | 0        |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.229    |
# |    n_updates        | 214      |
# ----------------------------------
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    LAPH
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    LAPH
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    LFOH
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    CDR3
# long
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    CDR6
# long
# urgent
# Method selection:                    RCRS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | -8.67    |
# |    exploration_rate | 0.232    |
# | time/               |          |
# |    episodes         | 225      |
# |    fps              | 0        |
# |    time_elapsed     | 927      |
# |    total_timesteps  | 2680     |
# | train/              |          |
# |    actual_tardiness | 0        |
# |    episode_reward   | 0        |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.712    |
# |    n_updates        | 217      |
# ----------------------------------
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    GA
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    CDR6
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    CDR2
# long
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    RCRS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | -8.28    |
# |    exploration_rate | 0.229    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 0        |
# |    time_elapsed     | 939      |
# |    total_timesteps  | 2708     |
# | train/              |          |
# |    actual_tardiness | 1.48e+05 |
# |    episode_reward   | -5.26    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.375    |
# |    n_updates        | 220      |
# ----------------------------------
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# Method selection:                    LFOH-TS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# long
# Method selection:                    RCRS
# ...
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.4      |
# |    ep_rew_mean      | -3.46    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 765      |
# |    fps              | 1        |
# |    time_elapsed     | 4250     |
# |    total_timesteps  | 7779     |
# | train/              |          |
# |    actual_tardiness | 0        |
# |    episode_reward   | 0        |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0573   |
# |    n_updates        | 757      |
# ----------------------------------
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    LAP_LFO
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.32     |
# |    ep_rew_mean      | -3.46    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 768      |
# |    fps              | 1        |
# |    time_elapsed     | 4261     |
# |    total_timesteps  | 7799     |
# | train/              |          |
# |    actual_tardiness | 3.61e+04 |
# |    episode_reward   | -1.27    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.203    |
# |    n_updates        | 760      |
# ----------------------------------
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    CDR3
# long
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LFOH-GA
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    CDR2
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.31     |
# |    ep_rew_mean      | -3.5     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 771      |
# |    fps              | 1        |
# |    time_elapsed     | 4278     |
# |    total_timesteps  | 7831     |
# | train/              |          |
# |    actual_tardiness | 0        |
# |    episode_reward   | 0        |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0307   |
# |    n_updates        | 763      |
# ----------------------------------
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    CDR6
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.36     |
# |    ep_rew_mean      | -3.25    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 774      |
# |    fps              | 1        |
# |    time_elapsed     | 4284     |
# |    total_timesteps  | 7856     |
# | train/              |          |
# |    actual_tardiness | 2.42e+03 |
# |    episode_reward   | -0.0852  |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.454    |
# |    n_updates        | 766      |
# ----------------------------------
# Method selection:                    TS
# Method selection:                    CDR1
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    GA
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    LAP_LFO
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    CDR1
# long
# Method selection:                    CDR1
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    LFOH-TS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.4      |
# |    ep_rew_mean      | -3.25    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 777      |
# |    fps              | 1        |
# |    time_elapsed     | 4295     |
# |    total_timesteps  | 7889     |
# | train/              |          |
# |    actual_tardiness | 2.62e+03 |
# |    episode_reward   | -0.0921  |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.04     |
# |    n_updates        | 769      |
# ----------------------------------
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    LAPH-GA
# Method selection:                    TS
# long
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LAP_LFO
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    LFOH-TS
# long
# Method selection:                    CDR5
# long
# Method selection:                    CDR1
# long
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.35     |
# |    ep_rew_mean      | -3.21    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 1        |
# |    time_elapsed     | 4302     |
# |    total_timesteps  | 7913     |
# | train/              |          |
# |    actual_tardiness | 2.42e+03 |
# |    episode_reward   | -0.0851  |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.261    |
# |    n_updates        | 772      |
# ----------------------------------
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    LFOH-GA
# Method selection:                    TS
# long
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.42     |
# |    ep_rew_mean      | -3.26    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 783      |
# |    fps              | 1        |
# |    time_elapsed     | 4344     |
# |    total_timesteps  | 7945     |
# | train/              |          |
# |    actual_tardiness | 1.38e+05 |
# |    episode_reward   | -5.24    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0157   |
# |    n_updates        | 775      |
# ----------------------------------
# Method selection:                    CDR3
# long
# Method selection:                    TS
# Method selection:                    CDR2
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.38     |
# |    ep_rew_mean      | -3.27    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 786      |
# |    fps              | 1        |
# |    time_elapsed     | 4361     |
# |    total_timesteps  | 7973     |
# | train/              |          |
# |    actual_tardiness | 1.32e+03 |
# |    episode_reward   | -0.0464  |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.108    |
# |    n_updates        | 778      |
# ----------------------------------
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    CDR3
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    LAPH
# long
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.39     |
# |    ep_rew_mean      | -3.35    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 789      |
# |    fps              | 1        |
# |    time_elapsed     | 4384     |
# |    total_timesteps  | 8006     |
# | train/              |          |
# |    actual_tardiness | 2.24e+05 |
# |    episode_reward   | -7.9     |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.344    |
# |    n_updates        | 781      |
# ----------------------------------

# %%
# Phase 3 training
from stable_baselines3 import DQN
model_phase3 = DQN.load(model_path, 
                        env=env3, 
                        verbose=1, 
                        tensorboard_log=logdir, 
                        train_freq=(1, "episode"),
                        target_update_interval=2000
                        # ,exploration_initial_eps=0.20, 
                        # exploration_final_eps=0.1, 
                        # exploration_fraction=explore_fraction_phase3
                        )

model_phase3.exploration_schedule.initial_p = 0.20
model_phase3.exploration_schedule.final_p = 0.05
model_phase3.exploration_schedule.schedule_timesteps = explore_fraction_phase3 * 10000

model_phase3.learn(total_timesteps=10000, 
                   tb_log_name="DQN_phase3",
                   log_interval=3,
                   reset_num_timesteps=False,
                   callback=callback)
model_phase3.save(model_path)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs/testing-self-attention_2024-07-14_07-20-31/DQN_phase3_0
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    CDR3
# Method selection:                    TS
# Method selection:                    LFOH-TS
# Method selection:                    CDR5
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LFOH-GA
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    GA
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LFOH-TS
# Method selection:                    RCRS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | -3.47    |
# |    exploration_rate | 0.139    |
# | time/               |          |
# |    episodes         | 792      |
# |    fps              | 0        |
# |    time_elapsed     | 189      |
# |    total_timesteps  | 8118     |
# | train/              |          |
# |    actual_tardiness | 6.05e+05 |
# |    episode_reward   | -24.2    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.158    |
# |    n_updates        | 784      |
# ----------------------------------
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    CDR5
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LAPH-GA
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    CDR5
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    TS
# Method selection:                    TS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | -3.35    |
# |    exploration_rate | 0.136    |
# | time/               |          |
# |    episodes         | 795      |
# |    fps              | 0        |
# |    time_elapsed     | 258      |
# |    total_timesteps  | 8190     |
# | train/              |          |
# |    actual_tardiness | 2.45e+05 |
# |    episode_reward   | -8.97    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0922   |
# |    n_updates        | 787      |
# ----------------------------------
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LFOH-GA
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LAP_LFO
# Method selection:                    LAP_LFO
# Method selection:                    LFOH
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    CDR1
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LFOH
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LFOH-TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LAPH
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LFOH
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    LAPH-TS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | -3.33    |
# |    exploration_rate | 0.132    |
# | time/               |          |
# |    episodes         | 798      |
# |    fps              | 0        |
# |    time_elapsed     | 307      |
# |    total_timesteps  | 8273     |
# | train/              |          |
# |    actual_tardiness | 250      |
# |    episode_reward   | -0.00972 |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0452   |
# |    n_updates        | 790      |
# ----------------------------------
# Method selection:                    LAPH-GA
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LAPH-TS
# Method selection:                    RCRS
# Method selection:                    TS
# Method selection:                    CDR1
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    RCRS
# Method selection:                    TS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LFOH
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    TS
# Method selection:                    RCRS
# Method selection:                    RCRS
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.6     |
# |    ep_rew_mean      | -3.49    |
# |    exploration_rate | 0.129    |
# | time/               |          |
# |    episodes         | 801      |
# |    fps              | 0        |
# |    time_elapsed     | 360      |
# |    total_timesteps  | 8346     |
# | train/              |          |
# |    actual_tardiness | 4.24e+05 |
# |    episode_reward   | -16.2    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0415   |
# |    n_updates        | 793      |
# ----------------------------------
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LFOH-TS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    LAPH
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    LFOH-GA
# Method selection:                    LFOH
# Method selection:                    RCRS
# Method selection:                    CDR5
# Method selection:                    LFOH-TS
# Method selection:                    GA
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    LFOH
# Method selection:                    RCRS
# Method selection:                    LAPH
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | -2.76    |
# |    exploration_rate | 0.127    |
# | time/               |          |
# |    episodes         | 804      |
# |    fps              | 1        |
# |    time_elapsed     | 384      |
# |    total_timesteps  | 8397     |
# | train/              |          |
# |    actual_tardiness | 1.43e+03 |
# |    episode_reward   | -0.0532  |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0325   |
# |    n_updates        | 796      |
# ----------------------------------
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    CDR6
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    CDR1
# Method selection:                    LFOH-TS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | -2.84    |
# |    exploration_rate | 0.125    |
# | time/               |          |
# |    episodes         | 807      |
# |    fps              | 1        |
# |    time_elapsed     | 390      |
# |    total_timesteps  | 8445     |
# | train/              |          |
# |    actual_tardiness | 1.21e+05 |
# |    episode_reward   | -4.34    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.131    |
# |    n_updates        | 799      |
# ----------------------------------
# Method selection:                    LFOH-TS
# Method selection:                    CDR1
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    LFOH-TS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    LAPH
# Method selection:                    LAPH
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    GA
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    CDR1
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    CDR1
# Method selection:                    RCRS
# Method selection:                    CDR6
# Method selection:                    CDR5
# Method selection:                    LAP_LFO
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | -2.86    |
# |    exploration_rate | 0.122    |
# | time/               |          |
# |    episodes         | 810      |
# |    fps              | 1        |
# |    time_elapsed     | 397      |
# |    total_timesteps  | 8499     |
# | train/              |          |
# |    actual_tardiness | 1.9e+05  |
# |    episode_reward   | -6.95    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.142    |
# |    n_updates        | 802      |
# ----------------------------------
# Method selection:                    CDR3
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    GA
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    RCRS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    CDR2
# Method selection:                    LFOH-TS
# Method selection:                    LAPH
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    CDR6
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LAPH-GA
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    CDR6
# Method selection:                    LFOH-TS
# Method selection:                    LAP_LFO
# Method selection:                    LAP_LFO
# Method selection:                    LAP_LFO
# Method selection:                    LAP_LFO
# Method selection:                    LAP_LFO
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    CDR6
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | -3.03    |
# |    exploration_rate | 0.118    |
# | time/               |          |
# |    episodes         | 813      |
# |    fps              | 1        |
# |    time_elapsed     | 472      |
# |    total_timesteps  | 8590     |
# | train/              |          |
# |    actual_tardiness | 3.98e+05 |
# |    episode_reward   | -17.1    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.069    |
# |    n_updates        | 805      |
# ----------------------------------
# Method selection:                    TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LAPH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LAPH-GA
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    CDR2
# Method selection:                    LFOH-TS
# Method selection:                    LAPH-GA
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    CDR3
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LAP_LFO
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    CDR1
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LAPH-GA
# Method selection:                    LAPH
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    CDR5
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    CDR2
# Method selection:                    LAPH-GA
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-GA
# Method selection:                    LAPH
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LAPH-TS
# Method selection:                    TS
# Method selection:                    GA
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    CDR2
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LAP_LFO
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | -3.05    |
# |    exploration_rate | 0.113    |
# | time/               |          |
# |    episodes         | 816      |
# |    fps              | 1        |
# |    time_elapsed     | 580      |
# |    total_timesteps  | 8700     |
# | train/              |          |
# |    actual_tardiness | 0        |
# |    episode_reward   | 0        |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0707   |
# |    n_updates        | 808      |
# ----------------------------------
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAPH-TS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAPH
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | -3.53    |
# |    exploration_rate | 0.109    |
# | time/               |          |
# |    episodes         | 819      |
# |    fps              | 1        |
# |    time_elapsed     | 613      |
# |    total_timesteps  | 8794     |
# | train/              |          |
# |    actual_tardiness | 5.13e+05 |
# |    episode_reward   | -19.9    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0261   |
# |    n_updates        | 811      |
# ----------------------------------
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR3
# urgent
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LAP_LFO
# urgent
# Method selection:                    LAP_LFO
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# Method selection:                    LFOH-TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    LAP_LFO
# long
# Method selection:                    LAP_LFO
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LFOH-TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    LAP_LFO
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | -3.71    |
# |    exploration_rate | 0.107    |
# | time/               |          |
# |    episodes         | 822      |
# |    fps              | 1        |
# |    time_elapsed     | 699      |
# |    total_timesteps  | 8849     |
# | train/              |          |
# |    actual_tardiness | 3.01e+03 |
# |    episode_reward   | -0.106   |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0375   |
# |    n_updates        | 814      |
# ----------------------------------
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# Method selection:                    LFOH-TS
# long
# Method selection:                    LFOH-TS
# long
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# long
# urgent
# Method selection:                    RCRS
# long
# urgent
# Method selection:                    LFOH-TS
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | -3.64    |
# |    exploration_rate | 0.106    |
# | time/               |          |
# |    episodes         | 825      |
# |    fps              | 1        |
# |    time_elapsed     | 709      |
# |    total_timesteps  | 8867     |
# | train/              |          |
# |    actual_tardiness | 0        |
# |    episode_reward   | 0        |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.218    |
# |    n_updates        | 817      |
# ----------------------------------
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# long
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# long
# urgent
# Method selection:                    LFOH-TS
# long
# urgent
# Method selection:                    LFOH-TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# urgent
# Method selection:                    LFOH-TS
# long
# urgent
# Method selection:                    LFOH-TS
# long
# urgent
# Method selection:                    LFOH-TS
# long
# urgent
# Method selection:                    LFOH-TS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | -3.57    |
# |    exploration_rate | 0.105    |
# | time/               |          |
# |    episodes         | 828      |
# |    fps              | 1        |
# |    time_elapsed     | 731      |
# |    total_timesteps  | 8893     |
# | train/              |          |
# |    actual_tardiness | 3.65e+03 |
# |    episode_reward   | -0.129   |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0954   |
# |    n_updates        | 820      |
# ----------------------------------
# Method selection:                    TS
# Method selection:                    TS
# ...
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LFOH
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LFOH-TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LFOH-GA
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    CDR6
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    CDR3
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LFOH-TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | -4.54    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 1401     |
# |    fps              | 1        |
# |    time_elapsed     | 8046     |
# |    total_timesteps  | 17791    |
# | train/              |          |
# |    actual_tardiness | 0        |
# |    episode_reward   | 0        |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0741   |
# |    n_updates        | 1393     |
# ----------------------------------
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    CDR3
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    CDR6
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    CDR2
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LAP_LFO
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LFOH-GA
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LAPH-TS
# Method selection:                    TS
# Method selection:                    GA
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    RCRS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | -4.59    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 1404     |
# |    fps              | 1        |
# |    time_elapsed     | 8103     |
# |    total_timesteps  | 17898    |
# | train/              |          |
# |    actual_tardiness | 2.56e+04 |
# |    episode_reward   | -0.969   |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.03     |
# |    n_updates        | 1396     |
# ----------------------------------
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    CDR6
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LFOH-GA
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LAPH-GA
# Method selection:                    CDR2
# Method selection:                    TS
# Method selection:                    LAP_LFO
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LFOH
# Method selection:                    TS
# Method selection:                    TS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    RCRS
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR3
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR5
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    CDR2
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LAP_LFO
# Method selection:                    GA
# Method selection:                    TS
# Method selection:                    TS
# urgent
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | -4.79    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 1407     |
# |    fps              | 1        |
# |    time_elapsed     | 8193     |
# |    total_timesteps  | 17982    |
# | train/              |          |
# |    actual_tardiness | 5.72e+05 |
# |    episode_reward   | -22.1    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0676   |
# |    n_updates        | 1399     |
# ----------------------------------
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LFOH-GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAP_LFO
# Method selection:                    TS
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LAPH-GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR2
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS

# %%
with open('VALIDATION/SMALL/pickle_valid_instances_480.pkl', 'rb') as f:
    valid_instances = pickle.load(f)
with open('VALIDATION/SMALL/pickle_valid_scenarios_480.pkl', 'rb') as f:
    valid_scenarios = pickle.load(f)

results = []
method = 'predictive-reactive DQN'
InstanceList = [f'valid{i+1}' for i in range(12)]
ScenarioList = ['A', 'B', 'C']

valenv = FJSP_under_uncertainties_Env(False, False, valid_instances, valid_scenarios, K, WeibullDistribution, critical_machines, 
                                      ReworkProbability, planning_horizon, PopSize, maxtime, maxJob, maxOpe, reward_ratio)


model = DQN.load(model_path, env=valenv)

for instance_id in InstanceList:
    print("-----------", instance_id)
    for scenario_id in ScenarioList:
        print("-----", scenario_id)
        # Reset the environment with the new dataset
        valenv.reset(test=True, 
                  datatest=instance_id, 
                  scenariotest=scenario_id)
        
        obs, info = valenv.reset()
        done = False
        
        while not done:
            action, _states = model.predict(obs)
            obs, reward, done, truncated, info = valenv.step(action)
        
        tardiness = valenv.calc_tardiness()
    
        results.append({
                        'Method'    : method,
                        'InstanceID': instance_id,
                        'ScenarioID': scenario_id,
                        'Tardiness' : tardiness
                        })

df = pd.DataFrame(results)
file_name = f"VALIDATION/{purpose}.xlsx"
df.to_excel(file_name, index=False)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------- valid1
# ----- A
# urgent
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LFOH
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# ----- B
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    GA
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# ----- C
# Method selection:                    LAPH-GA
# Method selection:                    LFOH
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    CDR3
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# ----------- valid2
# ----- A
# urgent
# Method selection:                    CDR6
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# ----- B
# Method selection:                    TS
# Method selection:                    LAPH
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# ----- C
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# ----------- valid3
# ----- A
# urgent
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    CDR5
# Method selection:                    LAPH
# long
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# ----- B
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# ----- C
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# ----------- valid4
# ----- A
# urgent
# urgent
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    LFOH-TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# ----- B
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# ----- C
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    CDR6
# ----------- valid5
# ----- A
# urgent
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LAPH-TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LFOH-TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# ----- B
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    CDR1
# Method selection:                    CDR3
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LAPH-GA
# ----- C
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LFOH-GA
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LAPH
# Method selection:                    TS
# Method selection:                    TS
# ----------- valid6
# ----- A
# urgent
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    CDR5
# Method selection:                    TS
# Method selection:                    LFOH-TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LAP_LFO
# Method selection:                    TS
# Method selection:                    TS
# ----- B
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    CDR5
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LAPH-GA
# ----- C
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR1
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    RCRS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# ----------- valid7
# ----- A
# long
# urgent
# urgent
# Method selection:                    GA
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    CDR6
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# ----- B
# long
# Method selection:                    TS
# Method selection:                    LAP_LFO
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LFOH
# Method selection:                    GA
# Method selection:                    TS
# ----- C
# long
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    CDR3
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LAPH
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# ----------- valid8
# ----- A
# urgent
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LAPH-TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# ----- B
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# ----- C
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# ----------- valid9
# ----- A
# urgent
# Method selection:                    TS
# Method selection:                    LAPH
# Method selection:                    TS
# Method selection:                    LAPH-TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LAPH
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# ----- B
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    LFOH
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# urgent
# Method selection:                    TS
# ----- C
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    LFOH
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# ----------- valid10
# ----- A
# urgent
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# ----- B
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    RCRS
# Method selection:                    TS
# ----- C
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    CDR5
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# Method selection:                    TS
# ----------- valid11
# ----- A
# urgent
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# ----- B
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# ----- C
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# ----------- valid12
# ----- A
# long
# Method selection:                    TS
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# long
# Method selection:                    TS
# ----- B
# long
# urgent
# Method selection:                    LFOH-GA
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# ----- C
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
# long
# urgent
# Method selection:                    TS
