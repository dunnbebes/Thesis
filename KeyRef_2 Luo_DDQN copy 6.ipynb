# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'

import tensorflow as tf

import gymnasium as gym
import pickle

from VALIDATION.KeyRef_2.KeyRef_2_env2 import Luo_DDQN_env
from stable_baselines3.common.callbacks   import BaseCallback
from stable_baselines3.common.env_checker import check_env

import datetime
import pandas as pd
from stable_baselines3.common.callbacks import BaseCallback

K = 30
planning_horizon        = 480*60
ReworkProbability       = 0.03
critical_machines       = {5, 6, 7, 8, 9, 10, 11, 12, 13, 21, 22, 26, 27}


purpose                 = "_tight_duedate_JA_MB"
directory               = 'DATA/TIGHT_DUEDATE'

tight_duedate_setting   = True if "tight_duedate" in purpose else False
JA_only_setting         = True if "JA_only" in purpose else False

WeibullDistribution     = pd.read_excel('DATA/DataMaster.xlsx', sheet_name='Distribution')

with open('DATA/ComponentMaster.pkl', 'rb') as f:
    master = pickle.load(f)
with open(f'{directory}_VALIDATION/pickle_valid_scenarios_480.pkl', 'rb') as f:
    valid_scenarios = pickle.load(f)

env = Luo_DDQN_env(K, planning_horizon, ReworkProbability, valid_scenarios, WeibullDistribution, critical_machines,
			  	 master, tight_duedate_setting, JA_only_setting, directory)

# check_env(env)
# obs = env.reset(seed=42,
#                 test=True, 
#                 datatest="valid2", 
#                 scenariotest="A")
            
# print("Observation:", obs)

# episodes = 1
# for episode in range(episodes):
# 	done = False
# 	obs = env.reset(test=True, 
#                     datatest="valid2", 
#                     scenariotest="A")
# 	while done == False: #not done:
# 		random_action = env.action_space.sample()
# 		obs, reward, done, truncated, info = env.step(random_action)

# %%
action_list = ["CDR1", "CDR2", "CDR3", "CDR4", "CDR5", "CDR6"]
                          
# Create directories for models and logs
current_time = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
models_dir = f"models/LuoDDQN{purpose}-{current_time}"
logdir = f"logs/LuoDDQN{purpose}-{current_time}"
log_training_txt_dir = "keyref2_log_training_txt"
log_training_excel_dir = "keyref2_log_training_excel"

if not os.path.exists(models_dir):
    os.makedirs(models_dir)
if not os.path.exists(logdir):
    os.makedirs(logdir)
if not os.path.exists(log_training_txt_dir):
    os.makedirs(log_training_txt_dir)
if not os.path.exists(log_training_excel_dir):
    os.makedirs(log_training_excel_dir)

# Generate unique file names based on current time
log_file          = os.path.join(log_training_txt_dir,   f"training_keyref2.txt")
excel_file        = os.path.join(log_training_excel_dir, f"training_keyref2.xlsx")
action_count_file = os.path.join(log_training_txt_dir,   f"action_count_keyref2.txt")
action_excel_file = os.path.join(log_training_excel_dir, f"action_count_keyref2.xlsx")

# Define the custom callback -------------------------------------------------------------
class CustomCallback(BaseCallback):
    def __init__(self, log_dir, excel_file, txt_file, action_count_file, action_excel_file, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.log_dir = log_dir
        self.excel_file = excel_file
        self.txt_file = txt_file
        self.action_count_file = action_count_file
        self.action_excel_file = action_excel_file
        self.logs = []
        self.episode_rewards = []
        self.action_counts = {}
        self.episode_start = True

    def _on_training_start(self) -> None:
        # Initialize action counts
        self.action_counts = {action: 0 for action in action_list}

    def _on_step(self) -> bool:
        if self.episode_start:
            self.episode_rewards.append(0)
            self.episode_start = False

        # Record reward for the current step
        reward = self.locals['rewards'][0]
        self.episode_rewards[-1] += reward

        # Increment action count
        action = self.locals.get('actions', None)
        if action is not None:
            action_name = action_list[action[0]]
            self.action_counts[action_name] += 1
            
        return True

    def _on_rollout_end(self) -> None:
        # Called at the end of each episode
        sum_reward   = self.episode_rewards[-1] if self.episode_rewards else 0
        
        self.logger.record('train/episode_reward',   sum_reward)
        self.logs.append({
            'sum_reward': sum_reward,
        })

        self.episode_start = True

    
    def _on_training_end(self) -> None:
        # Save logs to Excel
        df = pd.DataFrame(self.logs)
        df.to_excel(self.excel_file, index=False)

        action_df = pd.DataFrame(list(self.action_counts.items()), columns=['Action', 'Count'])
        action_df.to_excel(self.action_excel_file, index=False)

        # Save logs to text file
        with open(self.txt_file, 'w') as f:
            f.write(df.to_string(index=False))
        with open(self.action_count_file, 'w') as f:
            f.write(action_df.to_string(index=False))

# Create the callback
callback = CustomCallback(log_dir=logdir, 
                          excel_file=excel_file,
                          txt_file=log_file,
                          action_count_file=action_count_file,
                          action_excel_file=action_excel_file,
                          verbose=1)

import torch
import torch.nn as nn
import torch.nn.functional as F
from gymnasium import spaces
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
from stable_baselines3 import DQN

class CustomFeaturesExtractor(BaseFeaturesExtractor):
    """
    Custom feature extractor for DQN.
    
    :param observation_space: (spaces.Box)
    """
    def __init__(self, observation_space: spaces.Box):
        super(CustomFeaturesExtractor, self).__init__(observation_space, features_dim=6)  # Output features_dim matches last layer's output
        n_input_nodes = observation_space.shape[0]
        self.fc1 = nn.Linear(n_input_nodes, 30)
        self.fc2 = nn.Linear(30, 30)
        self.fc3 = nn.Linear(30, 30)
        self.fc4 = nn.Linear(30, 30)
        self.fc5 = nn.Linear(30, 30)
        self.fc6 = nn.Linear(30, 6)  # Output layer with 6 nodes

    def forward(self, observations: torch.Tensor) -> torch.Tensor:
        x = F.tanh(self.fc1(observations))
        x = F.tanh(self.fc2(x))
        x = F.tanh(self.fc3(x))
        x = F.tanh(self.fc4(x))
        x = F.tanh(self.fc5(x))
        x = self.fc6(x)  # Output layer
        return x

# Custom DQN class to implement soft target update
class CustomDQN(DQN):
    def __init__(self, *args, tau=0.01, **kwargs):
        super(CustomDQN, self).__init__(*args, **kwargs)
        self.tau = tau

    def train(self, gradient_steps, batch_size=100):
        # Train for gradient_steps
        for gradient_step in range(gradient_steps):
            # Sample replay buffer
            replay_data = self.replay_buffer.sample(batch_size, env=self._vec_normalize_env)
            
            # Mix online and target networks
            target_q_values = self.q_net_target(replay_data.next_observations)
            next_q_values, _ = target_q_values.max(dim=1)
            next_q_values = next_q_values.reshape(-1, 1)

            # Compute the target for the Q function
            target_q = replay_data.rewards + (1 - replay_data.dones) * self.gamma * next_q_values

            # Get current Q estimates
            current_q = self.q_net(replay_data.observations).gather(1, replay_data.actions.long())

            # Compute Huber loss (less sensitive to outliers)
            loss = F.smooth_l1_loss(current_q, target_q)

            # Optimize the model
            self.policy.optimizer.zero_grad()
            loss.backward()
            self.policy.optimizer.step()

            # Soft update of target network
            with torch.no_grad():
                for target_param, param in zip(self.q_net_target.parameters(), self.q_net.parameters()):
                    target_param.data.copy_(self.tau * param.data + (1.0 - self.tau) * target_param.data)

            self.logger.record('train/loss', loss.item())

# Define policy_kwargs for DQN model
policy_kwargs = dict(
    features_extractor_class=CustomFeaturesExtractor,
)

model_path = os.path.join(models_dir, "CustomDQN_.zip")
# Initialize CustomDQN using the custom model
model = CustomDQN(
    'MlpPolicy',                    # Use a Multi-layer Perceptron (MLP) policy
    env,                            # Your RL environment
    policy_kwargs=policy_kwargs,
    buffer_size=2000,               # Replay buffer size N
    batch_size=32,                  # Batch size
    gamma=0.9,                      # Discount factor
    tau=0.01,                       # Soft target update strategy
    exploration_initial_eps=0.5,    # Initial epsilon
    exploration_final_eps=0.1,      # Final epsilon
    exploration_fraction=0.5,
    verbose=1,
    tensorboard_log=logdir,
    train_freq=(30,"step"),
    learning_starts= 2000,
    learning_rate= 1e-4
)
model.learn(total_timesteps=40000, 
            tb_log_name="Luo DDQN",
            log_interval=1,
            reset_num_timesteps=True,
            callback=callback)
model.save(model_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs/LuoDDQN_tight_duedate_JA_MB-2025-01-12_01-20-52\Luo DDQN_1
# 0 There are 319 jobs left
# 0 There are 269 jobs left
# 0 There are 219 jobs left
# 0 There are 169 jobs left
# 0 There are 119 jobs left
# 0 There are 69 jobs left
# 0 There are 19 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.83e+03 |
# |    ep_rew_mean      | -280     |
# |    exploration_rate | 0.463    |
# | time/               |          |
# |    episodes         | 1        |
# |    fps              | 143      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 1830     |
# | train/              |          |
# |    episode_reward   | -4       |
# ----------------------------------
# 0 There are 945 jobs left
# 0 There are 895 jobs left
# 0 There are 845 jobs left
# 0 There are 795 jobs left
# find breakdownnnnnn
# having MB in random_events 19
# [[1, 275]]
# [[1, 275]]
# ----------- Random MB at time 18660 on machine [19] at Ope [1, 275]
# 0 749 18660 [('MB', 19, 5940, 'normal')]
# 0 There are 745 jobs left
# 0 There are 695 jobs left
# 0 There are 645 jobs left
# 0 There are 595 jobs left
# 0 There are 545 jobs left
# 0 There are 495 jobs left
# 0 There are 445 jobs left
# 0 There are 395 jobs left
# 0 There are 345 jobs left
# 0 There are 295 jobs left
# 0 There are 245 jobs left
# 0 There are 195 jobs left
# 0 There are 145 jobs left
# 0 There are 95 jobs left
# 0 There are 45 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.45e+03 |
# |    ep_rew_mean      | -356     |
# |    exploration_rate | 0.402    |
# | time/               |          |
# |    episodes         | 2        |
# |    fps              | 66       |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 4905     |
# | train/              |          |
# |    episode_reward   | -7       |
# |    loss             | 0.185    |
# ----------------------------------
# 0 There are 945 jobs left
# 0 There are 895 jobs left
# 0 There are 845 jobs left
# 0 There are 795 jobs left
# 0 There are 745 jobs left
# 0 There are 695 jobs left
# 0 There are 645 jobs left
# 0 There are 595 jobs left
# 0 There are 545 jobs left
# 0 There are 495 jobs left
# 0 There are 445 jobs left
# 0 There are 395 jobs left
# 0 There are 345 jobs left
# 0 There are 295 jobs left
# 0 There are 245 jobs left
# 0 There are 195 jobs left
# 0 There are 145 jobs left
# 0 There are 95 jobs left
# 0 There are 45 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.66e+03 |
# |    ep_rew_mean      | -360     |
# |    exploration_rate | 0.34     |
# | time/               |          |
# |    episodes         | 3        |
# |    fps              | 59       |
# |    time_elapsed     | 135      |
# |    total_timesteps  | 7980     |
# | train/              |          |
# |    episode_reward   | -2       |
# |    loss             | 0.227    |
# ----------------------------------
# 0 There are 216 jobs left
# 0 There are 166 jobs left
# 0 There are 116 jobs left
# 0 There are 66 jobs left
# 0 There are 16 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.31e+03 |
# |    ep_rew_mean      | -322     |
# |    exploration_rate | 0.316    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 64       |
# |    time_elapsed     | 142      |
# |    total_timesteps  | 9224     |
# | train/              |          |
# |    episode_reward   | -10      |
# |    loss             | 0.321    |
# ----------------------------------
# 0 There are 959 jobs left
# 0 There are 909 jobs left
# 0 There are 859 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 6
# [[2, 190]]
# [[2, 190]]
# ----------- Random MB at time 11960 on machine [6] at Ope [2, 190]
# 0 848 11960 [('MB', 6, 3960, 'critical')]
# 0 There are 809 jobs left
# 0 There are 759 jobs left
# 0 There are 709 jobs left
# 0 There are 659 jobs left
# 0 There are 609 jobs left
# 0 There are 559 jobs left
# 0 There are 509 jobs left
# 0 There are 459 jobs left
# 0 There are 409 jobs left
# 0 There are 359 jobs left
# 0 There are 309 jobs left
# 0 There are 259 jobs left
# 0 There are 209 jobs left
# 0 There are 159 jobs left
# 0 There are 109 jobs left
# 0 There are 59 jobs left
# 0 There are 9 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.47e+03 |
# |    ep_rew_mean      | -336     |
# |    exploration_rate | 0.253    |
# | time/               |          |
# |    episodes         | 5        |
# |    fps              | 58       |
# |    time_elapsed     | 209      |
# |    total_timesteps  | 12344    |
# | train/              |          |
# |    episode_reward   | -8       |
# |    loss             | 0.246    |
# ----------------------------------
# 0 There are 306 jobs left
# 0 There are 256 jobs left
# 0 There are 206 jobs left
# 0 There are 156 jobs left
# 0 There are 106 jobs left
# 0 There are 56 jobs left
# 0 There are 6 jobs left
# find no events
# find no events
# ====== Done ======
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.32e+03 |
# |    ep_rew_mean      | -316     |
# |    exploration_rate | 0.221    |
# | time/               |          |
# |    episodes         | 6        |
# |    fps              | 62       |
# |    time_elapsed     | 221      |
# |    total_timesteps  | 13940    |
# | train/              |          |
# |    episode_reward   | 0        |
# |    loss             | 0.241    |
# ----------------------------------
# 0 There are 289 jobs left
# 0 There are 239 jobs left
# 0 There are 189 jobs left
# 0 There are 139 jobs left
# 0 There are 89 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | -286     |
# |    exploration_rate | 0.197    |
# | time/               |          |
# |    episodes         | 7        |
# |    fps              | 65       |
# |    time_elapsed     | 230      |
# |    total_timesteps  | 15158    |
# | train/              |          |
# |    episode_reward   | -4       |
# |    loss             | 0.213    |
# ----------------------------------
# 0 There are 203 jobs left
# 0 There are 153 jobs left
# 0 There are 103 jobs left
# 0 There are 53 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 10
# [[2, 241], [2, 242]]
# [[2, 241], [2, 242]]
# ----------- Random MB at time 17520 on machine [10] at Ope [2, 241]
# 0 There are 3 jobs left
# find no events
# ====== Done ======
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | -311     |
# |    exploration_rate | 0.16     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 69       |
# |    time_elapsed     | 244      |
# |    total_timesteps  | 16983    |
# | train/              |          |
# |    episode_reward   | -11      |
# |    loss             | 0.12     |
# ----------------------------------
# 0 There are 109 jobs left
# 0 There are 59 jobs left
# 0 There are 9 jobs left
# find no events
# ====== Done ======
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | -305     |
# |    exploration_rate | 0.139    |
# | time/               |          |
# |    episodes         | 9        |
# |    fps              | 72       |
# |    time_elapsed     | 250      |
# |    total_timesteps  | 18061    |
# | train/              |          |
# |    episode_reward   | -6       |
# |    loss             | 0.0639   |
# ----------------------------------
# 0 There are 693 jobs left
# 0 There are 643 jobs left
# 0 There are 593 jobs left
# 0 There are 543 jobs left
# 0 There are 493 jobs left
# 0 There are 443 jobs left
# 0 There are 393 jobs left
# 0 There are 343 jobs left
# 0 There are 293 jobs left
# 0 There are 243 jobs left
# 0 There are 193 jobs left
# 0 There are 143 jobs left
# 0 There are 93 jobs left
# 0 There are 43 jobs left
# find no events
# find no events
# ====== Done ======
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | -277     |
# |    exploration_rate | 0.108    |
# | time/               |          |
# |    episodes         | 10       |
# |    fps              | 72       |
# |    time_elapsed     | 269      |
# |    total_timesteps  | 19591    |
# | train/              |          |
# |    episode_reward   | -1       |
# |    loss             | 0.0565   |
# ----------------------------------
# 0 There are 154 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 11
# [[2, 59]]
# [[2, 59]]
# ----------- Random MB at time 4080 on machine [11] at Ope [2, 59]
# 0 There are 104 jobs left
# 0 There are 54 jobs left
# 0 There are 4 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.92e+03 |
# |    ep_rew_mean      | -284     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 11       |
# |    fps              | 75       |
# |    time_elapsed     | 279      |
# |    total_timesteps  | 21066    |
# | train/              |          |
# |    episode_reward   | -7       |
# |    loss             | 0.0866   |
# ----------------------------------
# 0 There are 979 jobs left
# 0 There are 929 jobs left
# 0 There are 879 jobs left
# 0 There are 829 jobs left
# 0 There are 779 jobs left
# 0 There are 729 jobs left
# 0 There are 679 jobs left
# 0 There are 629 jobs left
# 0 There are 579 jobs left
# 0 There are 529 jobs left
# 0 There are 479 jobs left
# 0 There are 429 jobs left
# 0 There are 379 jobs left
# 0 There are 329 jobs left
# 0 There are 279 jobs left
# 0 There are 229 jobs left
# 0 There are 179 jobs left
# 0 There are 129 jobs left
# 0 There are 79 jobs left
# 0 There are 29 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | -297     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 69       |
# |    time_elapsed     | 348      |
# |    total_timesteps  | 24246    |
# | train/              |          |
# |    episode_reward   | 2        |
# |    loss             | 0.0428   |
# ----------------------------------
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 7
# [[2, 10], [2, 19]]
# [[2, 10], [2, 19]]
# ----------- Random MB at time 480 on machine [7] at Ope [2, 10]
# 0 There are 485 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 9
# [[2, 79]]
# [[2, 79]]
# ----------- Random MB at time 5100 on machine [9] at Ope [2, 79]
# c:\Users\dvtruc\.conda\envs\dunnbebes\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\dvtruc\.conda\envs\dunnbebes\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 0 There are 435 jobs left
# 0 There are 385 jobs left
# 0 There are 335 jobs left
# 0 There are 285 jobs left
# 0 There are 235 jobs left
# 0 There are 185 jobs left
# 0 There are 135 jobs left
# 0 There are 85 jobs left
# 0 There are 35 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | -294     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 13       |
# |    fps              | 70       |
# |    time_elapsed     | 372      |
# |    total_timesteps  | 26289    |
# | train/              |          |
# |    episode_reward   | -3       |
# |    loss             | 0.0856   |
# ----------------------------------
# 0 There are 678 jobs left
# 0 There are 628 jobs left
# 0 There are 578 jobs left
# 0 There are 528 jobs left
# 0 There are 478 jobs left
# 0 There are 428 jobs left
# 0 There are 378 jobs left
# 0 There are 328 jobs left
# 0 There are 278 jobs left
# 0 There are 228 jobs left
# 0 There are 178 jobs left
# 0 There are 128 jobs left
# 0 There are 78 jobs left
# 0 There are 28 jobs left
# find no events
# find no events
# ====== Done ======
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | -266     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 14       |
# |    fps              | 71       |
# |    time_elapsed     | 390      |
# |    total_timesteps  | 27819    |
# | train/              |          |
# |    episode_reward   | 1        |
# |    loss             | 0.14     |
# ----------------------------------
# 0 There are 492 jobs left
# 0 There are 442 jobs left
# 0 There are 392 jobs left
# find breakdownnnnnn
# having MB in random_events 11
# [[2, 177]]
# [[2, 177]]
# ----------- Random MB at time 12710 on machine [11] at Ope [2, 177]
# 0 380 12710 [('MB', 11, 1980, 'critical')]
# 0 There are 342 jobs left
# 0 There are 292 jobs left
# 0 There are 242 jobs left
# 0 There are 192 jobs left
# 0 There are 142 jobs left
# 0 There are 92 jobs left
# 0 There are 42 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | -261     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 15       |
# |    fps              | 72       |
# |    time_elapsed     | 415      |
# |    total_timesteps  | 30060    |
# | train/              |          |
# |    episode_reward   | 1        |
# |    loss             | 0.0769   |
# ----------------------------------
# 0 There are 376 jobs left
# 0 There are 326 jobs left
# 0 There are 276 jobs left
# 0 There are 226 jobs left
# 0 There are 176 jobs left
# 0 There are 126 jobs left
# 0 There are 76 jobs left
# 0 There are 26 jobs left
# find no events
# ====== Done ======
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | -249     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 73       |
# |    time_elapsed     | 427      |
# |    total_timesteps  | 31455    |
# | train/              |          |
# |    episode_reward   | 4        |
# |    loss             | 0.129    |
# ----------------------------------
# 0 There are 353 jobs left
# 0 There are 303 jobs left
# 0 There are 253 jobs left
# 0 There are 203 jobs left
# 0 There are 153 jobs left
# 0 There are 103 jobs left
# 0 There are 53 jobs left
# 0 There are 3 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | -247     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 17       |
# |    fps              | 74       |
# |    time_elapsed     | 442      |
# |    total_timesteps  | 33105    |
# | train/              |          |
# |    episode_reward   | -2       |
# |    loss             | 0.137    |
# ----------------------------------
# 0 There are 945 jobs left
# find breakdownnnnnn
# having MB in random_events 11
# [[2, 102]]
# [[2, 102]]
# ----------- Random MB at time 5560 on machine [11] at Ope [2, 102]
# 0 922 5560 [('MB', 11, 1740, 'critical')]
# 0 There are 895 jobs left
# 0 There are 845 jobs left
# 0 There are 795 jobs left
# 0 There are 745 jobs left
# 0 There are 695 jobs left
# 0 There are 645 jobs left
# 0 There are 595 jobs left
# 0 There are 545 jobs left
# 0 There are 495 jobs left
# 0 There are 445 jobs left
# 0 There are 395 jobs left
# 0 There are 345 jobs left
# 0 There are 295 jobs left
# 0 There are 245 jobs left
# 0 There are 195 jobs left
# 0 There are 145 jobs left
# 0 There are 95 jobs left
# 0 There are 45 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | -255     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 18       |
# |    fps              | 70       |
# |    time_elapsed     | 516      |
# |    total_timesteps  | 36180    |
# | train/              |          |
# |    episode_reward   | -4       |
# |    loss             | 0.0494   |
# ----------------------------------
# 0 There are 289 jobs left
# 0 There are 239 jobs left
# 0 There are 189 jobs left
# 0 There are 139 jobs left
# 0 There are 89 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# ====== Done ======
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | -247     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 19       |
# |    fps              | 71       |
# |    time_elapsed     | 525      |
# |    total_timesteps  | 37398    |
# | train/              |          |
# |    episode_reward   | 0        |
# |    loss             | 0.0775   |
# ----------------------------------
# 0 There are 693 jobs left
# 0 There are 643 jobs left
# 0 There are 593 jobs left
# 0 There are 543 jobs left
# 0 There are 493 jobs left
# 0 There are 443 jobs left
# 0 There are 393 jobs left
# 0 There are 343 jobs left
# 0 There are 293 jobs left
# 0 There are 243 jobs left
# 0 There are 193 jobs left
# 0 There are 143 jobs left
# 0 There are 93 jobs left
# 0 There are 43 jobs left
# find no events
# find no events
# ====== Done ======
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | -236     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 71       |
# |    time_elapsed     | 544      |
# |    total_timesteps  | 38928    |
# | train/              |          |
# |    episode_reward   | 1        |
# |    loss             | 0.101    |
# ----------------------------------
# 0 There are 216 jobs left
# 0 There are 166 jobs left
# 0 There are 116 jobs left
# 0 There are 66 jobs left

# %%
import numpy as np
import torch
from stable_baselines3 import DQN

# model_path = "models/LuoDDQN_tight_duedate_JA_only-2024-12-30_02-42-42/CustomDQN_"

model = DQN.load(model_path, env=env)
def softmax_action_selection(model, obs, mu):
    obs_tensor      = torch.tensor(obs, dtype=torch.float32).unsqueeze(0).to(model.device)
    q_values        = model.q_net(obs_tensor).detach().cpu().numpy().flatten()
    exp_q_values    = np.exp(mu * q_values)
    probabilities   = exp_q_values / np.sum(exp_q_values)
    action          = np.random.choice(len(q_values), p=probabilities)
    return action

results = []
method = 'keyref2'
InstanceList = [f'valid{i+1}' for i in range(15)]
ScenarioList = ['A', 'B', 'C']

mu = 1.6 
for time_run in range(1):
    print('time:', time_run)
    for instance_id in InstanceList:
        print("-----------", instance_id)
        for scenario_id in ScenarioList:
            print("-----", scenario_id)
            # Reset the environment with the new dataset
            obs, info = env.reset(test=True, 
                    datatest=instance_id, 
                    scenariotest=scenario_id)
            
            done = False
            
            while not done:
                action = softmax_action_selection(model, obs, mu)
                obs, reward, done, truncated, info = env.step(action)
            
            tardiness = env.calc_tardiness()
            print(tardiness)
            results.append({
                            'TimeRun'   : time_run,
                            'Method'    : method,
                            'InstanceID': instance_id,
                            'ScenarioID': scenario_id,
                            'Tardiness' : tardiness
                            })
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# time: 0
# ----------- valid1
# ----- A
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 1
# [[0, 44]]
# [[0, 44]]
# ----------- Random MB at time 1980 on machine [1] at Ope [0, 44]
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 8
# [[2, 410]]
# [[2, 410]]
# ----------- Random MB at time 29070 on machine [8] at Ope [2, 410]
# 0 104 29070 [('MB', 8, 3180.0, 'critical')]
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 101395.0
# ----- B
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 8
# [[2, 180]]
# [[2, 180]]
# ----------- Random MB at time 12000 on machine [8] at Ope [2, 180]
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 8
# [[2, 211]]
# [[2, 211]]
# ----------- Random MB at time 13670 on machine [8] at Ope [2, 211]
# 0 304 13670 [('MB', 8, 1320.0, 'critical')]
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 10
# [[2, 484]]
# [[2, 484]]
# ----------- Random MB at time 34080 on machine [10] at Ope [2, 484]
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 119870.0
# ----- C
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 105965.0
# ----------- valid2
# ----- A
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 93235.0
# ----- B
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 6
# [[2, 243]]
# [[2, 243]]
# ----------- Random MB at time 18070 on machine [6] at Ope [2, 243]
# 0 260 18070 [('MB', 6, 780.0, 'critical')]
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 110055.0
# ----- C
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 9
# [[2, 398]]
# [[2, 398], [2, 402]]
# ----------- Random MB at time 28920 on machine [9] at Ope [2, 398]
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 91265.0
# ----------- valid3
# ----- A
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 9
# [[2, 175]]
# [[2, 175]]
# ----------- Random MB at time 12820 on machine [9] at Ope [2, 175]
# 0 332 12820 [('MB', 9, 960.0, 'critical')]
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 97735.0
# ----- B
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 105780.0
# ----- C
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 9
# [[2, 347]]
# [[2, 347]]
# ----------- Random MB at time 24870 on machine [9] at Ope [2, 347]
# 0 159 24870 [('MB', 9, 120.0, 'critical')]
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 103715.0
# ----------- valid4
# ----- A
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 1
# [[0, 258]]
# [[0, 258]]
# ----------- Random MB at time 18850 on machine [1] at Ope [0, 258]
# 0 246 18850 [('MB', 1, 900.0, 'normal')]
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 102705.0
# ----- B
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 97250.0
# ----- C
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 1
# [[0, 16]]
# [[0, 16]]
# ----------- Random MB at time 540 on machine [1] at Ope [0, 16]
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 16
# [[1, 228], [1, 231]]
# [[1, 228], [1, 231]]
# ----------- Random MB at time 16920 on machine [16] at Ope [1, 228]
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 17
# [[1, 233]]
# [[1, 233]]
# ----------- Random MB at time 17150 on machine [17] at Ope [1, 233]
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 12
# [[2, 246]]
# [[2, 246]]
# ----------- Random MB at time 17870 on machine [12] at Ope [2, 246]
# 0 258 17870 [('MB', 12, 1320.0, 'critical')]
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 10
# [[2, 331]]
# [[2, 331]]
# ----------- Random MB at time 24220 on machine [10] at Ope [2, 331]
# 0 172 24220 [('MB', 10, 540.0, 'critical')]
# 0 There are 144 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 1
# [[0, 372]]
# [[0, 372]]
# ----------- Random MB at time 27050 on machine [1] at Ope [0, 372]
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 88965.0
# ----------- valid5
# ----- A
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 116980.0
# ----- B
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 117935.0
# ----- C
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 118335.0
# ----------- valid6
# ----- A
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# 0 There are 344 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 9
# [[2, 159]]
# [[2, 159]]
# ----------- Random MB at time 11640 on machine [9] at Ope [2, 159]
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 6
# [[2, 468]]
# [[2, 468]]
# ----------- Random MB at time 34020 on machine [6] at Ope [2, 468]
# 0 40 34020 [('MB', 6, 2820.0, 'critical')]
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 116780.0
# ----- B
# 0 There are 444 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 12
# [[2, 79]]
# [[2, 79]]
# ----------- Random MB at time 5200 on machine [12] at Ope [2, 79]
# 0 424 5200 [('MB', 12, 2040.0, 'critical')]
# 0 There are 394 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 12
# [[2, 157]]
# [[2, 157]]
# ----------- Random MB at time 10820 on machine [12] at Ope [2, 157]
# 0 351 10820 [('MB', 12, 3360.0, 'critical')]
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 10
# [[2, 307]]
# [[2, 307]]
# ----------- Random MB at time 21750 on machine [10] at Ope [2, 307]
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 126365.0
# ----- C
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 12
# [[2, 357]]
# [[2, 357]]
# ----------- Random MB at time 25500 on machine [12] at Ope [2, 357]
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 109210.0
# ----------- valid7
# ----- A
# 0 There are 444 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 8
# [[2, 99]]
# [[2, 99]]
# ----------- Random MB at time 7770 on machine [8] at Ope [2, 99]
# 0 397 7770 [('MB', 8, 120.0, 'critical')]
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 1
# [[0, 260]]
# [[0, 260]]
# ----------- Random MB at time 20100 on machine [1] at Ope [0, 260]
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 88465.0
# ----- B
# 0 There are 444 jobs left
# find breakdownnnnnn
# having MB in random_events 10
# [[2, 75]]
# [[2, 75]]
# ----------- Random MB at time 5460 on machine [10] at Ope [2, 75]
# 0 422 5460 [('MB', 10, 360.0, 'critical')]
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 9
# [[2, 165]]
# [[2, 165]]
# ----------- Random MB at time 12670 on machine [9] at Ope [2, 165]
# 0 332 12670 [('MB', 9, 3000.0, 'critical')]
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 98565.0
# ----- C
# 0 There are 444 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 9
# [[2, 70]]
# [[2, 70]]
# ----------- Random MB at time 5640 on machine [9] at Ope [2, 70]
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 101805.0
# ----------- valid8
# ----- A
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 133810.0
# ----- B
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 141475.0
# ----- C
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 148050.0
# ----------- valid9
# ----- A
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 6
# [[2, 271]]
# [[2, 271]]
# ----------- Random MB at time 19020 on machine [6] at Ope [2, 271]
# 0 234 19020 [('MB', 6, 660.0, 'critical')]
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 104075.0
# ----- B
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 91110.0
# ----- C
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 1
# [[0, 252]]
# [[0, 252]]
# ----------- Random MB at time 18170 on machine [1] at Ope [0, 252]
# 0 254 18170 [('MB', 1, 8520.0, 'normal')]
# 0 There are 244 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 10
# [[2, 284]]
# [[2, 284]]
# ----------- Random MB at time 20720 on machine [10] at Ope [2, 284]
# 0 222 20720 [('MB', 10, 480.0, 'critical')]
# 0 There are 194 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 8
# [[2, 329]]
# [[2, 329]]
# ----------- Random MB at time 24780 on machine [8] at Ope [2, 329]
# 0 There are 144 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 6
# [[2, 396]]
# [[2, 396]]
# ----------- Random MB at time 29100 on machine [6] at Ope [2, 396]
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 76560.0
# ----------- valid10
# ----- A
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 95620.0
# ----- B
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 105335.0
# ----- C
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 103480.0
# ----------- valid11
# ----- A
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 104235.0
# ----- B
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 16
# [[1, 480], [1, 482]]
# [[1, 480], [1, 482]]
# ----------- Random MB at time 34140 on machine [16] at Ope [1, 480]
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 12
# [[3, 480]]
# [[3, 480]]
# ----------- Random MB at time 34250 on machine [12] at Ope [3, 480]
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 17
# [[1, 486]]
# [[1, 486]]
# ----------- Random MB at time 34550 on machine [17] at Ope [1, 486]
# 0 37 34550 [('MB', 17, 3660.0, 'normal')]
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 107785.0
# ----- C
# 0 There are 444 jobs left
# find breakdownnnnnn
# having MB in random_events 1
# [[0, 95]]
# [[0, 95]]
# ----------- Random MB at time 4800 on machine [1] at Ope [0, 95]
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 119305.0
# ----------- valid12
# ----- A
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 1
# [[0, 219]]
# [[0, 219]]
# ----------- Random MB at time 15840 on machine [1] at Ope [0, 219]
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 103350.0
# ----- B
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 10
# [[2, 141]]
# [[2, 141]]
# ----------- Random MB at time 9470 on machine [10] at Ope [2, 141]
# 0 365 9470 [('MB', 10, 3840.0, 'critical')]
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 94160.0
# ----- C
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 6
# [[2, 401]]
# [[2, 401]]
# ----------- Random MB at time 29170 on machine [6] at Ope [2, 401]
# 0 105 29170 [('MB', 6, 3960.0, 'critical')]
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 97635.0
# ----------- valid13
# ----- A
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 10
# [[2, 336]]
# [[2, 336]]
# ----------- Random MB at time 24720 on machine [10] at Ope [2, 336]
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 103855.0
# ----- B
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 96390.0
# ----- C
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 9
# [[2, 155]]
# [[2, 155]]
# ----------- Random MB at time 11370 on machine [9] at Ope [2, 155]
# 0 346 11370 [('MB', 9, 900.0, 'critical')]
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 99290.0
# ----------- valid14
# ----- A
# 0 There are 444 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 10
# [[2, 76], [2, 87]]
# [[2, 76], [2, 87]]
# ----------- Random MB at time 5340 on machine [10] at Ope [2, 76]
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 90260.0
# ----- B
# 0 There are 444 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 12
# [[2, 68]]
# [[2, 68]]
# ----------- Random MB at time 4260 on machine [12] at Ope [2, 68]
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 6
# [[2, 443]]
# [[2, 443]]
# ----------- Random MB at time 32300 on machine [6] at Ope [2, 443]
# 0 59 32300 [('MB', 6, 900.0, 'critical')]
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 91890.0
# ----- C
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 10
# [[2, 305]]
# [[2, 305]]
# ----------- Random MB at time 22150 on machine [10] at Ope [2, 305]
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 92860.0
# ----------- valid15
# ----- A
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# 0 There are 344 jobs left
# find breakdownnnnnn
# having MB in random_events 1
# [[0, 173]]
# [[0, 173]]
# ----------- Random MB at time 11880 on machine [1] at Ope [0, 173]
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 117980.0
# ----- B
# 0 There are 444 jobs left
# 0 There are 394 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 8
# [[2, 150]]
# [[2, 150]]
# ----------- Random MB at time 10370 on machine [8] at Ope [2, 150]
# 0 357 10370 [('MB', 8, 360.0, 'critical')]
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 16
# [[1, 416]]
# [[1, 416]]
# ----------- Random MB at time 30850 on machine [16] at Ope [1, 416]
# 0 90 30850 [('MB', 16, 4620.0, 'normal')]
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 110540.0
# ----- C
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 9
# [[2, 59]]
# [[2, 59]]
# ----------- Random MB at time 3420 on machine [9] at Ope [2, 59]
# 0 There are 444 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 16
# [[1, 81]]
# [[1, 81]]
# ----------- Random MB at time 4920 on machine [16] at Ope [1, 81]
# 0 There are 394 jobs left
# find breakdownnnnnn
# find breakdownnnnnn
# find breakdownnnnnn
# having MB in random_events 9
# [[2, 157], [2, 158]]
# [[2, 157], [2, 158]]
# ----------- Random MB at time 10380 on machine [9] at Ope [2, 157]
# 0 There are 344 jobs left
# 0 There are 294 jobs left
# 0 There are 244 jobs left
# 0 There are 194 jobs left
# 0 There are 144 jobs left
# 0 There are 94 jobs left
# 0 There are 44 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# 124180.0

# %%
df = pd.DataFrame(results)
file_name = f"VALIDATION/LuoDDQN_{purpose}_{current_time}_FULL.xlsx"
df.to_excel(file_name, index=False)
