# %%
import numpy as np
import pandas as pd
import copy
import time
import pickle
from util.util_load         import read_txt
from env_action.metaheu     import GeneticAlgorithm, random_population
from env_action.data_indentifier import InstanceData

directory           = 'SMALL'
planning_horizon    = 480*60
ReworkProbability   = 0.03
CaseList            = ['_fixed_instance'] + [case+1 for case in range(1,48)]
maxtime             = 1000
PopSize             = 100
instances           = {}

# Run only once
for CaseID in CaseList:
    print(CaseID)
    data_path = f"DATA/SMALL/Case{CaseID}_480.txt"

    J, I, K, p_ijk, h_ijk,   \
    d_j, n_j, MC_ji, n_MC_ji,\
    OperationPool          = read_txt(data_path)

    S_k                    = np.zeros((K))
    S_j                    = np.zeros((J))
    n_ops_left_j           = copy.deepcopy(n_j)

    t                      = 0
    JSet                   = list(range(J))
    OJSet                  = [[] for _ in range(J)]
    for j in JSet:
        OJSet[j]           = [i for i in range(int(n_j[j]))]

    StartTime                     = time.time()
    print("Random", time.time())
    population, chromosome_len    = random_population(OperationPool, PopSize)
    print("Solving", time.time())
    GBest, X_ijk, S_ij, C_ij, C_j = GeneticAlgorithm(S_k, S_j, JSet, OJSet, J, I, K, 
                                                    p_ijk, h_ijk, d_j, n_j, n_ops_left_j, 
                                                    MC_ji, n_MC_ji, OperationPool,
                                                    PopSize, population, chromosome_len,
                                                    StartTime, maxtime)
    print("Storing", time.time())
    instances[CaseID]             = InstanceData(J, I, X_ijk, S_ij, C_ij, C_j, p_ijk, h_ijk, 
                                                 d_j, n_j, MC_ji, n_MC_ji, OperationPool)
    print("Done", time.time())
    

# Store data
with open('pickle_instances_480.pkl', 'wb') as f:
    pickle.dump(instances, f)
# Out:
# _fixed_instance
# Random 1719274699.5967155
# Solving 1719274699.613514
# chromosome len 2740
# Start Decoding 1719274776.7848587
# End Decoding 1719274776.8014822
# Storing 1719274776.8014822
# Done 1719274776.8014822
# 2
# Random 1719274776.834986
# Solving 1719274776.834986
# chromosome len 3120
# Start Decoding 1719274834.1411235
# End Decoding 1719274834.2255647
# Storing 1719274834.2255647
# Done 1719274834.2255647
# 3
# Random 1719274834.252314
# Solving 1719274834.2680135
# chromosome len 2755
# Start Decoding 1719274878.0591578
# End Decoding 1719274878.074797
# Storing 1719274878.074797
# Done 1719274878.074797
# 4
# Random 1719274878.1279845
# Solving 1719274878.143678
# chromosome len 4890
# Start Decoding 1719274954.9453185
# End Decoding 1719274954.9769106
# Storing 1719274954.9769106
# Done 1719274954.9769106
# 5
# Random 1719274954.9926043
# Solving 1719274954.9926043
# chromosome len 1680
# Start Decoding 1719274976.2299016
# End Decoding 1719274976.245455
# Storing 1719274976.245455
# Done 1719274976.245455
# 6
# Random 1719274976.3161757
# Solving 1719274976.331132
# chromosome len 5270
# Start Decoding 1719275043.9674375
# End Decoding 1719275043.998617
# Storing 1719275043.998617
# Done 1719275043.998617
# 7
# Random 1719275044.0299356
# Solving 1719275044.050176
# chromosome len 3080
# Start Decoding 1719275081.2691808
# End Decoding 1719275081.2847407
# Storing 1719275081.2847407
# Done 1719275081.2847407
# 8
# Random 1719275081.3192036
# Solving 1719275081.3370652
# chromosome len 2590
# Start Decoding 1719275106.003966
# End Decoding 1719275106.0195115
# Storing 1719275106.0195115
# Done 1719275106.0195115
# 9
# Random 1719275106.035215
# Solving 1719275106.0560277
# chromosome len 2620
# Start Decoding 1719275143.5393891
# End Decoding 1719275143.557259
# Storing 1719275143.557259
# Done 1719275143.557259
# 10
# Random 1719275143.574074
# Solving 1719275143.574074
# chromosome len 1512
# Start Decoding 1719275168.025248
# End Decoding 1719275168.040946
# Storing 1719275168.040946
# Done 1719275168.040946
# 11
# Random 1719275168.1502361
# Solving 1719275168.168449
# chromosome len 5100
# Start Decoding 1719275248.5130813
# End Decoding 1719275248.5444345
# Storing 1719275248.5444345
# Done 1719275248.5444345
# 12
# Random 1719275248.5782838
# Solving 1719275248.5985477
# chromosome len 2270
# Start Decoding 1719275280.1629324
# End Decoding 1719275280.1785555
# Storing 1719275280.1785555
# Done 1719275280.1785555
# 13
# Random 1719275280.2143962
# Solving 1719275280.2143962
# chromosome len 2200
# Start Decoding 1719275310.628813
# End Decoding 1719275310.628813
# Storing 1719275310.628813
# Done 1719275310.628813
# 14
# Random 1719275310.6646197
# Solving 1719275310.6803193
# chromosome len 2800
# Start Decoding 1719275341.6184983
# End Decoding 1719275341.634194
# Storing 1719275341.634194
# Done 1719275341.634194
# 15
# Random 1719275341.6826053
# Solving 1719275341.6826053
# chromosome len 3250
# Start Decoding 1719275380.8554318
# End Decoding 1719275380.8866796
# Storing 1719275380.8866796
# Done 1719275380.8866796
# 16
# Random 1719275380.9495718
# Solving 1719275380.9670162
# chromosome len 3270
# Start Decoding 1719275414.4700263
# End Decoding 1719275414.49157
# Storing 1719275414.49157
# Done 1719275414.49157
# 17
# Random 1719275414.5193427
# Solving 1719275414.534979
# chromosome len 3400
# Start Decoding 1719275498.5925496
# End Decoding 1719275498.6081734
# Storing 1719275498.6081734
# Done 1719275498.6081734
# 18
# Random 1719275498.6425579
# Solving 1719275498.6581101
# chromosome len 3170
# Start Decoding 1719275534.5085793
# End Decoding 1719275534.5435846
# Storing 1719275534.5435846
# Done 1719275534.5435846
# 19
# Random 1719275534.6444187
# Solving 1719275534.6626003
# chromosome len 4680
# Start Decoding 1719275601.3308342
# End Decoding 1719275601.3678262
# Storing 1719275601.3678262
# Done 1719275601.3678262
# 20
# Random 1719275601.3991437
# Solving 1719275601.3991437
# chromosome len 3130
# Start Decoding 1719275745.1831698
# End Decoding 1719275745.2183812
# Storing 1719275745.2183812
# Done 1719275745.2183812
# 21
# Random 1719275745.2734733
# Solving 1719275745.289095
# chromosome len 5360
# Start Decoding 1719275800.9889565
# End Decoding 1719275801.0243545
# Storing 1719275801.0243545
# Done 1719275801.0243545
# 22
# Random 1719275801.0741665
# Solving 1719275801.0929813
# chromosome len 4700
# Start Decoding 1719275862.3789403
# End Decoding 1719275862.397387
# Storing 1719275862.397387
# Done 1719275862.397387
# 23
# Random 1719275862.4443324
# Solving 1719275862.4443324
# chromosome len 3600
# Start Decoding 1719275908.0967264
# End Decoding 1719275908.1147313
# Storing 1719275908.1147313
# Done 1719275908.1147313
# 24
# Random 1719275908.1847641
# Solving 1719275908.2003903
# chromosome len 6498
# Start Decoding 1719276050.6070178
# End Decoding 1719276050.6405632
# Storing 1719276050.6405632
# Done 1719276050.6405632
# 25
# Random 1719276050.6718113
# Solving 1719276050.6718113
# chromosome len 2196
# Start Decoding 1719276072.0240104
# End Decoding 1719276072.0397007
# Storing 1719276072.0397007
# Done 1719276072.0397007
# 26
# Random 1719276072.0701046
# Solving 1719276072.074134
# chromosome len 2604
# Start Decoding 1719276091.1421366
# End Decoding 1719276091.1570873
# Storing 1719276091.1570873
# Done 1719276091.1570873
# 27
# Random 1719276091.1747441
# Solving 1719276091.1747441
# chromosome len 2266
# Start Decoding 1719276121.996833
# End Decoding 1719276122.0125287
# Storing 1719276122.0125287
# Done 1719276122.0125287
# 28
# Random 1719276122.0281522
# Solving 1719276122.0281522
# chromosome len 2228
# Start Decoding 1719276149.9300678
# End Decoding 1719276149.945764
# Storing 1719276149.945764
# Done 1719276149.945764
# 29
# Random 1719276150.011379
# Solving 1719276150.029002
# chromosome len 7122
# Start Decoding 1719276264.7812455
# End Decoding 1719276264.8357315
# Storing 1719276264.8357315
# Done 1719276264.8357315
# 30
# Random 1719276264.884362
# Solving 1719276264.9000554
# chromosome len 4940
# Start Decoding 1719276318.953004
# End Decoding 1719276318.988868
# Storing 1719276318.988868
# Done 1719276318.988868
# 31
# Random 1719276319.0380046
# Solving 1719276319.0389924
# chromosome len 4002
# Start Decoding 1719276358.1529143
# End Decoding 1719276358.1710343
# Storing 1719276358.1710343
# Done 1719276358.1710343
# 32
# Random 1719276358.2408621
# Solving 1719276358.2565267
# chromosome len 5710
# Start Decoding 1719276437.729486
# End Decoding 1719276437.7607331
# Storing 1719276437.7607331
# Done 1719276437.7607331
# 33
# Random 1719276437.789164
# Solving 1719276437.7942145
# chromosome len 1491
# Start Decoding 1719276447.6779912
# End Decoding 1719276447.6802437
# Storing 1719276447.6802437
# Done 1719276447.6802437
# 34
# Random 1719276447.7785375
# Solving 1719276447.794246
# chromosome len 7000
# Start Decoding 1719276602.2728791
# End Decoding 1719276602.3082247
# Storing 1719276602.3082247
# Done 1719276602.3082247
# 35
# Random 1719276602.3551693
# Solving 1719276602.3708022
# chromosome len 3350
# Start Decoding 1719276642.788829
# End Decoding 1719276642.8045206
# Storing 1719276642.8045206
# Done 1719276642.8045206
# 36
# Random 1719276642.8389373
# Solving 1719276642.8556826
# chromosome len 2709
# Start Decoding 1719276677.6411438
# End Decoding 1719276677.6569815
# Storing 1719276677.6569815
# Done 1719276677.6569815
# 37
# Random 1719276677.691989
# Solving 1719276677.691989
# chromosome len 2150
# Start Decoding 1719276711.5470405
# End Decoding 1719276711.5621135
# Storing 1719276711.5621135
# Done 1719276711.5621135
# 38
# Random 1719276711.5778255
# Solving 1719276711.593374
# chromosome len 1872
# Start Decoding 1719276724.89546
# End Decoding 1719276724.9110868
# Storing 1719276724.9110868
# Done 1719276724.9110868
# 39
# Random 1719276724.9458692
# Solving 1719276724.9458692
# chromosome len 3300
# Start Decoding 1719276756.877606
# End Decoding 1719276756.8932264
# Storing 1719276756.8932264
# Done 1719276756.8932264
# 40
# Random 1719276756.930662
# Solving 1719276756.930662
# chromosome len 2918
# Start Decoding 1719276788.3327029
# End Decoding 1719276788.3483584
# Storing 1719276788.3483584
# Done 1719276788.3483584
# 41
# Random 1719276788.3802273
# Solving 1719276788.3813536
# chromosome len 2555
# Start Decoding 1719276807.235693
# End Decoding 1719276807.2513876
# Storing 1719276807.2513876
# Done 1719276807.2513876
# 42
# Random 1719276807.282636
# Solving 1719276807.282636
# chromosome len 2796
# Start Decoding 1719276831.553989
# End Decoding 1719276831.5696857
# Storing 1719276831.5696857
# Done 1719276831.5696857
# 43
# Random 1719276831.63257
# Solving 1719276831.6485305
# chromosome len 2544
# Start Decoding 1719276853.0493464
# End Decoding 1719276853.0650632
# Storing 1719276853.0650632
# Done 1719276853.0650632
# 44
# Random 1719276853.0986862
# Solving 1719276853.1027293
# chromosome len 2880
# Start Decoding 1719276884.6173382
# End Decoding 1719276884.632965
# Storing 1719276884.632965
# Done 1719276884.632965
# 45
# Random 1719276884.6689546
# Solving 1719276884.6846569
# chromosome len 4620
# Start Decoding 1719276979.5242984
# End Decoding 1719276979.5557199
# Storing 1719276979.5557199
# Done 1719276979.5557199
# 46
# Random 1719276979.6089377
# Solving 1719276979.6284769
# chromosome len 5760
# Start Decoding 1719277069.679427
# End Decoding 1719277069.710728
# Storing 1719277069.710728
# Done 1719277069.710728
# 47
# Random 1719277069.7464097
# Solving 1719277069.762033
# chromosome len 4400
# Start Decoding 1719277171.319281
# End Decoding 1719277171.3505266
# Storing 1719277171.3505266
# Done 1719277171.3505266
# 48
# Random 1719277171.4021518
# Solving 1719277171.4178545
# chromosome len 6120
# Start Decoding 1719277272.5070865
# End Decoding 1719277272.538411
# Storing 1719277272.538411
# Done 1719277272.538411

# %%
from util.util_load              import read_scenario
from env_action.data_indentifier import ScenarioData

import pickle
K = 30
scenarios           = {}
critical_machines   = {5, 6, 7, 8, 9, 10, 11, 12, 13, 21, 22, 26, 27}
ScenarioList        = ['_fixed_scenario', 'A', 'B', 'C', 'D', 'E', 'F', 'G']

for ScenarioID in ScenarioList:
    scenario_path = f"DATA/SMALL/Scenario{ScenarioID}_480.txt"
    JA_event, MB_event     = read_scenario(scenario_path, K, critical_machines)
    scenarios[ScenarioID]  = ScenarioData(JA_event, MB_event)

with open('pickle_scenarios_480.pkl', 'wb') as f:
    pickle.dump(scenarios, f)
