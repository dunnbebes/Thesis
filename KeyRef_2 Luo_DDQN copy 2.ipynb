# %%
import gymnasium as gym
import pickle
from VALIDATION.KeyRef_2.KeyRef_2_env2 import Luo_DDQN_env
from stable_baselines3.common.callbacks   import BaseCallback
from stable_baselines3.common.env_checker import check_env
import os
import datetime
import pandas as pd
from stable_baselines3.common.callbacks import BaseCallback

K = 30
planning_horizon        = 480*60
ReworkProbability       = 0.03
critical_machines       = {5, 6, 7, 8, 9, 10, 11, 12, 13, 21, 22, 26, 27}

purpose                 = "_tight_duedate_JA_only"
directory               = 'DATA/TIGHT_DUEDATE'

tight_duedate_setting   = True if "tight_duedate" in purpose else False
JA_only_setting         = True if "JA_only" in purpose else False

WeibullDistribution     = pd.read_excel('DATA/DataMaster.xlsx', sheet_name='Distribution')

with open('DATA/ComponentMaster.pkl', 'rb') as f:
    master = pickle.load(f)
with open(f'{directory}_VALIDATION/pickle_valid_scenarios_480.pkl', 'rb') as f:
    valid_scenarios = pickle.load(f)

env = Luo_DDQN_env(K, planning_horizon, ReworkProbability, valid_scenarios, WeibullDistribution, critical_machines,
			  	 master, tight_duedate_setting, JA_only_setting, directory)

# check_env(env)
# obs = env.reset(seed=42,
#                 test=True, 
#                 datatest="valid2", 
#                 scenariotest="A")
            
# print("Observation:", obs)

# episodes = 1
# for episode in range(episodes):
# 	done = False
# 	obs = env.reset(test=True, 
#                     datatest="valid2", 
#                     scenariotest="A")
# 	while done == False: #not done:
# 		random_action = env.action_space.sample()
# 		obs, reward, done, truncated, info = env.step(random_action)

# %%
action_list = ["CDR1", "CDR2", "CDR3", "CDR4", "CDR5", "CDR6"]
                          
# Create directories for models and logs
current_time = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
models_dir = f"models/LuoDDQN{purpose}-{current_time}"
logdir = f"logs/LuoDDQN{purpose}-{current_time}"
log_training_txt_dir = "keyref2_log_training_txt"
log_training_excel_dir = "keyref2_log_training_excel"

if not os.path.exists(models_dir):
    os.makedirs(models_dir)
if not os.path.exists(logdir):
    os.makedirs(logdir)
if not os.path.exists(log_training_txt_dir):
    os.makedirs(log_training_txt_dir)
if not os.path.exists(log_training_excel_dir):
    os.makedirs(log_training_excel_dir)

# Generate unique file names based on current time
log_file          = os.path.join(log_training_txt_dir,   f"training_keyref2.txt")
excel_file        = os.path.join(log_training_excel_dir, f"training_keyref2.xlsx")
action_count_file = os.path.join(log_training_txt_dir,   f"action_count_keyref2.txt")
action_excel_file = os.path.join(log_training_excel_dir, f"action_count_keyref2.xlsx")

# Define the custom callback -------------------------------------------------------------
class CustomCallback(BaseCallback):
    def __init__(self, log_dir, excel_file, txt_file, action_count_file, action_excel_file, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.log_dir = log_dir
        self.excel_file = excel_file
        self.txt_file = txt_file
        self.action_count_file = action_count_file
        self.action_excel_file = action_excel_file
        self.logs = []
        self.episode_rewards = []
        self.action_counts = {}
        self.episode_start = True

    def _on_training_start(self) -> None:
        # Initialize action counts
        self.action_counts = {action: 0 for action in action_list}

    def _on_step(self) -> bool:
        if self.episode_start:
            self.episode_rewards.append(0)
            self.episode_start = False

        # Record reward for the current step
        reward = self.locals['rewards'][0]
        self.episode_rewards[-1] += reward

        # Increment action count
        action = self.locals.get('actions', None)
        if action is not None:
            action_name = action_list[action[0]]
            self.action_counts[action_name] += 1
            
        return True

    def _on_rollout_end(self) -> None:
        # Called at the end of each episode
        sum_reward   = self.episode_rewards[-1] if self.episode_rewards else 0
        
        self.logger.record('train/episode_reward',   sum_reward)
        self.logs.append({
            'sum_reward': sum_reward,
        })

        self.episode_start = True

    
    def _on_training_end(self) -> None:
        # Save logs to Excel
        df = pd.DataFrame(self.logs)
        df.to_excel(self.excel_file, index=False)

        action_df = pd.DataFrame(list(self.action_counts.items()), columns=['Action', 'Count'])
        action_df.to_excel(self.action_excel_file, index=False)

        # Save logs to text file
        with open(self.txt_file, 'w') as f:
            f.write(df.to_string(index=False))
        with open(self.action_count_file, 'w') as f:
            f.write(action_df.to_string(index=False))

# Create the callback
callback = CustomCallback(log_dir=logdir, 
                          excel_file=excel_file,
                          txt_file=log_file,
                          action_count_file=action_count_file,
                          action_excel_file=action_excel_file,
                          verbose=1)

import torch
import torch.nn as nn
import torch.nn.functional as F
from gymnasium import spaces
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
from stable_baselines3 import DQN

class CustomFeaturesExtractor(BaseFeaturesExtractor):
    """
    Custom feature extractor for DQN.
    
    :param observation_space: (spaces.Box)
    """
    def __init__(self, observation_space: spaces.Box):
        super(CustomFeaturesExtractor, self).__init__(observation_space, features_dim=6)  # Output features_dim matches last layer's output
        n_input_nodes = observation_space.shape[0]
        self.fc1 = nn.Linear(n_input_nodes, 30)
        self.fc2 = nn.Linear(30, 30)
        self.fc3 = nn.Linear(30, 30)
        self.fc4 = nn.Linear(30, 30)
        self.fc5 = nn.Linear(30, 30)
        self.fc6 = nn.Linear(30, 6)  # Output layer with 6 nodes

    def forward(self, observations: torch.Tensor) -> torch.Tensor:
        x = F.tanh(self.fc1(observations))
        x = F.tanh(self.fc2(x))
        x = F.tanh(self.fc3(x))
        x = F.tanh(self.fc4(x))
        x = F.tanh(self.fc5(x))
        x = self.fc6(x)  # Output layer
        return x

# Custom DQN class to implement soft target update
class CustomDQN(DQN):
    def __init__(self, *args, tau=0.01, **kwargs):
        super(CustomDQN, self).__init__(*args, **kwargs)
        self.tau = tau

    def train(self, gradient_steps, batch_size=100):
        # Train for gradient_steps
        for gradient_step in range(gradient_steps):
            # Sample replay buffer
            replay_data = self.replay_buffer.sample(batch_size, env=self._vec_normalize_env)
            
            # Mix online and target networks
            target_q_values = self.q_net_target(replay_data.next_observations)
            next_q_values, _ = target_q_values.max(dim=1)
            next_q_values = next_q_values.reshape(-1, 1)

            # Compute the target for the Q function
            target_q = replay_data.rewards + (1 - replay_data.dones) * self.gamma * next_q_values

            # Get current Q estimates
            current_q = self.q_net(replay_data.observations).gather(1, replay_data.actions.long())

            # Compute Huber loss (less sensitive to outliers)
            loss = F.smooth_l1_loss(current_q, target_q)

            # Optimize the model
            self.policy.optimizer.zero_grad()
            loss.backward()
            self.policy.optimizer.step()

            # Soft update of target network
            with torch.no_grad():
                for target_param, param in zip(self.q_net_target.parameters(), self.q_net.parameters()):
                    target_param.data.copy_(self.tau * param.data + (1.0 - self.tau) * target_param.data)

            self.logger.record('train/loss', loss.item())

# Define policy_kwargs for DQN model
policy_kwargs = dict(
    features_extractor_class=CustomFeaturesExtractor,
)

model_path = os.path.join(models_dir, "CustomDQN_.zip")
# Initialize CustomDQN using the custom model
model = CustomDQN(
    'MlpPolicy',                    # Use a Multi-layer Perceptron (MLP) policy
    env,                            # Your RL environment
    policy_kwargs=policy_kwargs,
    buffer_size=2000,               # Replay buffer size N
    batch_size=32,                  # Batch size
    gamma=0.9,                      # Discount factor
    tau=0.01,                       # Soft target update strategy
    exploration_initial_eps=0.5,    # Initial epsilon
    exploration_final_eps=0.1,      # Final epsilon
    exploration_fraction=0.5,
    verbose=1,
    tensorboard_log=logdir,
    train_freq=(30,"step"),
    learning_starts= 2000,
    learning_rate= 1e-4
)
model.learn(total_timesteps=40000, 
            tb_log_name="Luo DDQN",
            log_interval=1,
            reset_num_timesteps=True,
            callback=callback)
model.save(model_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs/LuoDDQN_tight_duedate_JA_only-2024-12-17_06-54-33\Luo DDQN_1
# 0 False
# 0 There are 289 jobs left
# 0 There are 219 jobs left
# 0 There are 149 jobs left
# 0 There are 79 jobs left
# 0 There are 9 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.37e+03 |
# |    ep_rew_mean      | -596     |
# |    exploration_rate | 0.473    |
# | time/               |          |
# |    episodes         | 1        |
# |    fps              | 179      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 1370     |
# | train/              |          |
# |    episode_reward   | -12      |
# ----------------------------------
# 2 True
# 1 True
# 0 False
# 0 There are 925 jobs left
# 0 There are 855 jobs left
# 0 There are 785 jobs left
# 0 There are 715 jobs left
# 0 There are 645 jobs left
# 0 There are 575 jobs left
# 0 There are 505 jobs left
# 0 There are 435 jobs left
# 0 There are 365 jobs left
# 0 There are 295 jobs left
# 0 There are 225 jobs left
# 0 There are 155 jobs left
# 0 There are 85 jobs left
# 0 There are 15 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 2.22e+03  |
# |    ep_rew_mean      | -1.78e+03 |
# |    exploration_rate | 0.411     |
# | time/               |           |
# |    episodes         | 2         |
# |    fps              | 97        |
# |    time_elapsed     | 45        |
# |    total_timesteps  | 4445      |
# | train/              |           |
# |    episode_reward   | -30       |
# |    loss             | 0.254     |
# -----------------------------------
# 0 False
# 0 There are 289 jobs left
# 0 There are 219 jobs left
# 0 There are 149 jobs left
# 0 There are 79 jobs left
# 0 There are 9 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 1.94e+03  |
# |    ep_rew_mean      | -1.46e+03 |
# |    exploration_rate | 0.384     |
# | time/               |           |
# |    episodes         | 3         |
# |    fps              | 106       |
# |    time_elapsed     | 54        |
# |    total_timesteps  | 5815      |
# | train/              |           |
# |    episode_reward   | -20       |
# |    loss             | 0.231     |
# -----------------------------------
# 5 True
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 265 jobs left
# 0 There are 195 jobs left
# 0 There are 125 jobs left
# 0 There are 55 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 1.8e+03   |
# |    ep_rew_mean      | -1.41e+03 |
# |    exploration_rate | 0.356     |
# | time/               |           |
# |    episodes         | 4         |
# |    fps              | 114       |
# |    time_elapsed     | 63        |
# |    total_timesteps  | 7195      |
# | train/              |           |
# |    episode_reward   | -30       |
# |    loss             | 0.221     |
# -----------------------------------
# 1 True
# 0 False
# 0 There are 330 jobs left
# 0 There are 260 jobs left
# 0 There are 190 jobs left
# 0 There are 120 jobs left
# 0 There are 50 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 1.77e+03  |
# |    ep_rew_mean      | -1.44e+03 |
# |    exploration_rate | 0.323     |
# | time/               |           |
# |    episodes         | 5         |
# |    fps              | 118       |
# |    time_elapsed     | 74        |
# |    total_timesteps  | 8827      |
# | train/              |           |
# |    episode_reward   | -30       |
# |    loss             | 0.0524    |
# -----------------------------------
# 6 True
# 5 True
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 134 jobs left
# 0 There are 64 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 1.72e+03  |
# |    ep_rew_mean      | -1.37e+03 |
# |    exploration_rate | 0.294     |
# | time/               |           |
# |    episodes         | 6         |
# |    fps              | 124       |
# |    time_elapsed     | 82        |
# |    total_timesteps  | 10297     |
# | train/              |           |
# |    episode_reward   | -20       |
# |    loss             | 0.0901    |
# -----------------------------------
# 6 True
# 5 True
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 149 jobs left
# 0 There are 79 jobs left
# 0 There are 9 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 1.69e+03  |
# |    ep_rew_mean      | -1.32e+03 |
# |    exploration_rate | 0.264     |
# | time/               |           |
# |    episodes         | 7         |
# |    fps              | 127       |
# |    time_elapsed     | 92        |
# |    total_timesteps  | 11797     |
# | train/              |           |
# |    episode_reward   | -20       |
# |    loss             | 0.0983    |
# -----------------------------------
# 5 True
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 195 jobs left
# 0 There are 125 jobs left
# 0 There are 55 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 1.7e+03   |
# |    ep_rew_mean      | -1.31e+03 |
# |    exploration_rate | 0.229     |
# | time/               |           |
# |    episodes         | 8         |
# |    fps              | 130       |
# |    time_elapsed     | 104       |
# |    total_timesteps  | 13565     |
# | train/              |           |
# |    episode_reward   | -20       |
# |    loss             | 0.136     |
# -----------------------------------
# 5 True
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 265 jobs left
# 0 There are 195 jobs left
# 0 There are 125 jobs left
# 0 There are 55 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.66e+03 |
# |    ep_rew_mean      | -1.3e+03 |
# |    exploration_rate | 0.201    |
# | time/               |          |
# |    episodes         | 9        |
# |    fps              | 131      |
# |    time_elapsed     | 113      |
# |    total_timesteps  | 14945    |
# | train/              |          |
# |    episode_reward   | -30      |
# |    loss             | 0.0833   |
# ----------------------------------
# 5 True
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 265 jobs left
# 0 There are 195 jobs left
# 0 There are 125 jobs left
# 0 There are 55 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 1.63e+03  |
# |    ep_rew_mean      | -1.29e+03 |
# |    exploration_rate | 0.173     |
# | time/               |           |
# |    episodes         | 10        |
# |    fps              | 134       |
# |    time_elapsed     | 121       |
# |    total_timesteps  | 16325     |
# | train/              |           |
# |    episode_reward   | -30       |
# |    loss             | 0.00524   |
# -----------------------------------
# 6 True
# 5 True
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 134 jobs left
# 0 There are 64 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 1.62e+03  |
# |    ep_rew_mean      | -1.27e+03 |
# |    exploration_rate | 0.144     |
# | time/               |           |
# |    episodes         | 11        |
# |    fps              | 136       |
# |    time_elapsed     | 130       |
# |    total_timesteps  | 17795     |
# | train/              |           |
# |    episode_reward   | -22       |
# |    loss             | 0.0454    |
# -----------------------------------
# 5 True
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 314 jobs left
# 0 There are 244 jobs left
# 0 There are 174 jobs left
# 0 There are 104 jobs left
# 0 There are 34 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 1.63e+03  |
# |    ep_rew_mean      | -1.31e+03 |
# |    exploration_rate | 0.108     |
# | time/               |           |
# |    episodes         | 12        |
# |    fps              | 135       |
# |    time_elapsed     | 145       |
# |    total_timesteps  | 19595     |
# | train/              |           |
# |    episode_reward   | -30       |
# |    loss             | 0.00963   |
# -----------------------------------
# 2 True
# 1 True
# 0 False
# 0 There are 431 jobs left
# 0 There are 361 jobs left
# 0 There are 291 jobs left
# 0 There are 221 jobs left
# 0 There are 151 jobs left
# 0 There are 81 jobs left
# 0 There are 11 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 1.67e+03  |
# |    ep_rew_mean      | -1.36e+03 |
# |    exploration_rate | 0.1       |
# | time/               |           |
# |    episodes         | 13        |
# |    fps              | 129       |
# |    time_elapsed     | 167       |
# |    total_timesteps  | 21687     |
# | train/              |           |
# |    episode_reward   | -30       |
# |    loss             | 0.00152   |
# -----------------------------------
# 6 True
# 5 True
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 149 jobs left
# 0 There are 79 jobs left
# 0 There are 9 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 1.66e+03  |
# |    ep_rew_mean      | -1.34e+03 |
# |    exploration_rate | 0.1       |
# | time/               |           |
# |    episodes         | 14        |
# |    fps              | 131       |
# |    time_elapsed     | 176       |
# |    total_timesteps  | 23187     |
# | train/              |           |
# |    episode_reward   | -20       |
# |    loss             | 0.0555    |
# -----------------------------------
# 2 True
# 1 True
# 0 False
# 0 There are 360 jobs left
# 0 There are 290 jobs left
# 0 There are 220 jobs left
# 0 There are 150 jobs left
# 0 There are 80 jobs left
# 0 There are 10 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 1.73e+03  |
# |    ep_rew_mean      | -1.42e+03 |
# |    exploration_rate | 0.1       |
# | time/               |           |
# |    episodes         | 15        |
# |    fps              | 127       |
# |    time_elapsed     | 203       |
# |    total_timesteps  | 25916     |
# | train/              |           |
# |    episode_reward   | -30       |
# |    loss             | 0.000124  |
# -----------------------------------
# 5 True
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 195 jobs left
# 0 There are 125 jobs left
# 0 There are 55 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 1.73e+03  |
# |    ep_rew_mean      | -1.41e+03 |
# |    exploration_rate | 0.1       |
# | time/               |           |
# |    episodes         | 16        |
# |    fps              | 128       |
# |    time_elapsed     | 215       |
# |    total_timesteps  | 27684     |
# | train/              |           |
# |    episode_reward   | -20       |
# |    loss             | 0.0446    |
# -----------------------------------
# 1 True
# 0 False
# 0 There are 286 jobs left
# 0 There are 216 jobs left
# 0 There are 146 jobs left
# 0 There are 76 jobs left
# 0 There are 6 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.72e+03 |
# |    ep_rew_mean      | -1.4e+03 |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 17       |
# |    fps              | 128      |
# |    time_elapsed     | 227      |
# |    total_timesteps  | 29280    |
# | train/              |          |
# |    episode_reward   | -30      |
# |    loss             | 0.0482   |
# ----------------------------------
# 2 True
# 1 True
# 0 False
# 0 There are 454 jobs left
# 0 There are 384 jobs left
# 0 There are 314 jobs left
# 0 There are 244 jobs left
# 0 There are 174 jobs left
# 0 There are 104 jobs left
# 0 There are 34 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 1.79e+03  |
# |    ep_rew_mean      | -1.48e+03 |
# |    exploration_rate | 0.1       |
# | time/               |           |
# |    episodes         | 18        |
# |    fps              | 122       |
# |    time_elapsed     | 263       |
# |    total_timesteps  | 32260     |
# | train/              |           |
# |    episode_reward   | -30       |
# |    loss             | 3.34e-05  |
# -----------------------------------
# 6 True
# 5 True
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 149 jobs left
# 0 There are 79 jobs left
# 0 There are 9 jobs left
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 1.78e+03  |
# |    ep_rew_mean      | -1.46e+03 |
# |    exploration_rate | 0.1       |
# | time/               |           |
# |    episodes         | 19        |
# |    fps              | 124       |
# |    time_elapsed     | 271       |
# |    total_timesteps  | 33760     |
# | train/              |           |
# |    episode_reward   | -22       |
# |    loss             | 0.0425    |
# -----------------------------------
# 2 True
# 1 True
# 0 False
# 0 There are 706 jobs left
# 0 There are 636 jobs left
# 0 There are 566 jobs left
# 0 There are 496 jobs left
# 0 There are 426 jobs left
# 0 There are 356 jobs left
# 0 There are 286 jobs left
# 0 There are 216 jobs left
# 0 There are 146 jobs left
# 0 There are 76 jobs left
# 0 There are 6 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.81e+03 |
# |    ep_rew_mean      | -1.5e+03 |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 123      |
# |    time_elapsed     | 293      |
# |    total_timesteps  | 36160    |
# | train/              |          |
# |    episode_reward   | -30      |
# |    loss             | 0.000285 |
# ----------------------------------
# 2 True
# 1 True
# 0 False
# 0 There are 225 jobs left
# 0 There are 155 jobs left
# 0 There are 85 jobs left
# 0 There are 15 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 1.8e+03   |
# |    ep_rew_mean      | -1.48e+03 |
# |    exploration_rate | 0.1       |
# | time/               |           |
# |    episodes         | 21        |
# |    fps              | 124       |
# |    time_elapsed     | 303       |
# |    total_timesteps  | 37744     |
# | train/              |           |
# |    episode_reward   | -22       |
# |    loss             | 0.064     |
# -----------------------------------
# 2 True
# 1 True
# 0 False
# 0 There are 706 jobs left
# 0 There are 636 jobs left
# 0 There are 566 jobs left
# 0 There are 496 jobs left
# 0 There are 426 jobs left
# 0 There are 356 jobs left
# 0 There are 286 jobs left
# 0 There are 216 jobs left
# 0 There are 146 jobs left
# 0 There are 76 jobs left

# %%
import numpy as np
import torch
from stable_baselines3 import DQN

# model_path = "models/keyref2-2024-11-30_13-16-25/CustomDQN_"

model = DQN.load(model_path, env=env)
def softmax_action_selection(model, obs, mu):
    obs_tensor      = torch.tensor(obs, dtype=torch.float32).unsqueeze(0).to(model.device)
    q_values        = model.q_net(obs_tensor).detach().cpu().numpy().flatten()
    exp_q_values    = np.exp(mu * q_values)
    probabilities   = exp_q_values / np.sum(exp_q_values)
    action          = np.random.choice(len(q_values), p=probabilities)
    return action

results = []
method = 'keyref2'
InstanceList = [f'valid{i+1}' for i in range(5)]
ScenarioList = ['A', 'B', 'C']

mu = 1.6 
for time_run in range(1):
    print('time:', time_run)
    for instance_id in InstanceList:
        print("-----------", instance_id)
        for scenario_id in ScenarioList:
            print("-----", scenario_id)
            # Reset the environment with the new dataset
            obs, info = env.reset(test=True, 
                    datatest=instance_id, 
                    scenariotest=scenario_id)
            
            done = False
            
            while not done:
                action = softmax_action_selection(model, obs, mu)
                obs, reward, done, truncated, info = env.step(action)
            
            tardiness = env.calc_tardiness()
            print(tardiness)
            results.append({
                            'TimeRun'   : time_run,
                            'Method'    : method,
                            'InstanceID': instance_id,
                            'ScenarioID': scenario_id,
                            'Tardiness' : tardiness
                            })
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# time: 0
# ----------- valid1
# ----- A
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 7315.0
# ----- B
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 9955.0
# ----- C
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 9965.0
# ----------- valid2
# ----- A
# 5 True
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 3985.0
# ----- B
# 5 True
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 3700.0
# ----- C
# 5 True
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 3320.0
# ----------- valid3
# ----- A
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 3705.0
# ----- B
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 4485.0
# ----- C
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 4580.0
# ----------- valid4
# ----- A
# 2 True
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 4640.0
# ----- B
# 2 True
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 3615.0
# ----- C
# 2 True
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 1840.0
# ----------- valid5
# ----- A
# 5 True
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 11045.0
# ----- B
# 5 True
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 9655.0
# ----- C
# 5 True
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 10390.0

# %%
InstanceList = [f'valid{i+1}' for i in range(5,10)]

for time_run in range(1):
    print('time:', time_run)
    for instance_id in InstanceList:
        print("-----------", instance_id)
        for scenario_id in ScenarioList:
            print("-----", scenario_id)
            # Reset the environment with the new dataset
            obs, info = env.reset(test=True, 
                    datatest=instance_id, 
                    scenariotest=scenario_id)
            
            done = False
            
            while not done:
                action = softmax_action_selection(model, obs, mu)
                obs, reward, done, truncated, info = env.step(action)
            
            tardiness = env.calc_tardiness()
            print(tardiness)
            results.append({
                            'TimeRun'   : time_run,
                            'Method'    : method,
                            'InstanceID': instance_id,
                            'ScenarioID': scenario_id,
                            'Tardiness' : tardiness
                            })
# Out:
# time: 0
# ----------- valid6
# ----- A
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 19045.0
# ----- B
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 16030.0
# ----- C
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 16975.0
# ----------- valid7
# ----- A
# 6 True
# 5 True
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 935.0
# ----- B
# 6 True
# 5 True
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 1690.0
# ----- C
# 6 True
# 5 True
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 1740.0
# ----------- valid8
# ----- A
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 12515.0
# ----- B
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 20460.0
# ----- C
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 20245.0
# ----------- valid9
# ----- A
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 1785.0
# ----- B
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 2770.0
# ----- C
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 2120.0
# ----------- valid10
# ----- A
# 5 True
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 4565.0
# ----- B
# 5 True
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 9595.0
# ----- C
# 5 True
# 4 True
# 3 True
# 2 True
# 1 True
# 0 False
# 0 There are 669 jobs left
# 0 There are 599 jobs left
# 0 There are 529 jobs left
# 0 There are 459 jobs left
# 0 There are 389 jobs left
# 0 There are 319 jobs left
# 0 There are 249 jobs left
# 0 There are 179 jobs left
# 0 There are 109 jobs left
# 0 There are 39 jobs left
# find no events
# find no events
# find no events
# ====== Done ======
# JSet contains 0 elements while JA_event contains 0 True
# 7085.0

# %%
df = pd.DataFrame(results)
file_name = f"VALIDATION/LuoDDQN_tight_duedate_JA_only_1to10.xlsx"
df.to_excel(file_name, index=False)
